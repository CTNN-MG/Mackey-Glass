# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, random_split
import time
import random

import psutil
import os
from scipy.stats import f as f_dist
from scipy.stats import pearsonr, spearmanr
from scipy.signal import welch
from numpy.linalg import norm

# --- 1. Fix Python, NumPy, and random seeds ---
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# --- 2. Force deterministic behavior for cuDNN ---
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# --- Use GPU if available ---
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# --- Mackey-Glass Generator ---
def mackey_glass(t_max, tau=17, delta_t=1, beta=0.2, gamma=0.1, n=10, x0=1.2):
    t_len = int(t_max / delta_t)
    x = np.zeros(t_len)
    x[0] = x0
    for t in range(1, t_len):
        if t - tau >= 0:
            x[t] = x[t - 1] + delta_t * (
                beta * x[t - tau] / (1 + x[t - tau] ** n) - gamma * x[t - 1]
            )
        else:
            x[t] = x[t - 1] - delta_t * gamma * x[t - 1]
    return x

# --- Function to insert anomalies ---
def insert_anomalies(x, anomaly_rate=0.05, anomaly_scale=0.5):
    x_anom = x.copy()
    n_points = len(x)
    n_anomalies = int(n_points * anomaly_rate)
    anomaly_indices = np.random.choice(n_points, size=n_anomalies, replace=False)
    for idx in anomaly_indices:
        x_anom[idx] += np.random.uniform(-anomaly_scale, anomaly_scale)
    return x_anom
# ============================================================
# CPU RAM Tracking
# ============================================================

process = psutil.Process(os.getpid())
cpu_ram_log = []

def get_cpu_ram_mb():
    return process.memory_info().rss / (1024 ** 2)

# --- Parameters ---
t_max = 200
delta_t = 1
train_ics_left = np.linspace(0, 1.17, 15)
train_ics_right = np.linspace(1.23, 3, 15)
train_ics = np.concatenate((train_ics_left, train_ics_right))
test_ic = 0.8
timesteps = np.arange(0, t_max, delta_t)

# --- Generate training data ---
X_list, y_list = [], []
anomalous_indices = [15, 5, 23, 7, 18]

for i, ic in enumerate(train_ics):
    x = mackey_glass(t_max=t_max, x0=ic)
    if i in anomalous_indices:
        x = insert_anomalies(x, anomaly_rate=0.1, anomaly_scale=0.7)
    norm_t = timesteps / t_max
    features = np.stack([np.full_like(norm_t, ic), norm_t], axis=1)
    X_list.append(features)
    y_list.append(x)

X = np.vstack(X_list)
y = np.concatenate(y_list)

# --- Plot trajectories (optional) ---
import math
n_traj = len(y_list)
n_cols = 5
n_rows = math.ceil(n_traj / n_cols)
plt.figure(figsize=(n_cols*3, n_rows*2.5))
for i, x in enumerate(y_list):
    plt.subplot(n_rows, n_cols, i+1)
    if i in anomalous_indices:
        plt.plot(x, 'r--')
        plt.gca().set_facecolor("#ffeeee")
    else:
        plt.plot(x, 'b-')
    plt.title(f"IC={train_ics[i]:.2f}")
    plt.xticks([]); plt.yticks([])
plt.tight_layout(); plt.show()

# --- Generate test data ---
x_test = mackey_glass(t_max=200, x0=test_ic)
norm_t_test = timesteps / t_max
X_test = np.stack([np.full_like(norm_t_test, test_ic), norm_t_test], axis=1)
y_test = x_test

# --- Normalize features ---
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_test_scaled = scaler.transform(X_test)

# --- Prepare torch datasets ---
X_tensor = torch.tensor(X_scaled, dtype=torch.float32).reshape(len(train_ics), t_max, 2)
y_tensor = torch.tensor(y, dtype=torch.float32).reshape(len(train_ics), t_max)
X_test_tensor = torch.tensor(X_test_scaled, dtype=torch.float32).unsqueeze(0).to(device)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(0).to(device)

# --- Split into train and val ---
val_split = 1
train_len = len(train_ics) - val_split
train_dataset, val_dataset = random_split(TensorDataset(X_tensor, y_tensor), [train_len, val_split])
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=4)

# ============================================================
# Imports
# ============================================================
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset, random_split
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
import time
import psutil
import os
import random

# ============================================================
# Reproducibility
# ============================================================
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# ============================================================
# Device
# ============================================================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# ============================================================
# Mackey–Glass Generator
# ============================================================
def mackey_glass(t_max, tau=17, delta_t=1, beta=0.2, gamma=0.1, n=10, x0=1.2):
    t_len = int(t_max / delta_t)
    x = np.zeros(t_len)
    x[0] = x0
    for t in range(1, t_len):
        if t - tau >= 0:
            x[t] = x[t - 1] + delta_t * (
                beta * x[t - tau] / (1 + x[t - tau] ** n) - gamma * x[t - 1]
            )
        else:
            x[t] = x[t - 1] - delta_t * gamma * x[t - 1]
    return x

# ============================================================
# Dataset
# ============================================================
t_max = 200
delta_t = 1
timesteps = np.arange(0, t_max, delta_t)

train_ics = np.concatenate([
    np.linspace(0, 1.17, 15),
    np.linspace(1.23, 3, 15)
])

X_list, y_list = [], []
for ic in train_ics:
    traj = mackey_glass(t_max=t_max, x0=ic)
    norm_t = timesteps / t_max
    X_list.append(np.stack([np.full_like(norm_t, ic), norm_t], axis=1))
    y_list.append(traj)

X = np.vstack(X_list)
y = np.concatenate(y_list)

# Test
x_test = mackey_glass(t_max=t_max, x0=test_ic)
X_test = np.stack([np.full_like(timesteps, test_ic), timesteps / t_max], axis=1)

# ============================================================
# Normalize
# ============================================================
scaler = StandardScaler()
X = scaler.fit_transform(X)
X_test = scaler.transform(X_test)

X_tensor = torch.tensor(X, dtype=torch.float32).reshape(len(train_ics), t_max, 2)
y_tensor = torch.tensor(y, dtype=torch.float32).reshape(len(train_ics), t_max)

X_test_tensor = torch.tensor(X_test, dtype=torch.float32).unsqueeze(0).to(device)
y_test = x_test

# ============================================================
# DataLoaders
# ============================================================
dataset = TensorDataset(X_tensor, y_tensor)
train_ds, val_ds = random_split(dataset, [len(dataset)-1, 1])

train_loader = DataLoader(train_ds, batch_size=4, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=4)

# ============================================================
# FNO Components
# ============================================================
class SpectralConv1d(nn.Module):
    def __init__(self, in_channels, out_channels, modes):
        super().__init__()
        self.modes = modes
        self.scale = 1 / (in_channels * out_channels)
        self.weights_real = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, modes))
        self.weights_imag = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, modes))

    def forward(self, x):
        x_ft = torch.fft.rfft(x, dim=-1)
        modes = min(self.modes, x_ft.size(-1))
        out_ft = torch.einsum(
            "bcm,com->bom",
            x_ft[:, :, :modes],
            torch.complex(self.weights_real[:, :, :modes], self.weights_imag[:, :, :modes])
        )
        out_ft_full = torch.zeros(x.size(0), out_ft.size(1), x_ft.size(-1),
                                  dtype=torch.cfloat, device=x.device)
        out_ft_full[:, :, :modes] = out_ft
        return torch.fft.irfft(out_ft_full, n=x.size(-1), dim=-1)

class FNO1d(nn.Module):
    def __init__(self, modes=16, width=64):
        super().__init__()
        self.fc0 = nn.Linear(2, width)

        self.convs = nn.ModuleList([SpectralConv1d(width, width, modes) for _ in range(4)])
        self.ws = nn.ModuleList([nn.Conv1d(width, width, 1) for _ in range(4)])

        self.fc1 = nn.Linear(width, 128)
        self.fc2 = nn.Linear(128, 1)

    def forward(self, x):
        x = self.fc0(x).permute(0, 2, 1)
        for conv, w in zip(self.convs, self.ws):
            x = F.gelu(conv(x) + w(x))
        x = x.permute(0, 2, 1)
        return self.fc2(F.gelu(self.fc1(x))).squeeze(-1)

# ============================================================
# Instantiate
# ============================================================
model = FNO1d().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.MSELoss()

# ============================================================
# Resource Tracking
# ============================================================
def cpu_mem():
    return psutil.Process(os.getpid()).memory_info().rss / 1024**2

def gpu_mem():
    if torch.cuda.is_available():
        return torch.cuda.max_memory_allocated() / 1024**2
    return None

epoch_times, cpu_mem_log, gpu_mem_log = [], [], []

# ============================================================
# Training
# ============================================================
epochs = 200
best_val = float("inf")
patience, wait = 30, 0

start_train = time.time()
for ep in range(epochs):
    ep_start = time.time()
    model.train()

    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        loss = criterion(model(xb), yb)
        loss.backward()
        optimizer.step()

    model.eval()
    with torch.no_grad():
        val_loss = sum(criterion(model(xv.to(device)), yv.to(device)).item()
                       for xv, yv in val_loader)

    epoch_times.append(time.time() - ep_start)
    cpu_mem_log.append(cpu_mem())
    if torch.cuda.is_available():
        torch.cuda.synchronize()
        gpu_mem_log.append(gpu_mem())

    print(f"Epoch {ep:03d} | Val Loss {val_loss:.5f}")

    if val_loss < best_val:
        best_val = val_loss
        best_state = model.state_dict()
        wait = 0
    else:
        wait += 1
        if wait >= patience:
            break

total_train_time = time.time() - start_train
print(f"\nTotal training time: {total_train_time:.2f}s")

# ============================================================
# CPU RAM Usage
# ============================================================
process = psutil.Process(os.getpid())

# Current CPU RAM usage
cpu_ram_mb = process.memory_info().rss / (1024 ** 2)

print(f"CPU RAM: {cpu_ram_mb:.2f} MB")

# ============================================================
# Inference Timing
# ============================================================
model.load_state_dict(best_state)
model.eval()

with torch.no_grad():
    t0 = time.time()
    for _ in range(50):
        _ = model(X_test_tensor)
    infer_time = (time.time() - t0) / 50

print(f"Inference time per trajectory: {infer_time:.6f}s")

# ============================================================
# Evaluation
# ============================================================
with torch.no_grad():
    pred = model(X_test_tensor).cpu().numpy().flatten()

print("RMSE:", np.sqrt(mean_squared_error(y_test, pred)))
print("R²:", r2_score(y_test, pred))

# ============================================================
# Plots
# ============================================================
plt.figure()
plt.plot(epoch_times)
plt.title("FNO Epoch Time")
plt.xlabel("Epoch")
plt.ylabel("Seconds")
plt.grid()
plt.show()

plt.figure()
plt.plot(cpu_mem_log, label="CPU MB")
if gpu_mem_log:
    plt.plot(gpu_mem_log, label="GPU MB")
plt.legend()
plt.title("Memory Usage")
plt.grid()
plt.show()

plt.figure()
plt.plot(y_test, label="True")
plt.plot(pred, '--', label="FNO")
plt.legend()
plt.title("FNO Prediction on Unseen IC")
plt.grid()
plt.show()

# Divergence
errors = np.abs(pred - y_test)            # abs error
rmse_window = np.sqrt((pred - y_test)**2) # RMSE error

# Optional: smooth with moving average for clarity
def moving_avg(x, w=10):
    return np.convolve(x, np.ones(w)/w, mode='valid')

window_size = 10
smoothed_error = moving_avg(errors, w=window_size)
smoothed_rmse = moving_avg(rmse_window, w=window_size)

# Plot
plt.figure(figsize=(10, 4))
plt.plot(smoothed_error, label="Abs Error (Smoothed)", alpha=0.8)
plt.plot(smoothed_rmse, label="RMSE (Smoothed)", alpha=0.8)
plt.axhline(y=0.05, color='r', linestyle='--', label='Error Threshold (0.05)')
plt.title("Prediction Divergence Over Time")
plt.xlabel("Time Step")
plt.ylabel("Prediction Error")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

threshold = 0.05
divergence_time = np.argmax(smoothed_error > threshold)
print(f"Prediction horizon at threshold {threshold}: {divergence_time} steps")

# ============================================================
# FINAL METRICS
# ============================================================

# RMSE
rmse = np.sqrt(mean_squared_error(y_test, pred))

# R²
r2 = r2_score(y_test, pred)

# ------------------------------------------------------------
# F-statistic and p-value
# ------------------------------------------------------------
n = len(y_test)
k = X_test.shape[1]

F_stat = (r2 / k) / ((1 - r2) / (n - k - 1))
p_value = 1 - f_dist.cdf(F_stat, k, n - k - 1)

# ------------------------------------------------------------
# Pearson and Spearman correlations
# ------------------------------------------------------------
pearson_corr, _ = pearsonr(y_test, pred)
spearman_corr, _ = spearmanr(y_test, pred)

# ------------------------------------------------------------
# Spectral cosine similarity
# ------------------------------------------------------------
def spectral_similarity(y_true, y_pred, fs=1.0):
    # Welch’s method for power spectral density (PSD)
    f_true, Pxx_true = welch(y_true, fs=fs, nperseg=128)
    f_pred, Pxx_pred = welch(y_pred, fs=fs, nperseg=128)

    # Normalize
    Pxx_true /= np.sum(Pxx_true)
    Pxx_pred /= np.sum(Pxx_pred)

    # Cosine similarity
    cosine_sim = np.dot(Pxx_true, Pxx_pred) / (norm(Pxx_true) * norm(Pxx_pred))
    return cosine_sim, f_true, Pxx_true, Pxx_pred


cos_sim, f, spec_true, spec_pred = spectral_similarity(
    y_test,
    pred
)

# ------------------------------------------------------------
# Peak CPU RAM
# ------------------------------------------------------------
peak_cpu_ram = max(cpu_mem_log)

# ------------------------------------------------------------
# Print all metrics
# ------------------------------------------------------------
print("\n========================================")
print("FINAL MODEL METRICS")
print("========================================")
print(f"RMSE:                       {rmse:.6f}")
print(f"R²:                         {r2:.6f}")
print(f"F-statistic:                {F_stat:.6f}")
print(f"p-value:                    {p_value:.6e}")
print(f"Pearson correlation:        {pearson_corr:.6f}")
print(f"Spearman correlation:       {spearman_corr:.6f}")
print(f"Spectral cosine similarity: {cos_sim:.6f}")
print(f"Peak CPU RAM:               {peak_cpu_ram:.2f} MB")
print("========================================")
# Out:
# Using device: cuda
# Using device: cuda
# Epoch 000 | Val Loss 0.27205
# Epoch 001 | Val Loss 0.11161
# Epoch 002 | Val Loss 0.10203
# Epoch 003 | Val Loss 0.07272
# Epoch 004 | Val Loss 0.05293
# Epoch 005 | Val Loss 0.06594
# Epoch 006 | Val Loss 0.06277
# Epoch 007 | Val Loss 0.06533
# Epoch 008 | Val Loss 0.06265
# Epoch 009 | Val Loss 0.07808
# Epoch 010 | Val Loss 0.07100
# Epoch 011 | Val Loss 0.09635
# Epoch 012 | Val Loss 0.05939
# Epoch 013 | Val Loss 0.07123
# Epoch 014 | Val Loss 0.07315
# Epoch 015 | Val Loss 0.08544
# Epoch 016 | Val Loss 0.06971
# Epoch 017 | Val Loss 0.06269
# Epoch 018 | Val Loss 0.08025
# Epoch 019 | Val Loss 0.08580
# Epoch 020 | Val Loss 0.08865
# Epoch 021 | Val Loss 0.09080
# Epoch 022 | Val Loss 0.12909
# Epoch 023 | Val Loss 0.08037
# Epoch 024 | Val Loss 0.05969
# Epoch 025 | Val Loss 0.08157
# Epoch 026 | Val Loss 0.06494
# Epoch 027 | Val Loss 0.08475
# Epoch 028 | Val Loss 0.07781
# Epoch 029 | Val Loss 0.06747
# Epoch 030 | Val Loss 0.07335
# Epoch 031 | Val Loss 0.07038
# Epoch 032 | Val Loss 0.06223
# Epoch 033 | Val Loss 0.04620
# Epoch 034 | Val Loss 0.05114
# Epoch 035 | Val Loss 0.05412
# Epoch 036 | Val Loss 0.17381
# Epoch 037 | Val Loss 0.08904
# Epoch 038 | Val Loss 0.08441
# Epoch 039 | Val Loss 0.07534
# Epoch 040 | Val Loss 0.07550
# Epoch 041 | Val Loss 0.07092
# Epoch 042 | Val Loss 0.06281
# Epoch 043 | Val Loss 0.06391
# Epoch 044 | Val Loss 0.06225
# Epoch 045 | Val Loss 0.06331
# Epoch 046 | Val Loss 0.05825
# Epoch 047 | Val Loss 0.05816
# Epoch 048 | Val Loss 0.05532
# Epoch 049 | Val Loss 0.05623
# Epoch 050 | Val Loss 0.04878
# Epoch 051 | Val Loss 0.04795
# Epoch 052 | Val Loss 0.04454
# Epoch 053 | Val Loss 0.04380
# Epoch 054 | Val Loss 0.05237
# Epoch 055 | Val Loss 0.04231
# Epoch 056 | Val Loss 0.04138
# Epoch 057 | Val Loss 0.03760
# Epoch 058 | Val Loss 0.03372
# Epoch 059 | Val Loss 0.15788
# Epoch 060 | Val Loss 0.07783
# Epoch 061 | Val Loss 0.05688
# Epoch 062 | Val Loss 0.03887
# Epoch 063 | Val Loss 0.04761
# Epoch 064 | Val Loss 0.04621
# Epoch 065 | Val Loss 0.04414
# Epoch 066 | Val Loss 0.03605
# Epoch 067 | Val Loss 0.03204
# Epoch 068 | Val Loss 0.02994
# Epoch 069 | Val Loss 0.03236
# Epoch 070 | Val Loss 0.14776
# Epoch 071 | Val Loss 0.05555
# Epoch 072 | Val Loss 0.04361
# Epoch 073 | Val Loss 0.02876
# Epoch 074 | Val Loss 0.02761
# Epoch 075 | Val Loss 0.02886
# Epoch 076 | Val Loss 0.02837
# Epoch 077 | Val Loss 0.02815
# Epoch 078 | Val Loss 0.02890
# Epoch 079 | Val Loss 0.03243
# Epoch 080 | Val Loss 0.02873
# Epoch 081 | Val Loss 0.02577
# Epoch 082 | Val Loss 0.02289
# Epoch 083 | Val Loss 0.01601
# Epoch 084 | Val Loss 0.01855
# Epoch 085 | Val Loss 0.02387
# Epoch 086 | Val Loss 0.02256
# Epoch 087 | Val Loss 0.02144
# Epoch 088 | Val Loss 0.02355
# Epoch 089 | Val Loss 0.02029
# Epoch 090 | Val Loss 0.02198
# Epoch 091 | Val Loss 0.03075
# Epoch 092 | Val Loss 0.04149
# Epoch 093 | Val Loss 0.02396
# Epoch 094 | Val Loss 0.03067
# Epoch 095 | Val Loss 0.01886
# Epoch 096 | Val Loss 0.02281
# Epoch 097 | Val Loss 0.02177
# Epoch 098 | Val Loss 0.04525
# Epoch 099 | Val Loss 0.02414
# Epoch 100 | Val Loss 0.02302
# Epoch 101 | Val Loss 0.01599
# Epoch 102 | Val Loss 0.01687
# Epoch 103 | Val Loss 0.01525
# Epoch 104 | Val Loss 0.01867
# Epoch 105 | Val Loss 0.01895
# Epoch 106 | Val Loss 0.02047
# Epoch 107 | Val Loss 0.01617
# Epoch 108 | Val Loss 0.02167
# Epoch 109 | Val Loss 0.01682
# Epoch 110 | Val Loss 0.02295
# Epoch 111 | Val Loss 0.02722
# Epoch 112 | Val Loss 0.03096
# Epoch 113 | Val Loss 0.04033
# Epoch 114 | Val Loss 0.02550
# Epoch 115 | Val Loss 0.01706
# Epoch 116 | Val Loss 0.01950
# Epoch 117 | Val Loss 0.01761
# Epoch 118 | Val Loss 0.01824
# Epoch 119 | Val Loss 0.01603
# Epoch 120 | Val Loss 0.01763
# Epoch 121 | Val Loss 0.01910
# Epoch 122 | Val Loss 0.01808
# Epoch 123 | Val Loss 0.02452
# Epoch 124 | Val Loss 0.02264
# Epoch 125 | Val Loss 0.04370
# Epoch 126 | Val Loss 0.05206
# Epoch 127 | Val Loss 0.04974
# Epoch 128 | Val Loss 0.05511
# Epoch 129 | Val Loss 0.03293
# Epoch 130 | Val Loss 0.03032
# Epoch 131 | Val Loss 0.03441
# Epoch 132 | Val Loss 0.02520
# Epoch 133 | Val Loss 0.02018
#
# Total training time: 7.82s
# CPU RAM: 1429.73 MB
# Inference time per trajectory: 0.001981s
# RMSE: 0.7066297767029041
# R²: -5.707408278688394
# Prediction horizon at threshold 0.05: 0 steps
#
# ========================================
# FINAL MODEL METRICS
# ========================================
# RMSE:                       0.706630
# R²:                         -5.707408
# F-statistic:                -83.814745
# p-value:                    1.000000e+00
# Pearson correlation:        0.251726
# Spearman correlation:       0.252345
# Spectral cosine similarity: 0.570170
# Peak CPU RAM:               1429.73 MB
# ========================================

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, random_split
import time
import random

import psutil
import os
from scipy.stats import f as f_dist
from scipy.stats import pearsonr, spearmanr
from scipy.signal import welch
from numpy.linalg import norm

# --- 1. Fix Python, NumPy, and random seeds ---
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# --- 2. Force deterministic behavior for cuDNN ---
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# --- Use GPU if available ---
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# --- Mackey-Glass Generator ---
def mackey_glass(t_max, tau=17, delta_t=1, beta=0.2, gamma=0.1, n=10, x0=1.2):
    t_len = int(t_max / delta_t)
    x = np.zeros(t_len)
    x[0] = x0
    for t in range(1, t_len):
        if t - tau >= 0:
            x[t] = x[t - 1] + delta_t * (
                beta * x[t - tau] / (1 + x[t - tau] ** n) - gamma * x[t - 1]
            )
        else:
            x[t] = x[t - 1] - delta_t * gamma * x[t - 1]
    return x

# --- Function to insert anomalies ---
def insert_anomalies(x, anomaly_rate=0.05, anomaly_scale=0.5):
    x_anom = x.copy()
    n_points = len(x)
    n_anomalies = int(n_points * anomaly_rate)
    anomaly_indices = np.random.choice(n_points, size=n_anomalies, replace=False)
    for idx in anomaly_indices:
        x_anom[idx] += np.random.uniform(-anomaly_scale, anomaly_scale)
    return x_anom
# ============================================================
# CPU RAM Tracking
# ============================================================

process = psutil.Process(os.getpid())
cpu_ram_log = []

def get_cpu_ram_mb():
    return process.memory_info().rss / (1024 ** 2)

# --- Parameters ---
t_max = 200
delta_t = 1
train_ics_left = np.linspace(0, 1.17, 15)
train_ics_right = np.linspace(1.23, 3, 15)
train_ics = np.concatenate((train_ics_left, train_ics_right))
test_ic = 1.2
timesteps = np.arange(0, t_max, delta_t)

# --- Generate training data ---
X_list, y_list = [], []
anomalous_indices = [15, 5, 23, 7, 18]

for i, ic in enumerate(train_ics):
    x = mackey_glass(t_max=t_max, x0=ic)
    if i in anomalous_indices:
        x = insert_anomalies(x, anomaly_rate=0.1, anomaly_scale=0.7)
    norm_t = timesteps / t_max
    features = np.stack([np.full_like(norm_t, ic), norm_t], axis=1)
    X_list.append(features)
    y_list.append(x)

X = np.vstack(X_list)
y = np.concatenate(y_list)

# --- Plot trajectories (optional) ---
import math
n_traj = len(y_list)
n_cols = 5
n_rows = math.ceil(n_traj / n_cols)
plt.figure(figsize=(n_cols*3, n_rows*2.5))
for i, x in enumerate(y_list):
    plt.subplot(n_rows, n_cols, i+1)
    if i in anomalous_indices:
        plt.plot(x, 'r--')
        plt.gca().set_facecolor("#ffeeee")
    else:
        plt.plot(x, 'b-')
    plt.title(f"IC={train_ics[i]:.2f}")
    plt.xticks([]); plt.yticks([])
plt.tight_layout(); plt.show()

# --- Generate test data ---
x_test = mackey_glass(t_max=200, x0=test_ic)
norm_t_test = timesteps / t_max
X_test = np.stack([np.full_like(norm_t_test, test_ic), norm_t_test], axis=1)
y_test = x_test

# --- Normalize features ---
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_test_scaled = scaler.transform(X_test)

# --- Prepare torch datasets ---
X_tensor = torch.tensor(X_scaled, dtype=torch.float32).reshape(len(train_ics), t_max, 2)
y_tensor = torch.tensor(y, dtype=torch.float32).reshape(len(train_ics), t_max)
X_test_tensor = torch.tensor(X_test_scaled, dtype=torch.float32).unsqueeze(0).to(device)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(0).to(device)

# --- Split into train and val ---
val_split = 1
train_len = len(train_ics) - val_split
train_dataset, val_dataset = random_split(TensorDataset(X_tensor, y_tensor), [train_len, val_split])
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=4)

# ============================================================
# Imports
# ============================================================
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset, random_split
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
import time
import psutil
import os
import random

# ============================================================
# Reproducibility
# ============================================================
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# ============================================================
# Device
# ============================================================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# ============================================================
# Mackey–Glass Generator
# ============================================================
def mackey_glass(t_max, tau=17, delta_t=1, beta=0.2, gamma=0.1, n=10, x0=1.2):
    t_len = int(t_max / delta_t)
    x = np.zeros(t_len)
    x[0] = x0
    for t in range(1, t_len):
        if t - tau >= 0:
            x[t] = x[t - 1] + delta_t * (
                beta * x[t - tau] / (1 + x[t - tau] ** n) - gamma * x[t - 1]
            )
        else:
            x[t] = x[t - 1] - delta_t * gamma * x[t - 1]
    return x

# ============================================================
# Dataset
# ============================================================
t_max = 200
delta_t = 1
timesteps = np.arange(0, t_max, delta_t)

train_ics = np.concatenate([
    np.linspace(0, 1.17, 15),
    np.linspace(1.23, 3, 15)
])

X_list, y_list = [], []
for ic in train_ics:
    traj = mackey_glass(t_max=t_max, x0=ic)
    norm_t = timesteps / t_max
    X_list.append(np.stack([np.full_like(norm_t, ic), norm_t], axis=1))
    y_list.append(traj)

X = np.vstack(X_list)
y = np.concatenate(y_list)

# Test
x_test = mackey_glass(t_max=t_max, x0=test_ic)
X_test = np.stack([np.full_like(timesteps, test_ic), timesteps / t_max], axis=1)

# ============================================================
# Normalize
# ============================================================
scaler = StandardScaler()
X = scaler.fit_transform(X)
X_test = scaler.transform(X_test)

X_tensor = torch.tensor(X, dtype=torch.float32).reshape(len(train_ics), t_max, 2)
y_tensor = torch.tensor(y, dtype=torch.float32).reshape(len(train_ics), t_max)

X_test_tensor = torch.tensor(X_test, dtype=torch.float32).unsqueeze(0).to(device)
y_test = x_test

# ============================================================
# DataLoaders
# ============================================================
dataset = TensorDataset(X_tensor, y_tensor)
train_ds, val_ds = random_split(dataset, [len(dataset)-1, 1])

train_loader = DataLoader(train_ds, batch_size=4, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=4)

# ============================================================
# FNO Components
# ============================================================
class SpectralConv1d(nn.Module):
    def __init__(self, in_channels, out_channels, modes):
        super().__init__()
        self.modes = modes
        self.scale = 1 / (in_channels * out_channels)
        self.weights_real = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, modes))
        self.weights_imag = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, modes))

    def forward(self, x):
        x_ft = torch.fft.rfft(x, dim=-1)
        modes = min(self.modes, x_ft.size(-1))
        out_ft = torch.einsum(
            "bcm,com->bom",
            x_ft[:, :, :modes],
            torch.complex(self.weights_real[:, :, :modes], self.weights_imag[:, :, :modes])
        )
        out_ft_full = torch.zeros(x.size(0), out_ft.size(1), x_ft.size(-1),
                                  dtype=torch.cfloat, device=x.device)
        out_ft_full[:, :, :modes] = out_ft
        return torch.fft.irfft(out_ft_full, n=x.size(-1), dim=-1)

class FNO1d(nn.Module):
    def __init__(self, modes=16, width=64):
        super().__init__()
        self.fc0 = nn.Linear(2, width)

        self.convs = nn.ModuleList([SpectralConv1d(width, width, modes) for _ in range(4)])
        self.ws = nn.ModuleList([nn.Conv1d(width, width, 1) for _ in range(4)])

        self.fc1 = nn.Linear(width, 128)
        self.fc2 = nn.Linear(128, 1)

    def forward(self, x):
        x = self.fc0(x).permute(0, 2, 1)
        for conv, w in zip(self.convs, self.ws):
            x = F.gelu(conv(x) + w(x))
        x = x.permute(0, 2, 1)
        return self.fc2(F.gelu(self.fc1(x))).squeeze(-1)

# ============================================================
# Instantiate
# ============================================================
model = FNO1d().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.MSELoss()

# ============================================================
# Resource Tracking
# ============================================================
def cpu_mem():
    return psutil.Process(os.getpid()).memory_info().rss / 1024**2

def gpu_mem():
    if torch.cuda.is_available():
        return torch.cuda.max_memory_allocated() / 1024**2
    return None

epoch_times, cpu_mem_log, gpu_mem_log = [], [], []

# ============================================================
# Training
# ============================================================
epochs = 200
best_val = float("inf")
patience, wait = 30, 0

start_train = time.time()
for ep in range(epochs):
    ep_start = time.time()
    model.train()

    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        loss = criterion(model(xb), yb)
        loss.backward()
        optimizer.step()

    model.eval()
    with torch.no_grad():
        val_loss = sum(criterion(model(xv.to(device)), yv.to(device)).item()
                       for xv, yv in val_loader)

    epoch_times.append(time.time() - ep_start)
    cpu_mem_log.append(cpu_mem())
    if torch.cuda.is_available():
        torch.cuda.synchronize()
        gpu_mem_log.append(gpu_mem())

    print(f"Epoch {ep:03d} | Val Loss {val_loss:.5f}")

    if val_loss < best_val:
        best_val = val_loss
        best_state = model.state_dict()
        wait = 0
    else:
        wait += 1
        if wait >= patience:
            break

total_train_time = time.time() - start_train
print(f"\nTotal training time: {total_train_time:.2f}s")

# ============================================================
# CPU RAM Usage
# ============================================================
process = psutil.Process(os.getpid())

# Current CPU RAM usage
cpu_ram_mb = process.memory_info().rss / (1024 ** 2)

print(f"CPU RAM: {cpu_ram_mb:.2f} MB")

# ============================================================
# Inference Timing
# ============================================================
model.load_state_dict(best_state)
model.eval()

with torch.no_grad():
    t0 = time.time()
    for _ in range(50):
        _ = model(X_test_tensor)
    infer_time = (time.time() - t0) / 50

print(f"Inference time per trajectory: {infer_time:.6f}s")

# ============================================================
# Evaluation
# ============================================================
with torch.no_grad():
    pred = model(X_test_tensor).cpu().numpy().flatten()

print("RMSE:", np.sqrt(mean_squared_error(y_test, pred)))
print("R²:", r2_score(y_test, pred))

# ============================================================
# Plots
# ============================================================
plt.figure()
plt.plot(epoch_times)
plt.title("FNO Epoch Time")
plt.xlabel("Epoch")
plt.ylabel("Seconds")
plt.grid()
plt.show()

plt.figure()
plt.plot(cpu_mem_log, label="CPU MB")
if gpu_mem_log:
    plt.plot(gpu_mem_log, label="GPU MB")
plt.legend()
plt.title("Memory Usage")
plt.grid()
plt.show()

plt.figure()
plt.plot(y_test, label="True")
plt.plot(pred, '--', label="FNO")
plt.legend()
plt.title("FNO Prediction on Unseen IC")
plt.grid()
plt.show()


# Divergence
errors = np.abs(pred - y_test)            # abs error
rmse_window = np.sqrt((pred - y_test)**2) # RMSE error

# Optional: smooth with moving average for clarity
def moving_avg(x, w=10):
    return np.convolve(x, np.ones(w)/w, mode='valid')

window_size = 10
smoothed_error = moving_avg(errors, w=window_size)
smoothed_rmse = moving_avg(rmse_window, w=window_size)

# Plot
plt.figure(figsize=(10, 4))
plt.plot(smoothed_error, label="Abs Error (Smoothed)", alpha=0.8)
plt.plot(smoothed_rmse, label="RMSE (Smoothed)", alpha=0.8)
plt.axhline(y=0.05, color='r', linestyle='--', label='Error Threshold (0.05)')
plt.title("Prediction Divergence Over Time")
plt.xlabel("Time Step")
plt.ylabel("Prediction Error")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

threshold = 0.05
divergence_time = np.argmax(smoothed_error > threshold)
print(f"Prediction horizon at threshold {threshold}: {divergence_time} steps")

# ============================================================
# FINAL METRICS
# ============================================================

# RMSE
rmse = np.sqrt(mean_squared_error(y_test, pred))

# R²
r2 = r2_score(y_test, pred)

# ------------------------------------------------------------
# F-statistic and p-value
# ------------------------------------------------------------
n = len(y_test)
k = X_test.shape[1]

F_stat = (r2 / k) / ((1 - r2) / (n - k - 1))
p_value = 1 - f_dist.cdf(F_stat, k, n - k - 1)

# ------------------------------------------------------------
# Pearson and Spearman correlations
# ------------------------------------------------------------
pearson_corr, _ = pearsonr(y_test, pred)
spearman_corr, _ = spearmanr(y_test, pred)

# ------------------------------------------------------------
# Spectral cosine similarity
# ------------------------------------------------------------
def spectral_similarity(y_true, y_pred, fs=1.0):
    # Welch’s method for power spectral density (PSD)
    f_true, Pxx_true = welch(y_true, fs=fs, nperseg=128)
    f_pred, Pxx_pred = welch(y_pred, fs=fs, nperseg=128)

    # Normalize
    Pxx_true /= np.sum(Pxx_true)
    Pxx_pred /= np.sum(Pxx_pred)

    # Cosine similarity
    cosine_sim = np.dot(Pxx_true, Pxx_pred) / (norm(Pxx_true) * norm(Pxx_pred))
    return cosine_sim, f_true, Pxx_true, Pxx_pred


cos_sim, f, spec_true, spec_pred = spectral_similarity(
    y_test,
    pred
)

# ------------------------------------------------------------
# Peak CPU RAM
# ------------------------------------------------------------
peak_cpu_ram = max(cpu_mem_log)

# ------------------------------------------------------------
# Print all metrics
# ------------------------------------------------------------
print("\n========================================")
print("FINAL MODEL METRICS")
print("========================================")
print(f"RMSE:                       {rmse:.6f}")
print(f"R²:                         {r2:.6f}")
print(f"F-statistic:                {F_stat:.6f}")
print(f"p-value:                    {p_value:.6e}")
print(f"Pearson correlation:        {pearson_corr:.6f}")
print(f"Spearman correlation:       {spearman_corr:.6f}")
print(f"Spectral cosine similarity: {cos_sim:.6f}")
print(f"Peak CPU RAM:               {peak_cpu_ram:.2f} MB")
print("========================================")
# Out:
# Using device: cuda
# Using device: cuda
# Epoch 000 | Val Loss 0.27205
# Epoch 001 | Val Loss 0.11161
# Epoch 002 | Val Loss 0.10203
# Epoch 003 | Val Loss 0.07272
# Epoch 004 | Val Loss 0.05293
# Epoch 005 | Val Loss 0.06594
# Epoch 006 | Val Loss 0.06277
# Epoch 007 | Val Loss 0.06533
# Epoch 008 | Val Loss 0.06265
# Epoch 009 | Val Loss 0.07808
# Epoch 010 | Val Loss 0.07100
# Epoch 011 | Val Loss 0.09635
# Epoch 012 | Val Loss 0.05939
# Epoch 013 | Val Loss 0.07123
# Epoch 014 | Val Loss 0.07315
# Epoch 015 | Val Loss 0.08544
# Epoch 016 | Val Loss 0.06971
# Epoch 017 | Val Loss 0.06269
# Epoch 018 | Val Loss 0.08025
# Epoch 019 | Val Loss 0.08580
# Epoch 020 | Val Loss 0.08865
# Epoch 021 | Val Loss 0.09080
# Epoch 022 | Val Loss 0.12909
# Epoch 023 | Val Loss 0.08037
# Epoch 024 | Val Loss 0.05969
# Epoch 025 | Val Loss 0.08157
# Epoch 026 | Val Loss 0.06494
# Epoch 027 | Val Loss 0.08475
# Epoch 028 | Val Loss 0.07781
# Epoch 029 | Val Loss 0.06747
# Epoch 030 | Val Loss 0.07335
# Epoch 031 | Val Loss 0.07038
# Epoch 032 | Val Loss 0.06223
# Epoch 033 | Val Loss 0.04620
# Epoch 034 | Val Loss 0.05114
# Epoch 035 | Val Loss 0.05412
# Epoch 036 | Val Loss 0.17381
# Epoch 037 | Val Loss 0.08904
# Epoch 038 | Val Loss 0.08441
# Epoch 039 | Val Loss 0.07534
# Epoch 040 | Val Loss 0.07550
# Epoch 041 | Val Loss 0.07092
# Epoch 042 | Val Loss 0.06281
# Epoch 043 | Val Loss 0.06391
# Epoch 044 | Val Loss 0.06225
# Epoch 045 | Val Loss 0.06331
# Epoch 046 | Val Loss 0.05825
# Epoch 047 | Val Loss 0.05816
# Epoch 048 | Val Loss 0.05532
# Epoch 049 | Val Loss 0.05623
# Epoch 050 | Val Loss 0.04878
# Epoch 051 | Val Loss 0.04795
# Epoch 052 | Val Loss 0.04454
# Epoch 053 | Val Loss 0.04380
# Epoch 054 | Val Loss 0.05237
# Epoch 055 | Val Loss 0.04231
# Epoch 056 | Val Loss 0.04138
# Epoch 057 | Val Loss 0.03760
# Epoch 058 | Val Loss 0.03372
# Epoch 059 | Val Loss 0.15788
# Epoch 060 | Val Loss 0.07783
# Epoch 061 | Val Loss 0.05688
# Epoch 062 | Val Loss 0.03887
# Epoch 063 | Val Loss 0.04761
# Epoch 064 | Val Loss 0.04621
# Epoch 065 | Val Loss 0.04414
# Epoch 066 | Val Loss 0.03605
# Epoch 067 | Val Loss 0.03204
# Epoch 068 | Val Loss 0.02994
# Epoch 069 | Val Loss 0.03236
# Epoch 070 | Val Loss 0.14776
# Epoch 071 | Val Loss 0.05555
# Epoch 072 | Val Loss 0.04361
# Epoch 073 | Val Loss 0.02876
# Epoch 074 | Val Loss 0.02761
# Epoch 075 | Val Loss 0.02886
# Epoch 076 | Val Loss 0.02837
# Epoch 077 | Val Loss 0.02815
# Epoch 078 | Val Loss 0.02890
# Epoch 079 | Val Loss 0.03243
# Epoch 080 | Val Loss 0.02873
# Epoch 081 | Val Loss 0.02577
# Epoch 082 | Val Loss 0.02289
# Epoch 083 | Val Loss 0.01601
# Epoch 084 | Val Loss 0.01855
# Epoch 085 | Val Loss 0.02387
# Epoch 086 | Val Loss 0.02256
# Epoch 087 | Val Loss 0.02144
# Epoch 088 | Val Loss 0.02355
# Epoch 089 | Val Loss 0.02029
# Epoch 090 | Val Loss 0.02198
# Epoch 091 | Val Loss 0.03075
# Epoch 092 | Val Loss 0.04149
# Epoch 093 | Val Loss 0.02396
# Epoch 094 | Val Loss 0.03067
# Epoch 095 | Val Loss 0.01886
# Epoch 096 | Val Loss 0.02281
# Epoch 097 | Val Loss 0.02177
# Epoch 098 | Val Loss 0.04525
# Epoch 099 | Val Loss 0.02414
# Epoch 100 | Val Loss 0.02302
# Epoch 101 | Val Loss 0.01599
# Epoch 102 | Val Loss 0.01687
# Epoch 103 | Val Loss 0.01525
# Epoch 104 | Val Loss 0.01867
# Epoch 105 | Val Loss 0.01895
# Epoch 106 | Val Loss 0.02047
# Epoch 107 | Val Loss 0.01617
# Epoch 108 | Val Loss 0.02167
# Epoch 109 | Val Loss 0.01682
# Epoch 110 | Val Loss 0.02295
# Epoch 111 | Val Loss 0.02722
# Epoch 112 | Val Loss 0.03096
# Epoch 113 | Val Loss 0.04033
# Epoch 114 | Val Loss 0.02550
# Epoch 115 | Val Loss 0.01706
# Epoch 116 | Val Loss 0.01950
# Epoch 117 | Val Loss 0.01761
# Epoch 118 | Val Loss 0.01824
# Epoch 119 | Val Loss 0.01603
# Epoch 120 | Val Loss 0.01763
# Epoch 121 | Val Loss 0.01910
# Epoch 122 | Val Loss 0.01808
# Epoch 123 | Val Loss 0.02452
# Epoch 124 | Val Loss 0.02264
# Epoch 125 | Val Loss 0.04370
# Epoch 126 | Val Loss 0.05206
# Epoch 127 | Val Loss 0.04974
# Epoch 128 | Val Loss 0.05511
# Epoch 129 | Val Loss 0.03293
# Epoch 130 | Val Loss 0.03032
# Epoch 131 | Val Loss 0.03441
# Epoch 132 | Val Loss 0.02520
# Epoch 133 | Val Loss 0.02018
#
# Total training time: 12.12s
# CPU RAM: 1446.79 MB
# Inference time per trajectory: 0.002496s
# RMSE: 0.12409033726889261
# R²: 0.7827425411331754
# Prediction horizon at threshold 0.05: 0 steps
#
# ========================================
# FINAL MODEL METRICS
# ========================================
# RMSE:                       0.124090
# R²:                         0.782743
# F-statistic:                354.879141
# p-value:                    1.110223e-16
# Pearson correlation:        0.900617
# Spearman correlation:       0.887511
# Spectral cosine similarity: 0.991774
# Peak CPU RAM:               1446.79 MB
# ========================================

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, random_split
import time
import random

import psutil
import os
from scipy.stats import f as f_dist
from scipy.stats import pearsonr, spearmanr
from scipy.signal import welch
from numpy.linalg import norm

# --- 1. Fix Python, NumPy, and random seeds ---
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# --- 2. Force deterministic behavior for cuDNN ---
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# --- Use GPU if available ---
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# --- Mackey-Glass Generator ---
def mackey_glass(t_max, tau=17, delta_t=1, beta=0.2, gamma=0.1, n=10, x0=1.2):
    t_len = int(t_max / delta_t)
    x = np.zeros(t_len)
    x[0] = x0
    for t in range(1, t_len):
        if t - tau >= 0:
            x[t] = x[t - 1] + delta_t * (
                beta * x[t - tau] / (1 + x[t - tau] ** n) - gamma * x[t - 1]
            )
        else:
            x[t] = x[t - 1] - delta_t * gamma * x[t - 1]
    return x

# --- Function to insert anomalies ---
def insert_anomalies(x, anomaly_rate=0.05, anomaly_scale=0.5):
    x_anom = x.copy()
    n_points = len(x)
    n_anomalies = int(n_points * anomaly_rate)
    anomaly_indices = np.random.choice(n_points, size=n_anomalies, replace=False)
    for idx in anomaly_indices:
        x_anom[idx] += np.random.uniform(-anomaly_scale, anomaly_scale)
    return x_anom
# ============================================================
# CPU RAM Tracking
# ============================================================

process = psutil.Process(os.getpid())
cpu_ram_log = []

def get_cpu_ram_mb():
    return process.memory_info().rss / (1024 ** 2)

# --- Parameters ---
t_max = 200
delta_t = 1
train_ics_left = np.linspace(0, 1.17, 15)
train_ics_right = np.linspace(1.23, 3, 15)
train_ics = np.concatenate((train_ics_left, train_ics_right))
test_ic = 1.6
timesteps = np.arange(0, t_max, delta_t)

# --- Generate training data ---
X_list, y_list = [], []
anomalous_indices = [15, 5, 23, 7, 18]

for i, ic in enumerate(train_ics):
    x = mackey_glass(t_max=t_max, x0=ic)
    if i in anomalous_indices:
        x = insert_anomalies(x, anomaly_rate=0.1, anomaly_scale=0.7)
    norm_t = timesteps / t_max
    features = np.stack([np.full_like(norm_t, ic), norm_t], axis=1)
    X_list.append(features)
    y_list.append(x)

X = np.vstack(X_list)
y = np.concatenate(y_list)

# --- Plot trajectories (optional) ---
import math
n_traj = len(y_list)
n_cols = 5
n_rows = math.ceil(n_traj / n_cols)
plt.figure(figsize=(n_cols*3, n_rows*2.5))
for i, x in enumerate(y_list):
    plt.subplot(n_rows, n_cols, i+1)
    if i in anomalous_indices:
        plt.plot(x, 'r--')
        plt.gca().set_facecolor("#ffeeee")
    else:
        plt.plot(x, 'b-')
    plt.title(f"IC={train_ics[i]:.2f}")
    plt.xticks([]); plt.yticks([])
plt.tight_layout(); plt.show()

# --- Generate test data ---
x_test = mackey_glass(t_max=200, x0=test_ic)
norm_t_test = timesteps / t_max
X_test = np.stack([np.full_like(norm_t_test, test_ic), norm_t_test], axis=1)
y_test = x_test

# --- Normalize features ---
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_test_scaled = scaler.transform(X_test)

# --- Prepare torch datasets ---
X_tensor = torch.tensor(X_scaled, dtype=torch.float32).reshape(len(train_ics), t_max, 2)
y_tensor = torch.tensor(y, dtype=torch.float32).reshape(len(train_ics), t_max)
X_test_tensor = torch.tensor(X_test_scaled, dtype=torch.float32).unsqueeze(0).to(device)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(0).to(device)

# --- Split into train and val ---
val_split = 1
train_len = len(train_ics) - val_split
train_dataset, val_dataset = random_split(TensorDataset(X_tensor, y_tensor), [train_len, val_split])
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=4)

# ============================================================
# Imports
# ============================================================
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset, random_split
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
import time
import psutil
import os
import random

# ============================================================
# Reproducibility
# ============================================================
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# ============================================================
# Device
# ============================================================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# ============================================================
# Mackey–Glass Generator
# ============================================================
def mackey_glass(t_max, tau=17, delta_t=1, beta=0.2, gamma=0.1, n=10, x0=1.2):
    t_len = int(t_max / delta_t)
    x = np.zeros(t_len)
    x[0] = x0
    for t in range(1, t_len):
        if t - tau >= 0:
            x[t] = x[t - 1] + delta_t * (
                beta * x[t - tau] / (1 + x[t - tau] ** n) - gamma * x[t - 1]
            )
        else:
            x[t] = x[t - 1] - delta_t * gamma * x[t - 1]
    return x

# ============================================================
# Dataset
# ============================================================
t_max = 200
delta_t = 1
timesteps = np.arange(0, t_max, delta_t)

train_ics = np.concatenate([
    np.linspace(0, 1.17, 15),
    np.linspace(1.23, 3, 15)
])

X_list, y_list = [], []
for ic in train_ics:
    traj = mackey_glass(t_max=t_max, x0=ic)
    norm_t = timesteps / t_max
    X_list.append(np.stack([np.full_like(norm_t, ic), norm_t], axis=1))
    y_list.append(traj)

X = np.vstack(X_list)
y = np.concatenate(y_list)

# Test
x_test = mackey_glass(t_max=t_max, x0=test_ic)
X_test = np.stack([np.full_like(timesteps, test_ic), timesteps / t_max], axis=1)

# ============================================================
# Normalize
# ============================================================
scaler = StandardScaler()
X = scaler.fit_transform(X)
X_test = scaler.transform(X_test)

X_tensor = torch.tensor(X, dtype=torch.float32).reshape(len(train_ics), t_max, 2)
y_tensor = torch.tensor(y, dtype=torch.float32).reshape(len(train_ics), t_max)

X_test_tensor = torch.tensor(X_test, dtype=torch.float32).unsqueeze(0).to(device)
y_test = x_test

# ============================================================
# DataLoaders
# ============================================================
dataset = TensorDataset(X_tensor, y_tensor)
train_ds, val_ds = random_split(dataset, [len(dataset)-1, 1])

train_loader = DataLoader(train_ds, batch_size=4, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=4)

# ============================================================
# FNO Components
# ============================================================
class SpectralConv1d(nn.Module):
    def __init__(self, in_channels, out_channels, modes):
        super().__init__()
        self.modes = modes
        self.scale = 1 / (in_channels * out_channels)
        self.weights_real = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, modes))
        self.weights_imag = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, modes))

    def forward(self, x):
        x_ft = torch.fft.rfft(x, dim=-1)
        modes = min(self.modes, x_ft.size(-1))
        out_ft = torch.einsum(
            "bcm,com->bom",
            x_ft[:, :, :modes],
            torch.complex(self.weights_real[:, :, :modes], self.weights_imag[:, :, :modes])
        )
        out_ft_full = torch.zeros(x.size(0), out_ft.size(1), x_ft.size(-1),
                                  dtype=torch.cfloat, device=x.device)
        out_ft_full[:, :, :modes] = out_ft
        return torch.fft.irfft(out_ft_full, n=x.size(-1), dim=-1)

class FNO1d(nn.Module):
    def __init__(self, modes=16, width=64):
        super().__init__()
        self.fc0 = nn.Linear(2, width)

        self.convs = nn.ModuleList([SpectralConv1d(width, width, modes) for _ in range(4)])
        self.ws = nn.ModuleList([nn.Conv1d(width, width, 1) for _ in range(4)])

        self.fc1 = nn.Linear(width, 128)
        self.fc2 = nn.Linear(128, 1)

    def forward(self, x):
        x = self.fc0(x).permute(0, 2, 1)
        for conv, w in zip(self.convs, self.ws):
            x = F.gelu(conv(x) + w(x))
        x = x.permute(0, 2, 1)
        return self.fc2(F.gelu(self.fc1(x))).squeeze(-1)

# ============================================================
# Instantiate
# ============================================================
model = FNO1d().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.MSELoss()

# ============================================================
# Resource Tracking
# ============================================================
def cpu_mem():
    return psutil.Process(os.getpid()).memory_info().rss / 1024**2

def gpu_mem():
    if torch.cuda.is_available():
        return torch.cuda.max_memory_allocated() / 1024**2
    return None

epoch_times, cpu_mem_log, gpu_mem_log = [], [], []

# ============================================================
# Training
# ============================================================
epochs = 200
best_val = float("inf")
patience, wait = 30, 0

start_train = time.time()
for ep in range(epochs):
    ep_start = time.time()
    model.train()

    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        loss = criterion(model(xb), yb)
        loss.backward()
        optimizer.step()

    model.eval()
    with torch.no_grad():
        val_loss = sum(criterion(model(xv.to(device)), yv.to(device)).item()
                       for xv, yv in val_loader)

    epoch_times.append(time.time() - ep_start)
    cpu_mem_log.append(cpu_mem())
    if torch.cuda.is_available():
        torch.cuda.synchronize()
        gpu_mem_log.append(gpu_mem())

    print(f"Epoch {ep:03d} | Val Loss {val_loss:.5f}")

    if val_loss < best_val:
        best_val = val_loss
        best_state = model.state_dict()
        wait = 0
    else:
        wait += 1
        if wait >= patience:
            break

total_train_time = time.time() - start_train
print(f"\nTotal training time: {total_train_time:.2f}s")

# ============================================================
# CPU RAM Usage
# ============================================================
process = psutil.Process(os.getpid())

# Current CPU RAM usage
cpu_ram_mb = process.memory_info().rss / (1024 ** 2)

print(f"CPU RAM: {cpu_ram_mb:.2f} MB")

# ============================================================
# Inference Timing
# ============================================================
model.load_state_dict(best_state)
model.eval()

with torch.no_grad():
    t0 = time.time()
    for _ in range(50):
        _ = model(X_test_tensor)
    infer_time = (time.time() - t0) / 50

print(f"Inference time per trajectory: {infer_time:.6f}s")

# ============================================================
# Evaluation
# ============================================================
with torch.no_grad():
    pred = model(X_test_tensor).cpu().numpy().flatten()

print("RMSE:", np.sqrt(mean_squared_error(y_test, pred)))
print("R²:", r2_score(y_test, pred))

# ============================================================
# Plots
# ============================================================
plt.figure()
plt.plot(epoch_times)
plt.title("FNO Epoch Time")
plt.xlabel("Epoch")
plt.ylabel("Seconds")
plt.grid()
plt.show()

plt.figure()
plt.plot(cpu_mem_log, label="CPU MB")
if gpu_mem_log:
    plt.plot(gpu_mem_log, label="GPU MB")
plt.legend()
plt.title("Memory Usage")
plt.grid()
plt.show()

plt.figure()
plt.plot(y_test, label="True")
plt.plot(pred, '--', label="FNO")
plt.legend()
plt.title("FNO Prediction on Unseen IC")
plt.grid()
plt.show()

# Divergence
errors = np.abs(pred - y_test)            # abs error
rmse_window = np.sqrt((pred - y_test)**2) # RMSE error

# Optional: smooth with moving average for clarity
def moving_avg(x, w=10):
    return np.convolve(x, np.ones(w)/w, mode='valid')

window_size = 10
smoothed_error = moving_avg(errors, w=window_size)
smoothed_rmse = moving_avg(rmse_window, w=window_size)

# Plot
plt.figure(figsize=(10, 4))
plt.plot(smoothed_error, label="Abs Error (Smoothed)", alpha=0.8)
plt.plot(smoothed_rmse, label="RMSE (Smoothed)", alpha=0.8)
plt.axhline(y=0.05, color='r', linestyle='--', label='Error Threshold (0.05)')
plt.title("Prediction Divergence Over Time")
plt.xlabel("Time Step")
plt.ylabel("Prediction Error")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

threshold = 0.05
divergence_time = np.argmax(smoothed_error > threshold)
print(f"Prediction horizon at threshold {threshold}: {divergence_time} steps")
# ============================================================
# FINAL METRICS
# ============================================================

# RMSE
rmse = np.sqrt(mean_squared_error(y_test, pred))

# R²
r2 = r2_score(y_test, pred)

# ------------------------------------------------------------
# F-statistic and p-value
# ------------------------------------------------------------
n = len(y_test)
k = X_test.shape[1]

F_stat = (r2 / k) / ((1 - r2) / (n - k - 1))
p_value = 1 - f_dist.cdf(F_stat, k, n - k - 1)

# ------------------------------------------------------------
# Pearson and Spearman correlations
# ------------------------------------------------------------
pearson_corr, _ = pearsonr(y_test, pred)
spearman_corr, _ = spearmanr(y_test, pred)

# ------------------------------------------------------------
# Spectral cosine similarity
# ------------------------------------------------------------
def spectral_similarity(y_true, y_pred, fs=1.0):
    # Welch’s method for power spectral density (PSD)
    f_true, Pxx_true = welch(y_true, fs=fs, nperseg=128)
    f_pred, Pxx_pred = welch(y_pred, fs=fs, nperseg=128)

    # Normalize
    Pxx_true /= np.sum(Pxx_true)
    Pxx_pred /= np.sum(Pxx_pred)

    # Cosine similarity
    cosine_sim = np.dot(Pxx_true, Pxx_pred) / (norm(Pxx_true) * norm(Pxx_pred))
    return cosine_sim, f_true, Pxx_true, Pxx_pred


cos_sim, f, spec_true, spec_pred = spectral_similarity(
    y_test,
    pred
)

# ------------------------------------------------------------
# Peak CPU RAM
# ------------------------------------------------------------
peak_cpu_ram = max(cpu_mem_log)

# ------------------------------------------------------------
# Print all metrics
# ------------------------------------------------------------
print("\n========================================")
print("FINAL MODEL METRICS")
print("========================================")
print(f"RMSE:                       {rmse:.6f}")
print(f"R²:                         {r2:.6f}")
print(f"F-statistic:                {F_stat:.6f}")
print(f"p-value:                    {p_value:.6e}")
print(f"Pearson correlation:        {pearson_corr:.6f}")
print(f"Spearman correlation:       {spearman_corr:.6f}")
print(f"Spectral cosine similarity: {cos_sim:.6f}")
print(f"Peak CPU RAM:               {peak_cpu_ram:.2f} MB")
print("========================================")
# Out:
# Using device: cuda
# Using device: cuda
# Epoch 000 | Val Loss 0.27205
# Epoch 001 | Val Loss 0.11161
# Epoch 002 | Val Loss 0.10203
# Epoch 003 | Val Loss 0.07272
# Epoch 004 | Val Loss 0.05293
# Epoch 005 | Val Loss 0.06594
# Epoch 006 | Val Loss 0.06277
# Epoch 007 | Val Loss 0.06533
# Epoch 008 | Val Loss 0.06265
# Epoch 009 | Val Loss 0.07808
# Epoch 010 | Val Loss 0.07100
# Epoch 011 | Val Loss 0.09635
# Epoch 012 | Val Loss 0.05939
# Epoch 013 | Val Loss 0.07123
# Epoch 014 | Val Loss 0.07315
# Epoch 015 | Val Loss 0.08544
# Epoch 016 | Val Loss 0.06971
# Epoch 017 | Val Loss 0.06269
# Epoch 018 | Val Loss 0.08025
# Epoch 019 | Val Loss 0.08580
# Epoch 020 | Val Loss 0.08865
# Epoch 021 | Val Loss 0.09080
# Epoch 022 | Val Loss 0.12909
# Epoch 023 | Val Loss 0.08037
# Epoch 024 | Val Loss 0.05969
# Epoch 025 | Val Loss 0.08157
# Epoch 026 | Val Loss 0.06494
# Epoch 027 | Val Loss 0.08475
# Epoch 028 | Val Loss 0.07781
# Epoch 029 | Val Loss 0.06747
# Epoch 030 | Val Loss 0.07335
# Epoch 031 | Val Loss 0.07038
# Epoch 032 | Val Loss 0.06223
# Epoch 033 | Val Loss 0.04620
# Epoch 034 | Val Loss 0.05114
# Epoch 035 | Val Loss 0.05412
# Epoch 036 | Val Loss 0.17381
# Epoch 037 | Val Loss 0.08904
# Epoch 038 | Val Loss 0.08441
# Epoch 039 | Val Loss 0.07534
# Epoch 040 | Val Loss 0.07550
# Epoch 041 | Val Loss 0.07092
# Epoch 042 | Val Loss 0.06281
# Epoch 043 | Val Loss 0.06391
# Epoch 044 | Val Loss 0.06225
# Epoch 045 | Val Loss 0.06331
# Epoch 046 | Val Loss 0.05825
# Epoch 047 | Val Loss 0.05816
# Epoch 048 | Val Loss 0.05532
# Epoch 049 | Val Loss 0.05623
# Epoch 050 | Val Loss 0.04878
# Epoch 051 | Val Loss 0.04795
# Epoch 052 | Val Loss 0.04454
# Epoch 053 | Val Loss 0.04380
# Epoch 054 | Val Loss 0.05237
# Epoch 055 | Val Loss 0.04231
# Epoch 056 | Val Loss 0.04138
# Epoch 057 | Val Loss 0.03760
# Epoch 058 | Val Loss 0.03372
# Epoch 059 | Val Loss 0.15788
# Epoch 060 | Val Loss 0.07783
# Epoch 061 | Val Loss 0.05688
# Epoch 062 | Val Loss 0.03887
# Epoch 063 | Val Loss 0.04761
# Epoch 064 | Val Loss 0.04621
# Epoch 065 | Val Loss 0.04414
# Epoch 066 | Val Loss 0.03605
# Epoch 067 | Val Loss 0.03204
# Epoch 068 | Val Loss 0.02994
# Epoch 069 | Val Loss 0.03236
# Epoch 070 | Val Loss 0.14776
# Epoch 071 | Val Loss 0.05555
# Epoch 072 | Val Loss 0.04361
# Epoch 073 | Val Loss 0.02876
# Epoch 074 | Val Loss 0.02761
# Epoch 075 | Val Loss 0.02886
# Epoch 076 | Val Loss 0.02837
# Epoch 077 | Val Loss 0.02815
# Epoch 078 | Val Loss 0.02890
# Epoch 079 | Val Loss 0.03243
# Epoch 080 | Val Loss 0.02873
# Epoch 081 | Val Loss 0.02577
# Epoch 082 | Val Loss 0.02289
# Epoch 083 | Val Loss 0.01601
# Epoch 084 | Val Loss 0.01855
# Epoch 085 | Val Loss 0.02387
# Epoch 086 | Val Loss 0.02256
# Epoch 087 | Val Loss 0.02144
# Epoch 088 | Val Loss 0.02355
# Epoch 089 | Val Loss 0.02029
# Epoch 090 | Val Loss 0.02198
# Epoch 091 | Val Loss 0.03075
# Epoch 092 | Val Loss 0.04149
# Epoch 093 | Val Loss 0.02396
# Epoch 094 | Val Loss 0.03067
# Epoch 095 | Val Loss 0.01886
# Epoch 096 | Val Loss 0.02281
# Epoch 097 | Val Loss 0.02177
# Epoch 098 | Val Loss 0.04525
# Epoch 099 | Val Loss 0.02414
# Epoch 100 | Val Loss 0.02302
# Epoch 101 | Val Loss 0.01599
# Epoch 102 | Val Loss 0.01687
# Epoch 103 | Val Loss 0.01525
# Epoch 104 | Val Loss 0.01867
# Epoch 105 | Val Loss 0.01895
# Epoch 106 | Val Loss 0.02047
# Epoch 107 | Val Loss 0.01617
# Epoch 108 | Val Loss 0.02167
# Epoch 109 | Val Loss 0.01682
# Epoch 110 | Val Loss 0.02295
# Epoch 111 | Val Loss 0.02722
# Epoch 112 | Val Loss 0.03096
# Epoch 113 | Val Loss 0.04033
# Epoch 114 | Val Loss 0.02550
# Epoch 115 | Val Loss 0.01706
# Epoch 116 | Val Loss 0.01950
# Epoch 117 | Val Loss 0.01761
# Epoch 118 | Val Loss 0.01824
# Epoch 119 | Val Loss 0.01603
# Epoch 120 | Val Loss 0.01763
# Epoch 121 | Val Loss 0.01910
# Epoch 122 | Val Loss 0.01808
# Epoch 123 | Val Loss 0.02452
# Epoch 124 | Val Loss 0.02264
# Epoch 125 | Val Loss 0.04370
# Epoch 126 | Val Loss 0.05206
# Epoch 127 | Val Loss 0.04974
# Epoch 128 | Val Loss 0.05511
# Epoch 129 | Val Loss 0.03293
# Epoch 130 | Val Loss 0.03032
# Epoch 131 | Val Loss 0.03441
# Epoch 132 | Val Loss 0.02520
# Epoch 133 | Val Loss 0.02018
#
# Total training time: 8.73s
# CPU RAM: 1455.27 MB
# Inference time per trajectory: 0.001873s
# RMSE: 0.21785935383715857
# R²: 0.36285749867773165
# Prediction horizon at threshold 0.05: 0 steps
#
# ========================================
# FINAL MODEL METRICS
# ========================================
# RMSE:                       0.217859
# R²:                         0.362857
# F-statistic:                56.096499
# p-value:                    1.110223e-16
# Pearson correlation:        0.682741
# Spearman correlation:       0.667046
# Spectral cosine similarity: 0.979253
# Peak CPU RAM:               1455.27 MB
# ========================================
