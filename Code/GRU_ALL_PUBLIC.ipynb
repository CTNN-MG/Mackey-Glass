# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from scipy.stats import f as f_dist
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import random
import time

import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, random_split
import time
import torch
import numpy as np
import random

# --- 1. Fix Python, NumPy, and random seeds ---
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# --- 2. Force deterministic behavior for cuDNN ---
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# --- Use GPU if available ---
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)


# --- Mackey-Glass Generator ---
def mackey_glass(t_max, tau=17, delta_t=1, beta=0.2, gamma=0.1, n=10, x0=0.8):
    t_len = int(t_max / delta_t)
    x = np.zeros(t_len)
    x[0] = x0
    for t in range(1, t_len):
        if t - tau >= 0:
            x[t] = x[t - 1] + delta_t * (
                beta * x[t - tau] / (1 + x[t - tau] ** n) - gamma * x[t - 1]
            )
        else:
            x[t] = x[t - 1] - delta_t * gamma * x[t - 1]
    return x
# --- Function to insert anomalies ---
def insert_anomalies(x, anomaly_rate=0.05, anomaly_scale=0.5):
    """
    Insert anomalies into a time series.
    anomaly_rate: fraction of points that are anomalous
    anomaly_scale: magnitude of anomalies
    """
    x_anom = x.copy()
    n_points = len(x)
    n_anomalies = int(n_points * anomaly_rate)

    anomaly_indices = np.random.choice(n_points, size=n_anomalies, replace=False)
    for idx in anomaly_indices:
        x_anom[idx] += np.random.uniform(-anomaly_scale, anomaly_scale)
    return x_anom

# --- Parameters ---
t_max = 200
delta_t = 1
train_ics_left = np.linspace(0, 1.17, 15)
train_ics_right = np.linspace(1.23, 3, 15)
train_ics = np.concatenate((train_ics_left, train_ics_right))
test_ic = 0.8
timesteps = np.arange(0, t_max, delta_t)

# --- Generate training data (with anomalies on 5 sequences) ---
X_list, y_list = [], []
rng = np.random.default_rng()  # independent generator (no fixed seed)
anomalous_indices = [15, 5, 23, 7, 18]

for i, ic in enumerate(train_ics):
    x = mackey_glass(t_max=t_max, x0=ic)
    if i in anomalous_indices:
        x = insert_anomalies(x, anomaly_rate=0.1, anomaly_scale=0.7)  # insert anomalies
    norm_t = timesteps / t_max
    features = np.stack([np.full_like(norm_t, ic), norm_t], axis=1)
    X_list.append(features)
    y_list.append(x)

X = np.vstack(X_list)
y = np.concatenate(y_list)

import math

# Number of rows and columns for subplot grid
n_traj = len(y_list)
n_cols = 5  # you can change this
n_rows = math.ceil(n_traj / n_cols)

plt.figure(figsize=(n_cols*3, n_rows*2.5))

for i, x in enumerate(y_list):
    plt.subplot(n_rows, n_cols, i+1)
    if i in anomalous_indices:
        plt.plot(x, 'r--', label=f"IC={train_ics[i]:.2f} (Anomalous)")
    else:
        plt.plot(x, 'b-', label=f"IC={train_ics[i]:.2f}")
    plt.title(f"IC={train_ics[i]:.2f}")
    plt.xticks([])
    plt.yticks([])
    if i in anomalous_indices:
        plt.gca().set_facecolor("#ffeeee")  # light red background for anomalies

plt.tight_layout()
plt.show()




# --- Generate test data ---
x_test = mackey_glass(t_max=200, x0=test_ic)
norm_t_test = timesteps / t_max
X_test = np.stack([np.full_like(norm_t_test, test_ic), norm_t_test], axis=1)
y_test = x_test

# --- Normalize features ---
X_scaler = StandardScaler()
X_scaled = X_scaler.fit_transform(X)
X_test_scaled = X_scaler.transform(X_test)

# --- Normalize outputs ---
y_scaler = StandardScaler()
y_scaled = y_scaler.fit_transform(y.reshape(-1, 1)).flatten()
y_test_scaled = y_scaler.transform(y_test.reshape(-1, 1)).flatten()

# --- Prepare torch datasets ---
X_tensor = torch.tensor(
    X_scaled,
    dtype=torch.float32
).reshape(len(train_ics), t_max, 2)

y_tensor = torch.tensor(
    y_scaled,
    dtype=torch.float32
).reshape(len(train_ics), t_max)

X_test_tensor = torch.tensor(
    X_test_scaled,
    dtype=torch.float32
).unsqueeze(0).to(device)

y_test_tensor = torch.tensor(
    y_test_scaled,
    dtype=torch.float32
).unsqueeze(0).to(device)

# Split into train and validation (36 train, 4 val)
val_split = 1
train_len = len(train_ics) - val_split
train_dataset, val_dataset = random_split(TensorDataset(X_tensor, y_tensor), [train_len, val_split])
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=4)

# --- GRU Model ---
class GRUNet(nn.Module):
    def __init__(self, input_size=2, hidden_size=64, num_layers=3):
        super(GRUNet, self).__init__()
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True)
        self.linear = nn.Linear(hidden_size, 1)

    def forward(self, x):
        out, _ = self.gru(x)
        out = self.linear(out).squeeze(-1)
        return out


model = GRUNet().to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
# --- Early stopping params ---
best_val_loss = float('inf')
patience = 40
patience_counter = 0
best_model_state = None
# --- Train with validation tracking ---
train_losses = []
val_losses = []
start_time = time.time()
epochs = 200

# --- Train the model ---
epochs = 200
for epoch in range(epochs):
    model.train()
    total_loss = 0
    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        output = model(xb)
        loss = criterion(output, yb)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    # Validation loss
    if best_model_state is not None:
      model.load_state_dict(best_model_state)
    model.eval()
    with torch.no_grad():
        val_loss = 0
        for xb_val, yb_val in val_loader:
            xb_val, yb_val = xb_val.to(device), yb_val.to(device)
            val_output = model(xb_val)
            val_loss += criterion(val_output, yb_val).item()
        val_loss /= len(val_loader)
    train_losses.append(total_loss / len(train_loader))
    val_losses.append(val_loss)
    print(f"Epoch {epoch:03d}: Train Loss = {total_loss:.4f}, Val Loss = {val_loss:.4f}")

    # Check early stopping
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        best_model_state = model.state_dict()
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            break

# --- Plot Training vs Validation Loss ---
plt.figure(figsize=(8, 4))
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# --- Load best model ---
start_time = time.time()
# --- Predict on test IC ---
model.eval()
with torch.no_grad():
    pred_test_scaled = model(X_test_tensor).squeeze(0).cpu().numpy()

pred_test = y_scaler.inverse_transform(
    pred_test_scaled.reshape(-1, 1)
).flatten()

rmse = np.sqrt(mean_squared_error(y_test, pred_test))
r2 = r2_score(y_test, pred_test)
print(f"\nTest RMSE: {rmse:.4f}")
print(f"Test R²:   {r2:.4f}")
end_time = time.time()
# --- Plot results ---
plt.figure(figsize=(10, 5))
plt.plot(y_test, label='True')
plt.plot(pred_test, label='Predicted', linestyle='--')
plt.title(f"GRU Prediction on Unseen Initial Condition x₀ = {test_ic}")
plt.xlabel("Time Step")
plt.ylabel("x(t)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# --- F-statistic and p-value ---
n = len(y_test)
k = X_test.shape[1]  # number of predictors = 2
F_stat = (r2 / k) / ((1 - r2) / (n - k - 1))
p_value = 1 - f_dist.cdf(F_stat, k, n - k - 1)

print(f"F-statistic: {F_stat:.4f}")
print(f"P-value:     {p_value:.4e}")

print(f"Total Runtime: {end_time - start_time:.2f} seconds")

import numpy as np
import matplotlib.pyplot as plt

# Divergence
errors = np.abs(pred_test - y_test)            # abs error
rmse_window = np.sqrt((pred_test - y_test)**2) # RMSE error

# Optional: smooth with moving average for clarity
def moving_avg(x, w=10):
    return np.convolve(x, np.ones(w)/w, mode='valid')

window_size = 10
smoothed_error = moving_avg(errors, w=window_size)
smoothed_rmse = moving_avg(rmse_window, w=window_size)

# Plot
plt.figure(figsize=(10, 4))
plt.plot(smoothed_error, label="Abs Error (Smoothed)", alpha=0.8)
plt.plot(smoothed_rmse, label="RMSE (Smoothed)", alpha=0.8)
plt.axhline(y=0.05, color='r', linestyle='--', label='Error Threshold (0.05)')
plt.title("Prediction Divergence Over Time")
plt.xlabel("Time Step")
plt.ylabel("Prediction Error")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Divergence
errors = np.abs(pred_test - y_test)            # abs error
rmse_window = np.sqrt((pred_test - y_test)**2) # RMSE error

# Optional: smooth with moving average for clarity
def moving_avg(x, w=10):
    return np.convolve(x, np.ones(w)/w, mode='valid')

window_size = 10
smoothed_error = moving_avg(errors, w=window_size)
smoothed_rmse = moving_avg(rmse_window, w=window_size)

# Plot
plt.figure(figsize=(10, 4))
plt.plot(smoothed_error, label="Abs Error (Smoothed)", alpha=0.8)
plt.plot(smoothed_rmse, label="RMSE (Smoothed)", alpha=0.8)
plt.axhline(y=0.05, color='r', linestyle='--', label='Error Threshold (0.05)')
plt.title("Prediction Divergence Over Time")
plt.xlabel("Time Step")
plt.ylabel("Prediction Error")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

threshold = 0.05
divergence_time = np.argmax(smoothed_error > threshold)
print(f"Prediction horizon at threshold {threshold}: {divergence_time} steps")


print(f"Total runtime: {end_time - start_time:.2f} seconds")

from scipy.stats import pearsonr, spearmanr

def correlation_metrics(y_true, y_pred):
    pearson_corr, _ = pearsonr(y_true, y_pred)
    spearman_corr, _ = spearmanr(y_true, y_pred)
    return pearson_corr, spearman_corr

pearson_corr, spearman_corr = correlation_metrics(y_test, pred_test)
print(f"Pearson correlation: {pearson_corr:.4f}")
print(f"Spearman correlation: {spearman_corr:.4f}")

from scipy.signal import welch
from numpy.linalg import norm

def spectral_similarity(y_true, y_pred, fs=1.0):
    # Welch’s method for power spectral density (PSD)
    f_true, Pxx_true = welch(y_true, fs=fs, nperseg=128)
    f_pred, Pxx_pred = welch(y_pred, fs=fs, nperseg=128)

    # Normalize
    Pxx_true /= np.sum(Pxx_true)
    Pxx_pred /= np.sum(Pxx_pred)

    # Cosine similarity
    cosine_sim = np.dot(Pxx_true, Pxx_pred) / (norm(Pxx_true) * norm(Pxx_pred))
    return cosine_sim, f_true, Pxx_true, Pxx_pred

cos_sim, f, spec_true, spec_pred = spectral_similarity(y_test, pred_test)
print(f"Spectral cosine similarity: {cos_sim:.4f}")

# Plot spectra
plt.figure(figsize=(8,4))
plt.semilogy(f, spec_true, label="True PSD")
plt.semilogy(f, spec_pred, label="Predicted PSD")
plt.title("Power Spectrum Comparison")
plt.xlabel("Frequency")
plt.ylabel("Normalized Power")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Using device: cuda
# Epoch 000: Train Loss = 10.2550, Val Loss = 0.8442
# Epoch 001: Train Loss = 7.1122, Val Loss = 0.7455
# Epoch 002: Train Loss = 6.7379, Val Loss = 0.7764
# Epoch 003: Train Loss = 6.8080, Val Loss = 0.7638
# Epoch 004: Train Loss = 6.5619, Val Loss = 0.7426
# Epoch 005: Train Loss = 6.4259, Val Loss = 0.6347
# Epoch 006: Train Loss = 6.3872, Val Loss = 0.5787
# Epoch 007: Train Loss = 6.1255, Val Loss = 0.4915
# Epoch 008: Train Loss = 6.0301, Val Loss = 0.4715
# Epoch 009: Train Loss = 6.2974, Val Loss = 0.4209
# Epoch 010: Train Loss = 5.5428, Val Loss = 0.3955
# Epoch 011: Train Loss = 5.8854, Val Loss = 0.3804
# Epoch 012: Train Loss = 5.8540, Val Loss = 0.4070
# Epoch 013: Train Loss = 5.3682, Val Loss = 0.3572
# Epoch 014: Train Loss = 5.8549, Val Loss = 0.5042
# Epoch 015: Train Loss = 5.5088, Val Loss = 0.4274
# Epoch 016: Train Loss = 5.5167, Val Loss = 0.4475
# Epoch 017: Train Loss = 5.2449, Val Loss = 0.4538
# Epoch 018: Train Loss = 5.1754, Val Loss = 0.4490
# Epoch 019: Train Loss = 5.1969, Val Loss = 0.3649
# Epoch 020: Train Loss = 4.9134, Val Loss = 0.4463
# Epoch 021: Train Loss = 4.8583, Val Loss = 0.4086
# Epoch 022: Train Loss = 4.6849, Val Loss = 0.3925
# Epoch 023: Train Loss = 4.8684, Val Loss = 0.5607
# Epoch 024: Train Loss = 4.7584, Val Loss = 0.3250
# Epoch 025: Train Loss = 4.6537, Val Loss = 0.4270
# Epoch 026: Train Loss = 4.4547, Val Loss = 0.4991
# Epoch 027: Train Loss = 4.5620, Val Loss = 0.3124
# Epoch 028: Train Loss = 4.2519, Val Loss = 0.5505
# Epoch 029: Train Loss = 4.1671, Val Loss = 0.3845
# Epoch 030: Train Loss = 4.0238, Val Loss = 0.2964
# Epoch 031: Train Loss = 4.0708, Val Loss = 0.3461
# Epoch 032: Train Loss = 4.0525, Val Loss = 0.3342
# Epoch 033: Train Loss = 3.8623, Val Loss = 0.3132
# Epoch 034: Train Loss = 3.7220, Val Loss = 0.3107
# Epoch 035: Train Loss = 3.8064, Val Loss = 0.3456
# Epoch 036: Train Loss = 3.6068, Val Loss = 0.2638
# Epoch 037: Train Loss = 3.3970, Val Loss = 0.4394
# Epoch 038: Train Loss = 3.4627, Val Loss = 0.2606
# Epoch 039: Train Loss = 4.2081, Val Loss = 0.2473
# Epoch 040: Train Loss = 3.7045, Val Loss = 0.4564
# Epoch 041: Train Loss = 3.3180, Val Loss = 0.3032
# Epoch 042: Train Loss = 3.3980, Val Loss = 0.3109
# Epoch 043: Train Loss = 3.1469, Val Loss = 0.2896
# Epoch 044: Train Loss = 3.2174, Val Loss = 0.2806
# Epoch 045: Train Loss = 2.8606, Val Loss = 0.3535
# Epoch 046: Train Loss = 2.8191, Val Loss = 0.2507
# Epoch 047: Train Loss = 2.8620, Val Loss = 0.2305
# Epoch 048: Train Loss = 3.3018, Val Loss = 0.2354
# Epoch 049: Train Loss = 3.2146, Val Loss = 0.2756
# Epoch 050: Train Loss = 2.9138, Val Loss = 0.2383
# Epoch 051: Train Loss = 2.9659, Val Loss = 0.3417
# Epoch 052: Train Loss = 2.5939, Val Loss = 0.2738
# Epoch 053: Train Loss = 2.5266, Val Loss = 0.2969
# Epoch 054: Train Loss = 2.5255, Val Loss = 0.2300
# Epoch 055: Train Loss = 2.4666, Val Loss = 0.2357
# Epoch 056: Train Loss = 2.3504, Val Loss = 0.1726
# Epoch 057: Train Loss = 2.6410, Val Loss = 0.2271
# Epoch 058: Train Loss = 2.6421, Val Loss = 0.2041
# Epoch 059: Train Loss = 2.2342, Val Loss = 0.2299
# Epoch 060: Train Loss = 2.3131, Val Loss = 0.2610
# Epoch 061: Train Loss = 2.2143, Val Loss = 0.1750
# Epoch 062: Train Loss = 2.2561, Val Loss = 0.1793
# Epoch 063: Train Loss = 2.2618, Val Loss = 0.2677
# Epoch 064: Train Loss = 2.4354, Val Loss = 0.2427
# Epoch 065: Train Loss = 2.7569, Val Loss = 0.2335
# Epoch 066: Train Loss = 2.1359, Val Loss = 0.1707
# Epoch 067: Train Loss = 2.1369, Val Loss = 0.1508
# Epoch 068: Train Loss = 2.6557, Val Loss = 0.1547
# Epoch 069: Train Loss = 2.3058, Val Loss = 0.2670
# Epoch 070: Train Loss = 2.2990, Val Loss = 0.1404
# Epoch 071: Train Loss = 2.5477, Val Loss = 0.2004
# Epoch 072: Train Loss = 2.3933, Val Loss = 0.2055
# Epoch 073: Train Loss = 2.4653, Val Loss = 0.3554
# Epoch 074: Train Loss = 2.2824, Val Loss = 0.3019
# Epoch 075: Train Loss = 2.9938, Val Loss = 0.1356
# Epoch 076: Train Loss = 2.4889, Val Loss = 0.1918
# Epoch 077: Train Loss = 1.6633, Val Loss = 0.2152
# Epoch 078: Train Loss = 1.4992, Val Loss = 0.2042
# Epoch 079: Train Loss = 1.3819, Val Loss = 0.1531
# Epoch 080: Train Loss = 2.3456, Val Loss = 0.2112
# Epoch 081: Train Loss = 4.3181, Val Loss = 4.4637
# Epoch 082: Train Loss = 4.7672, Val Loss = 1.8190
# Epoch 083: Train Loss = 2.6376, Val Loss = 0.5573
# Epoch 084: Train Loss = 2.1205, Val Loss = 0.3075
# Epoch 085: Train Loss = 2.2672, Val Loss = 0.2518
# Epoch 086: Train Loss = 1.6126, Val Loss = 0.1689
# Epoch 087: Train Loss = 1.7625, Val Loss = 0.2835
# Epoch 088: Train Loss = 1.9762, Val Loss = 0.2880
# Epoch 089: Train Loss = 1.7684, Val Loss = 0.2086
# Epoch 090: Train Loss = 1.9381, Val Loss = 0.1960
# Epoch 091: Train Loss = 1.6785, Val Loss = 0.2512
# Epoch 092: Train Loss = 1.4799, Val Loss = 0.1648
# Epoch 093: Train Loss = 1.5254, Val Loss = 0.1928
# Epoch 094: Train Loss = 1.4028, Val Loss = 0.1874
# Epoch 095: Train Loss = 1.2160, Val Loss = 0.1746
# Epoch 096: Train Loss = 1.3741, Val Loss = 0.1196
# Epoch 097: Train Loss = 1.4659, Val Loss = 0.1842
# Epoch 098: Train Loss = 1.5926, Val Loss = 0.1165
# Epoch 099: Train Loss = 1.5546, Val Loss = 0.1376
# Epoch 100: Train Loss = 1.2784, Val Loss = 0.1050
# Epoch 101: Train Loss = 1.3392, Val Loss = 0.2722
# Epoch 102: Train Loss = 1.6165, Val Loss = 0.1063
# Epoch 103: Train Loss = 2.0457, Val Loss = 0.1085
# Epoch 104: Train Loss = 1.4203, Val Loss = 0.1667
# Epoch 105: Train Loss = 1.3377, Val Loss = 0.1533
# Epoch 106: Train Loss = 1.4888, Val Loss = 0.1262
# Epoch 107: Train Loss = 1.4761, Val Loss = 0.1267
# Epoch 108: Train Loss = 1.6752, Val Loss = 0.0835
# Epoch 109: Train Loss = 2.6287, Val Loss = 0.4800
# Epoch 110: Train Loss = 3.0044, Val Loss = 0.1798
# Epoch 111: Train Loss = 2.5852, Val Loss = 0.3009
# Epoch 112: Train Loss = 2.4299, Val Loss = 0.3101
# Epoch 113: Train Loss = 1.8131, Val Loss = 0.2513
# Epoch 114: Train Loss = 1.8262, Val Loss = 0.2322
# Epoch 115: Train Loss = 1.8251, Val Loss = 0.1718
# Epoch 116: Train Loss = 2.2024, Val Loss = 0.2247
# Epoch 117: Train Loss = 2.2200, Val Loss = 0.3767
# Epoch 118: Train Loss = 2.6615, Val Loss = 0.1549
# Epoch 119: Train Loss = 1.7191, Val Loss = 0.5341
# Epoch 120: Train Loss = 1.6833, Val Loss = 0.2153
# Epoch 121: Train Loss = 1.1198, Val Loss = 0.1796
# Epoch 122: Train Loss = 1.2235, Val Loss = 0.1489
# Epoch 123: Train Loss = 1.2763, Val Loss = 0.1322
# Epoch 124: Train Loss = 1.1074, Val Loss = 0.1112
# Epoch 125: Train Loss = 1.0432, Val Loss = 0.1075
# Epoch 126: Train Loss = 1.2174, Val Loss = 0.1099
# Epoch 127: Train Loss = 1.5559, Val Loss = 0.0999
# Epoch 128: Train Loss = 3.7289, Val Loss = 0.1105
# Epoch 129: Train Loss = 1.0494, Val Loss = 0.4128
# Epoch 130: Train Loss = 1.3405, Val Loss = 0.2494
# Epoch 131: Train Loss = 2.6250, Val Loss = 0.1446
# Epoch 132: Train Loss = 2.9386, Val Loss = 0.6050
# Epoch 133: Train Loss = 2.5776, Val Loss = 0.2491
# Epoch 134: Train Loss = 3.0108, Val Loss = 0.1735
# Epoch 135: Train Loss = 2.3142, Val Loss = 0.5310
# Epoch 136: Train Loss = 2.2222, Val Loss = 0.1711
# Epoch 137: Train Loss = 1.8676, Val Loss = 0.1140
# Epoch 138: Train Loss = 1.2903, Val Loss = 0.1406
# Epoch 139: Train Loss = 1.1686, Val Loss = 0.1299
# Epoch 140: Train Loss = 1.5547, Val Loss = 0.0854
# Epoch 141: Train Loss = 1.6873, Val Loss = 0.0701
# Epoch 142: Train Loss = 1.6480, Val Loss = 0.0781
# Epoch 143: Train Loss = 1.2260, Val Loss = 0.1621
# Epoch 144: Train Loss = 0.9051, Val Loss = 0.1526
# Epoch 145: Train Loss = 0.8755, Val Loss = 0.0698
# Epoch 146: Train Loss = 0.8214, Val Loss = 0.1112
# Epoch 147: Train Loss = 0.8570, Val Loss = 0.0758
# Epoch 148: Train Loss = 1.0206, Val Loss = 0.0879
# Epoch 149: Train Loss = 1.1129, Val Loss = 0.0669
# Epoch 150: Train Loss = 1.1892, Val Loss = 0.1047
# Epoch 151: Train Loss = 1.4651, Val Loss = 0.0749
# Epoch 152: Train Loss = 0.9071, Val Loss = 0.0690
# Epoch 153: Train Loss = 0.9391, Val Loss = 0.0603
# Epoch 154: Train Loss = 0.9919, Val Loss = 0.0717
# Epoch 155: Train Loss = 0.8624, Val Loss = 0.0521
# Epoch 156: Train Loss = 0.8515, Val Loss = 0.0865
# Epoch 157: Train Loss = 0.7338, Val Loss = 0.0459
# Epoch 158: Train Loss = 0.8069, Val Loss = 0.0580
# Epoch 159: Train Loss = 0.7287, Val Loss = 0.0963
# Epoch 160: Train Loss = 0.7635, Val Loss = 0.0537
# Epoch 161: Train Loss = 0.9480, Val Loss = 0.3020
# Epoch 162: Train Loss = 2.2542, Val Loss = 0.1488
# Epoch 163: Train Loss = 1.6586, Val Loss = 0.3436
# Epoch 164: Train Loss = 1.5726, Val Loss = 0.1200
# Epoch 165: Train Loss = 1.7182, Val Loss = 0.0982
# Epoch 166: Train Loss = 1.0942, Val Loss = 0.0767
# Epoch 167: Train Loss = 1.1173, Val Loss = 0.0733
# Epoch 168: Train Loss = 1.2820, Val Loss = 0.0865
# Epoch 169: Train Loss = 1.1172, Val Loss = 0.1092
# Epoch 170: Train Loss = 1.0388, Val Loss = 0.0691
# Epoch 171: Train Loss = 0.9109, Val Loss = 0.0607
# Epoch 172: Train Loss = 0.7460, Val Loss = 0.0704
# Epoch 173: Train Loss = 0.6843, Val Loss = 0.0725
# Epoch 174: Train Loss = 0.7330, Val Loss = 0.0589
# Epoch 175: Train Loss = 0.7315, Val Loss = 0.0972
# Epoch 176: Train Loss = 0.6437, Val Loss = 0.0500
# Epoch 177: Train Loss = 0.6606, Val Loss = 0.0648
# Epoch 178: Train Loss = 0.5452, Val Loss = 0.0541
# Epoch 179: Train Loss = 0.5485, Val Loss = 0.0640
# Epoch 180: Train Loss = 0.7405, Val Loss = 0.0825
# Epoch 181: Train Loss = 0.8349, Val Loss = 0.0497
# Epoch 182: Train Loss = 1.1569, Val Loss = 0.1560
# Epoch 183: Train Loss = 1.3530, Val Loss = 0.1326
# Epoch 184: Train Loss = 0.7842, Val Loss = 0.0560
# Epoch 185: Train Loss = 0.6611, Val Loss = 0.1074
# Epoch 186: Train Loss = 1.0302, Val Loss = 0.0525
# Epoch 187: Train Loss = 1.5411, Val Loss = 0.0527
# Epoch 188: Train Loss = 1.4989, Val Loss = 0.1696
# Epoch 189: Train Loss = 1.7398, Val Loss = 0.1096
# Epoch 190: Train Loss = 1.9005, Val Loss = 0.3896
# Epoch 191: Train Loss = 2.3867, Val Loss = 0.3058
# Epoch 192: Train Loss = 2.3218, Val Loss = 0.4273
# Epoch 193: Train Loss = 2.1568, Val Loss = 0.3174
# Epoch 194: Train Loss = 2.1669, Val Loss = 0.2544
# Epoch 195: Train Loss = 2.0701, Val Loss = 0.2749
# Epoch 196: Train Loss = 2.0226, Val Loss = 0.2138
# Epoch 197: Train Loss = 1.8819, Val Loss = 0.2106
# Early stopping at epoch 197
# Test RMSE: 0.1276
# Test R²:   0.7814
# F-statistic: 352.1110
# P-value:     1.1102e-16
# Total Runtime: 0.00 seconds
# Prediction horizon at threshold 0.05: 0 steps
# Total runtime: 0.00 seconds
# Pearson correlation: 0.9162
# Spearman correlation: 0.8885
# Spectral cosine similarity: 0.9993

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from scipy.stats import f as f_dist
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import random
import time

import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, random_split
import time
import torch
import numpy as np
import random

# --- 1. Fix Python, NumPy, and random seeds ---
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# --- 2. Force deterministic behavior for cuDNN ---
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# --- Use GPU if available ---
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)


# --- Mackey-Glass Generator ---
def mackey_glass(t_max, tau=17, delta_t=1, beta=0.2, gamma=0.1, n=10, x0=0.8):
    t_len = int(t_max / delta_t)
    x = np.zeros(t_len)
    x[0] = x0
    for t in range(1, t_len):
        if t - tau >= 0:
            x[t] = x[t - 1] + delta_t * (
                beta * x[t - tau] / (1 + x[t - tau] ** n) - gamma * x[t - 1]
            )
        else:
            x[t] = x[t - 1] - delta_t * gamma * x[t - 1]
    return x
# --- Function to insert anomalies ---
def insert_anomalies(x, anomaly_rate=0.05, anomaly_scale=0.5):
    """
    Insert anomalies into a time series.
    anomaly_rate: fraction of points that are anomalous
    anomaly_scale: magnitude of anomalies
    """
    x_anom = x.copy()
    n_points = len(x)
    n_anomalies = int(n_points * anomaly_rate)

    anomaly_indices = np.random.choice(n_points, size=n_anomalies, replace=False)
    for idx in anomaly_indices:
        x_anom[idx] += np.random.uniform(-anomaly_scale, anomaly_scale)
    return x_anom

# --- Parameters ---
t_max = 200
delta_t = 1
train_ics_left = np.linspace(0, 1.17, 15)
train_ics_right = np.linspace(1.23, 3, 15)
train_ics = np.concatenate((train_ics_left, train_ics_right))
test_ic = 1.2
timesteps = np.arange(0, t_max, delta_t)

# --- Generate training data (with anomalies on 5 sequences) ---
X_list, y_list = [], []
rng = np.random.default_rng()  # independent generator (no fixed seed)
anomalous_indices = [15, 5, 23, 7, 18]

for i, ic in enumerate(train_ics):
    x = mackey_glass(t_max=t_max, x0=ic)
    if i in anomalous_indices:
        x = insert_anomalies(x, anomaly_rate=0.1, anomaly_scale=0.7)  # insert anomalies
    norm_t = timesteps / t_max
    features = np.stack([np.full_like(norm_t, ic), norm_t], axis=1)
    X_list.append(features)
    y_list.append(x)

X = np.vstack(X_list)
y = np.concatenate(y_list)

import math

# Number of rows and columns for subplot grid
n_traj = len(y_list)
n_cols = 5  # you can change this
n_rows = math.ceil(n_traj / n_cols)

plt.figure(figsize=(n_cols*3, n_rows*2.5))

for i, x in enumerate(y_list):
    plt.subplot(n_rows, n_cols, i+1)
    if i in anomalous_indices:
        plt.plot(x, 'r--', label=f"IC={train_ics[i]:.2f} (Anomalous)")
    else:
        plt.plot(x, 'b-', label=f"IC={train_ics[i]:.2f}")
    plt.title(f"IC={train_ics[i]:.2f}")
    plt.xticks([])
    plt.yticks([])
    if i in anomalous_indices:
        plt.gca().set_facecolor("#ffeeee")  # light red background for anomalies

plt.tight_layout()
plt.show()




# --- Generate test data ---
x_test = mackey_glass(t_max=200, x0=test_ic)
norm_t_test = timesteps / t_max
X_test = np.stack([np.full_like(norm_t_test, test_ic), norm_t_test], axis=1)
y_test = x_test

# --- Normalize features ---
X_scaler = StandardScaler()
X_scaled = X_scaler.fit_transform(X)
X_test_scaled = X_scaler.transform(X_test)

# --- Normalize outputs ---
y_scaler = StandardScaler()
y_scaled = y_scaler.fit_transform(y.reshape(-1, 1)).flatten()
y_test_scaled = y_scaler.transform(y_test.reshape(-1, 1)).flatten()

# --- Prepare torch datasets ---
X_tensor = torch.tensor(
    X_scaled,
    dtype=torch.float32
).reshape(len(train_ics), t_max, 2)

y_tensor = torch.tensor(
    y_scaled,
    dtype=torch.float32
).reshape(len(train_ics), t_max)

X_test_tensor = torch.tensor(
    X_test_scaled,
    dtype=torch.float32
).unsqueeze(0).to(device)

y_test_tensor = torch.tensor(
    y_test_scaled,
    dtype=torch.float32
).unsqueeze(0).to(device)

# Split into train and validation (36 train, 4 val)
val_split = 1
train_len = len(train_ics) - val_split
train_dataset, val_dataset = random_split(TensorDataset(X_tensor, y_tensor), [train_len, val_split])
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=4)

# --- GRU Model ---
class GRUNet(nn.Module):
    def __init__(self, input_size=2, hidden_size=64, num_layers=3):
        super(GRUNet, self).__init__()
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True)
        self.linear = nn.Linear(hidden_size, 1)

    def forward(self, x):
        out, _ = self.gru(x)
        out = self.linear(out).squeeze(-1)
        return out


model = GRUNet().to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
# --- Early stopping params ---
best_val_loss = float('inf')
patience = 40
patience_counter = 0
best_model_state = None
# --- Train with validation tracking ---
train_losses = []
val_losses = []
start_time = time.time()
epochs = 200

# --- Train the model ---
epochs = 200
for epoch in range(epochs):
    model.train()
    total_loss = 0
    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        output = model(xb)
        loss = criterion(output, yb)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    # Validation loss
    if best_model_state is not None:
      model.load_state_dict(best_model_state)
    model.eval()
    with torch.no_grad():
        val_loss = 0
        for xb_val, yb_val in val_loader:
            xb_val, yb_val = xb_val.to(device), yb_val.to(device)
            val_output = model(xb_val)
            val_loss += criterion(val_output, yb_val).item()
        val_loss /= len(val_loader)
    train_losses.append(total_loss / len(train_loader))
    val_losses.append(val_loss)
    print(f"Epoch {epoch:03d}: Train Loss = {total_loss:.4f}, Val Loss = {val_loss:.4f}")

    # Check early stopping
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        best_model_state = model.state_dict()
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            break

# --- Plot Training vs Validation Loss ---
plt.figure(figsize=(8, 4))
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# --- Load best model ---
start_time = time.time()
# --- Predict on test IC ---
model.eval()
with torch.no_grad():
    pred_test_scaled = model(X_test_tensor).squeeze(0).cpu().numpy()

pred_test = y_scaler.inverse_transform(
    pred_test_scaled.reshape(-1, 1)
).flatten()

rmse = np.sqrt(mean_squared_error(y_test, pred_test))
r2 = r2_score(y_test, pred_test)
print(f"\nTest RMSE: {rmse:.4f}")
print(f"Test R²:   {r2:.4f}")
end_time = time.time()
# --- Plot results ---
plt.figure(figsize=(10, 5))
plt.plot(y_test, label='True')
plt.plot(pred_test, label='Predicted', linestyle='--')
plt.title(f"GRU Prediction on Unseen Initial Condition x₀ = {test_ic}")
plt.xlabel("Time Step")
plt.ylabel("x(t)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# --- F-statistic and p-value ---
n = len(y_test)
k = X_test.shape[1]  # number of predictors = 2
F_stat = (r2 / k) / ((1 - r2) / (n - k - 1))
p_value = 1 - f_dist.cdf(F_stat, k, n - k - 1)

print(f"F-statistic: {F_stat:.4f}")
print(f"P-value:     {p_value:.4e}")

print(f"Total Runtime: {end_time - start_time:.2f} seconds")

import numpy as np
import matplotlib.pyplot as plt

# Divergence
errors = np.abs(pred_test - y_test)            # abs error
rmse_window = np.sqrt((pred_test - y_test)**2) # RMSE error

# Optional: smooth with moving average for clarity
def moving_avg(x, w=10):
    return np.convolve(x, np.ones(w)/w, mode='valid')

window_size = 10
smoothed_error = moving_avg(errors, w=window_size)
smoothed_rmse = moving_avg(rmse_window, w=window_size)

# Plot
plt.figure(figsize=(10, 4))
plt.plot(smoothed_error, label="Abs Error (Smoothed)", alpha=0.8)
plt.plot(smoothed_rmse, label="RMSE (Smoothed)", alpha=0.8)
plt.axhline(y=0.05, color='r', linestyle='--', label='Error Threshold (0.05)')
plt.title("Prediction Divergence Over Time")
plt.xlabel("Time Step")
plt.ylabel("Prediction Error")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Divergence
errors = np.abs(pred_test - y_test)            # abs error
rmse_window = np.sqrt((pred_test - y_test)**2) # RMSE error

# Optional: smooth with moving average for clarity
def moving_avg(x, w=10):
    return np.convolve(x, np.ones(w)/w, mode='valid')

window_size = 10
smoothed_error = moving_avg(errors, w=window_size)
smoothed_rmse = moving_avg(rmse_window, w=window_size)

# Plot
plt.figure(figsize=(10, 4))
plt.plot(smoothed_error, label="Abs Error (Smoothed)", alpha=0.8)
plt.plot(smoothed_rmse, label="RMSE (Smoothed)", alpha=0.8)
plt.axhline(y=0.05, color='r', linestyle='--', label='Error Threshold (0.05)')
plt.title("Prediction Divergence Over Time")
plt.xlabel("Time Step")
plt.ylabel("Prediction Error")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

threshold = 0.05
divergence_time = np.argmax(smoothed_error > threshold)
print(f"Prediction horizon at threshold {threshold}: {divergence_time} steps")


print(f"Total runtime: {end_time - start_time:.2f} seconds")

from scipy.stats import pearsonr, spearmanr

def correlation_metrics(y_true, y_pred):
    pearson_corr, _ = pearsonr(y_true, y_pred)
    spearman_corr, _ = spearmanr(y_true, y_pred)
    return pearson_corr, spearman_corr

pearson_corr, spearman_corr = correlation_metrics(y_test, pred_test)
print(f"Pearson correlation: {pearson_corr:.4f}")
print(f"Spearman correlation: {spearman_corr:.4f}")

from scipy.signal import welch
from numpy.linalg import norm

def spectral_similarity(y_true, y_pred, fs=1.0):
    # Welch’s method for power spectral density (PSD)
    f_true, Pxx_true = welch(y_true, fs=fs, nperseg=128)
    f_pred, Pxx_pred = welch(y_pred, fs=fs, nperseg=128)

    # Normalize
    Pxx_true /= np.sum(Pxx_true)
    Pxx_pred /= np.sum(Pxx_pred)

    # Cosine similarity
    cosine_sim = np.dot(Pxx_true, Pxx_pred) / (norm(Pxx_true) * norm(Pxx_pred))
    return cosine_sim, f_true, Pxx_true, Pxx_pred

cos_sim, f, spec_true, spec_pred = spectral_similarity(y_test, pred_test)
print(f"Spectral cosine similarity: {cos_sim:.4f}")

# Plot spectra
plt.figure(figsize=(8,4))
plt.semilogy(f, spec_true, label="True PSD")
plt.semilogy(f, spec_pred, label="Predicted PSD")
plt.title("Power Spectrum Comparison")
plt.xlabel("Frequency")
plt.ylabel("Normalized Power")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Using device: cuda
# Epoch 000: Train Loss = 10.2550, Val Loss = 0.8442
# Epoch 001: Train Loss = 7.1122, Val Loss = 0.7455
# Epoch 002: Train Loss = 6.7379, Val Loss = 0.7764
# Epoch 003: Train Loss = 6.8080, Val Loss = 0.7638
# Epoch 004: Train Loss = 6.5619, Val Loss = 0.7426
# Epoch 005: Train Loss = 6.4259, Val Loss = 0.6347
# Epoch 006: Train Loss = 6.3872, Val Loss = 0.5787
# Epoch 007: Train Loss = 6.1255, Val Loss = 0.4915
# Epoch 008: Train Loss = 6.0301, Val Loss = 0.4715
# Epoch 009: Train Loss = 6.2974, Val Loss = 0.4209
# Epoch 010: Train Loss = 5.5428, Val Loss = 0.3955
# Epoch 011: Train Loss = 5.8854, Val Loss = 0.3804
# Epoch 012: Train Loss = 5.8540, Val Loss = 0.4070
# Epoch 013: Train Loss = 5.3682, Val Loss = 0.3572
# Epoch 014: Train Loss = 5.8549, Val Loss = 0.5042
# Epoch 015: Train Loss = 5.5088, Val Loss = 0.4274
# Epoch 016: Train Loss = 5.5167, Val Loss = 0.4475
# Epoch 017: Train Loss = 5.2449, Val Loss = 0.4538
# Epoch 018: Train Loss = 5.1754, Val Loss = 0.4490
# Epoch 019: Train Loss = 5.1969, Val Loss = 0.3649
# Epoch 020: Train Loss = 4.9134, Val Loss = 0.4463
# Epoch 021: Train Loss = 4.8583, Val Loss = 0.4086
# Epoch 022: Train Loss = 4.6849, Val Loss = 0.3925
# Epoch 023: Train Loss = 4.8684, Val Loss = 0.5607
# Epoch 024: Train Loss = 4.7584, Val Loss = 0.3250
# Epoch 025: Train Loss = 4.6537, Val Loss = 0.4270
# Epoch 026: Train Loss = 4.4547, Val Loss = 0.4991
# Epoch 027: Train Loss = 4.5620, Val Loss = 0.3124
# Epoch 028: Train Loss = 4.2519, Val Loss = 0.5505
# Epoch 029: Train Loss = 4.1671, Val Loss = 0.3845
# Epoch 030: Train Loss = 4.0238, Val Loss = 0.2964
# Epoch 031: Train Loss = 4.0708, Val Loss = 0.3461
# Epoch 032: Train Loss = 4.0525, Val Loss = 0.3342
# Epoch 033: Train Loss = 3.8623, Val Loss = 0.3132
# Epoch 034: Train Loss = 3.7220, Val Loss = 0.3107
# Epoch 035: Train Loss = 3.8064, Val Loss = 0.3456
# Epoch 036: Train Loss = 3.6068, Val Loss = 0.2638
# Epoch 037: Train Loss = 3.3970, Val Loss = 0.4394
# Epoch 038: Train Loss = 3.4627, Val Loss = 0.2606
# Epoch 039: Train Loss = 4.2081, Val Loss = 0.2473
# Epoch 040: Train Loss = 3.7045, Val Loss = 0.4564
# Epoch 041: Train Loss = 3.3180, Val Loss = 0.3032
# Epoch 042: Train Loss = 3.3980, Val Loss = 0.3109
# Epoch 043: Train Loss = 3.1469, Val Loss = 0.2896
# Epoch 044: Train Loss = 3.2174, Val Loss = 0.2806
# Epoch 045: Train Loss = 2.8606, Val Loss = 0.3535
# Epoch 046: Train Loss = 2.8191, Val Loss = 0.2507
# Epoch 047: Train Loss = 2.8620, Val Loss = 0.2305
# Epoch 048: Train Loss = 3.3018, Val Loss = 0.2354
# Epoch 049: Train Loss = 3.2146, Val Loss = 0.2756
# Epoch 050: Train Loss = 2.9138, Val Loss = 0.2383
# Epoch 051: Train Loss = 2.9659, Val Loss = 0.3417
# Epoch 052: Train Loss = 2.5939, Val Loss = 0.2738
# Epoch 053: Train Loss = 2.5266, Val Loss = 0.2969
# Epoch 054: Train Loss = 2.5255, Val Loss = 0.2300
# Epoch 055: Train Loss = 2.4666, Val Loss = 0.2357
# Epoch 056: Train Loss = 2.3504, Val Loss = 0.1726
# Epoch 057: Train Loss = 2.6410, Val Loss = 0.2271
# Epoch 058: Train Loss = 2.6421, Val Loss = 0.2041
# Epoch 059: Train Loss = 2.2342, Val Loss = 0.2299
# Epoch 060: Train Loss = 2.3131, Val Loss = 0.2610
# Epoch 061: Train Loss = 2.2143, Val Loss = 0.1750
# Epoch 062: Train Loss = 2.2561, Val Loss = 0.1793
# Epoch 063: Train Loss = 2.2618, Val Loss = 0.2677
# Epoch 064: Train Loss = 2.4354, Val Loss = 0.2427
# Epoch 065: Train Loss = 2.7569, Val Loss = 0.2335
# Epoch 066: Train Loss = 2.1359, Val Loss = 0.1707
# Epoch 067: Train Loss = 2.1369, Val Loss = 0.1508
# Epoch 068: Train Loss = 2.6557, Val Loss = 0.1547
# Epoch 069: Train Loss = 2.3058, Val Loss = 0.2670
# Epoch 070: Train Loss = 2.2990, Val Loss = 0.1404
# Epoch 071: Train Loss = 2.5477, Val Loss = 0.2004
# Epoch 072: Train Loss = 2.3933, Val Loss = 0.2055
# Epoch 073: Train Loss = 2.4653, Val Loss = 0.3554
# Epoch 074: Train Loss = 2.2824, Val Loss = 0.3019
# Epoch 075: Train Loss = 2.9938, Val Loss = 0.1356
# Epoch 076: Train Loss = 2.4889, Val Loss = 0.1918
# Epoch 077: Train Loss = 1.6633, Val Loss = 0.2152
# Epoch 078: Train Loss = 1.4992, Val Loss = 0.2042
# Epoch 079: Train Loss = 1.3819, Val Loss = 0.1531
# Epoch 080: Train Loss = 2.3456, Val Loss = 0.2112
# Epoch 081: Train Loss = 4.3181, Val Loss = 4.4637
# Epoch 082: Train Loss = 4.7672, Val Loss = 1.8190
# Epoch 083: Train Loss = 2.6376, Val Loss = 0.5573
# Epoch 084: Train Loss = 2.1205, Val Loss = 0.3075
# Epoch 085: Train Loss = 2.2672, Val Loss = 0.2518
# Epoch 086: Train Loss = 1.6126, Val Loss = 0.1689
# Epoch 087: Train Loss = 1.7625, Val Loss = 0.2835
# Epoch 088: Train Loss = 1.9762, Val Loss = 0.2880
# Epoch 089: Train Loss = 1.7684, Val Loss = 0.2086
# Epoch 090: Train Loss = 1.9381, Val Loss = 0.1960
# Epoch 091: Train Loss = 1.6785, Val Loss = 0.2512
# Epoch 092: Train Loss = 1.4799, Val Loss = 0.1648
# Epoch 093: Train Loss = 1.5254, Val Loss = 0.1928
# Epoch 094: Train Loss = 1.4028, Val Loss = 0.1874
# Epoch 095: Train Loss = 1.2160, Val Loss = 0.1746
# Epoch 096: Train Loss = 1.3741, Val Loss = 0.1196
# Epoch 097: Train Loss = 1.4659, Val Loss = 0.1842
# Epoch 098: Train Loss = 1.5926, Val Loss = 0.1165
# Epoch 099: Train Loss = 1.5546, Val Loss = 0.1376
# Epoch 100: Train Loss = 1.2784, Val Loss = 0.1050
# Epoch 101: Train Loss = 1.3392, Val Loss = 0.2722
# Epoch 102: Train Loss = 1.6165, Val Loss = 0.1063
# Epoch 103: Train Loss = 2.0457, Val Loss = 0.1085
# Epoch 104: Train Loss = 1.4203, Val Loss = 0.1667
# Epoch 105: Train Loss = 1.3377, Val Loss = 0.1533
# Epoch 106: Train Loss = 1.4888, Val Loss = 0.1262
# Epoch 107: Train Loss = 1.4761, Val Loss = 0.1267
# Epoch 108: Train Loss = 1.6752, Val Loss = 0.0835
# Epoch 109: Train Loss = 2.6287, Val Loss = 0.4800
# Epoch 110: Train Loss = 3.0044, Val Loss = 0.1798
# Epoch 111: Train Loss = 2.5852, Val Loss = 0.3009
# Epoch 112: Train Loss = 2.4299, Val Loss = 0.3101
# Epoch 113: Train Loss = 1.8131, Val Loss = 0.2513
# Epoch 114: Train Loss = 1.8262, Val Loss = 0.2322
# Epoch 115: Train Loss = 1.8251, Val Loss = 0.1718
# Epoch 116: Train Loss = 2.2024, Val Loss = 0.2247
# Epoch 117: Train Loss = 2.2200, Val Loss = 0.3767
# Epoch 118: Train Loss = 2.6615, Val Loss = 0.1549
# Epoch 119: Train Loss = 1.7191, Val Loss = 0.5341
# Epoch 120: Train Loss = 1.6833, Val Loss = 0.2153
# Epoch 121: Train Loss = 1.1198, Val Loss = 0.1796
# Epoch 122: Train Loss = 1.2235, Val Loss = 0.1489
# Epoch 123: Train Loss = 1.2763, Val Loss = 0.1322
# Epoch 124: Train Loss = 1.1074, Val Loss = 0.1112
# Epoch 125: Train Loss = 1.0432, Val Loss = 0.1075
# Epoch 126: Train Loss = 1.2174, Val Loss = 0.1099
# Epoch 127: Train Loss = 1.5559, Val Loss = 0.0999
# Epoch 128: Train Loss = 3.7289, Val Loss = 0.1105
# Epoch 129: Train Loss = 1.0494, Val Loss = 0.4128
# Epoch 130: Train Loss = 1.3405, Val Loss = 0.2494
# Epoch 131: Train Loss = 2.6250, Val Loss = 0.1446
# Epoch 132: Train Loss = 2.9386, Val Loss = 0.6050
# Epoch 133: Train Loss = 2.5776, Val Loss = 0.2491
# Epoch 134: Train Loss = 3.0108, Val Loss = 0.1735
# Epoch 135: Train Loss = 2.3142, Val Loss = 0.5310
# Epoch 136: Train Loss = 2.2222, Val Loss = 0.1711
# Epoch 137: Train Loss = 1.8676, Val Loss = 0.1140
# Epoch 138: Train Loss = 1.2903, Val Loss = 0.1406
# Epoch 139: Train Loss = 1.1686, Val Loss = 0.1299
# Epoch 140: Train Loss = 1.5547, Val Loss = 0.0854
# Epoch 141: Train Loss = 1.6873, Val Loss = 0.0701
# Epoch 142: Train Loss = 1.6480, Val Loss = 0.0781
# Epoch 143: Train Loss = 1.2260, Val Loss = 0.1621
# Epoch 144: Train Loss = 0.9051, Val Loss = 0.1526
# Epoch 145: Train Loss = 0.8755, Val Loss = 0.0698
# Epoch 146: Train Loss = 0.8214, Val Loss = 0.1112
# Epoch 147: Train Loss = 0.8570, Val Loss = 0.0758
# Epoch 148: Train Loss = 1.0206, Val Loss = 0.0879
# Epoch 149: Train Loss = 1.1129, Val Loss = 0.0669
# Epoch 150: Train Loss = 1.1892, Val Loss = 0.1047
# Epoch 151: Train Loss = 1.4651, Val Loss = 0.0749
# Epoch 152: Train Loss = 0.9071, Val Loss = 0.0690
# Epoch 153: Train Loss = 0.9391, Val Loss = 0.0603
# Epoch 154: Train Loss = 0.9919, Val Loss = 0.0717
# Epoch 155: Train Loss = 0.8624, Val Loss = 0.0521
# Epoch 156: Train Loss = 0.8515, Val Loss = 0.0865
# Epoch 157: Train Loss = 0.7338, Val Loss = 0.0459
# Epoch 158: Train Loss = 0.8069, Val Loss = 0.0580
# Epoch 159: Train Loss = 0.7287, Val Loss = 0.0963
# Epoch 160: Train Loss = 0.7635, Val Loss = 0.0537
# Epoch 161: Train Loss = 0.9480, Val Loss = 0.3020
# Epoch 162: Train Loss = 2.2542, Val Loss = 0.1488
# Epoch 163: Train Loss = 1.6586, Val Loss = 0.3436
# Epoch 164: Train Loss = 1.5726, Val Loss = 0.1200
# Epoch 165: Train Loss = 1.7182, Val Loss = 0.0982
# Epoch 166: Train Loss = 1.0942, Val Loss = 0.0767
# Epoch 167: Train Loss = 1.1173, Val Loss = 0.0733
# Epoch 168: Train Loss = 1.2820, Val Loss = 0.0865
# Epoch 169: Train Loss = 1.1172, Val Loss = 0.1092
# Epoch 170: Train Loss = 1.0388, Val Loss = 0.0691
# Epoch 171: Train Loss = 0.9109, Val Loss = 0.0607
# Epoch 172: Train Loss = 0.7460, Val Loss = 0.0704
# Epoch 173: Train Loss = 0.6843, Val Loss = 0.0725
# Epoch 174: Train Loss = 0.7330, Val Loss = 0.0589
# Epoch 175: Train Loss = 0.7315, Val Loss = 0.0972
# Epoch 176: Train Loss = 0.6437, Val Loss = 0.0500
# Epoch 177: Train Loss = 0.6606, Val Loss = 0.0648
# Epoch 178: Train Loss = 0.5452, Val Loss = 0.0541
# Epoch 179: Train Loss = 0.5485, Val Loss = 0.0640
# Epoch 180: Train Loss = 0.7405, Val Loss = 0.0825
# Epoch 181: Train Loss = 0.8349, Val Loss = 0.0497
# Epoch 182: Train Loss = 1.1569, Val Loss = 0.1560
# Epoch 183: Train Loss = 1.3530, Val Loss = 0.1326
# Epoch 184: Train Loss = 0.7842, Val Loss = 0.0560
# Epoch 185: Train Loss = 0.6611, Val Loss = 0.1074
# Epoch 186: Train Loss = 1.0302, Val Loss = 0.0525
# Epoch 187: Train Loss = 1.5411, Val Loss = 0.0527
# Epoch 188: Train Loss = 1.4989, Val Loss = 0.1696
# Epoch 189: Train Loss = 1.7398, Val Loss = 0.1096
# Epoch 190: Train Loss = 1.9005, Val Loss = 0.3896
# Epoch 191: Train Loss = 2.3867, Val Loss = 0.3058
# Epoch 192: Train Loss = 2.3218, Val Loss = 0.4273
# Epoch 193: Train Loss = 2.1568, Val Loss = 0.3174
# Epoch 194: Train Loss = 2.1669, Val Loss = 0.2544
# Epoch 195: Train Loss = 2.0701, Val Loss = 0.2749
# Epoch 196: Train Loss = 2.0226, Val Loss = 0.2138
# Epoch 197: Train Loss = 1.8819, Val Loss = 0.2106
# Early stopping at epoch 197
# Test RMSE: 0.0736
# Test R²:   0.9236
# F-statistic: 1191.0998
# P-value:     1.1102e-16
# Total Runtime: 0.01 seconds
# Prediction horizon at threshold 0.05: 0 steps
# Total runtime: 0.01 seconds
# Pearson correlation: 0.9629
# Spearman correlation: 0.9644
# Spectral cosine similarity: 0.9922

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from scipy.stats import f as f_dist
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import random
import time

import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, random_split
import time
import torch
import numpy as np
import random

# --- 1. Fix Python, NumPy, and random seeds ---
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# --- 2. Force deterministic behavior for cuDNN ---
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# --- Use GPU if available ---
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)


# --- Mackey-Glass Generator ---
def mackey_glass(t_max, tau=17, delta_t=1, beta=0.2, gamma=0.1, n=10, x0=0.8):
    t_len = int(t_max / delta_t)
    x = np.zeros(t_len)
    x[0] = x0
    for t in range(1, t_len):
        if t - tau >= 0:
            x[t] = x[t - 1] + delta_t * (
                beta * x[t - tau] / (1 + x[t - tau] ** n) - gamma * x[t - 1]
            )
        else:
            x[t] = x[t - 1] - delta_t * gamma * x[t - 1]
    return x
# --- Function to insert anomalies ---
def insert_anomalies(x, anomaly_rate=0.05, anomaly_scale=0.5):
    """
    Insert anomalies into a time series.
    anomaly_rate: fraction of points that are anomalous
    anomaly_scale: magnitude of anomalies
    """
    x_anom = x.copy()
    n_points = len(x)
    n_anomalies = int(n_points * anomaly_rate)

    anomaly_indices = np.random.choice(n_points, size=n_anomalies, replace=False)
    for idx in anomaly_indices:
        x_anom[idx] += np.random.uniform(-anomaly_scale, anomaly_scale)
    return x_anom

# --- Parameters ---
t_max = 200
delta_t = 1
train_ics_left = np.linspace(0, 1.17, 15)
train_ics_right = np.linspace(1.23, 3, 15)
train_ics = np.concatenate((train_ics_left, train_ics_right))
test_ic = 1.6
timesteps = np.arange(0, t_max, delta_t)

# --- Generate training data (with anomalies on 5 sequences) ---
X_list, y_list = [], []
rng = np.random.default_rng()  # independent generator (no fixed seed)
anomalous_indices = [15, 5, 23, 7, 18]

for i, ic in enumerate(train_ics):
    x = mackey_glass(t_max=t_max, x0=ic)
    if i in anomalous_indices:
        x = insert_anomalies(x, anomaly_rate=0.1, anomaly_scale=0.7)  # insert anomalies
    norm_t = timesteps / t_max
    features = np.stack([np.full_like(norm_t, ic), norm_t], axis=1)
    X_list.append(features)
    y_list.append(x)

X = np.vstack(X_list)
y = np.concatenate(y_list)

import math

# Number of rows and columns for subplot grid
n_traj = len(y_list)
n_cols = 5  # you can change this
n_rows = math.ceil(n_traj / n_cols)

plt.figure(figsize=(n_cols*3, n_rows*2.5))

for i, x in enumerate(y_list):
    plt.subplot(n_rows, n_cols, i+1)
    if i in anomalous_indices:
        plt.plot(x, 'r--', label=f"IC={train_ics[i]:.2f} (Anomalous)")
    else:
        plt.plot(x, 'b-', label=f"IC={train_ics[i]:.2f}")
    plt.title(f"IC={train_ics[i]:.2f}")
    plt.xticks([])
    plt.yticks([])
    if i in anomalous_indices:
        plt.gca().set_facecolor("#ffeeee")  # light red background for anomalies

plt.tight_layout()
plt.show()




# --- Generate test data ---
x_test = mackey_glass(t_max=200, x0=test_ic)
norm_t_test = timesteps / t_max
X_test = np.stack([np.full_like(norm_t_test, test_ic), norm_t_test], axis=1)
y_test = x_test

# --- Normalize features ---
X_scaler = StandardScaler()
X_scaled = X_scaler.fit_transform(X)
X_test_scaled = X_scaler.transform(X_test)

# --- Normalize outputs ---
y_scaler = StandardScaler()
y_scaled = y_scaler.fit_transform(y.reshape(-1, 1)).flatten()
y_test_scaled = y_scaler.transform(y_test.reshape(-1, 1)).flatten()

# --- Prepare torch datasets ---
X_tensor = torch.tensor(
    X_scaled,
    dtype=torch.float32
).reshape(len(train_ics), t_max, 2)

y_tensor = torch.tensor(
    y_scaled,
    dtype=torch.float32
).reshape(len(train_ics), t_max)

X_test_tensor = torch.tensor(
    X_test_scaled,
    dtype=torch.float32
).unsqueeze(0).to(device)

y_test_tensor = torch.tensor(
    y_test_scaled,
    dtype=torch.float32
).unsqueeze(0).to(device)

# Split into train and validation (36 train, 4 val)
val_split = 1
train_len = len(train_ics) - val_split
train_dataset, val_dataset = random_split(TensorDataset(X_tensor, y_tensor), [train_len, val_split])
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=4)

# --- GRU Model ---
class GRUNet(nn.Module):
    def __init__(self, input_size=2, hidden_size=64, num_layers=3):
        super(GRUNet, self).__init__()
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True)
        self.linear = nn.Linear(hidden_size, 1)

    def forward(self, x):
        out, _ = self.gru(x)
        out = self.linear(out).squeeze(-1)
        return out


model = GRUNet().to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
# --- Early stopping params ---
best_val_loss = float('inf')
patience = 40
patience_counter = 0
best_model_state = None
# --- Train with validation tracking ---
train_losses = []
val_losses = []
start_time = time.time()
epochs = 200

# --- Train the model ---
epochs = 200
for epoch in range(epochs):
    model.train()
    total_loss = 0
    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        output = model(xb)
        loss = criterion(output, yb)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    # Validation loss
    if best_model_state is not None:
      model.load_state_dict(best_model_state)
    model.eval()
    with torch.no_grad():
        val_loss = 0
        for xb_val, yb_val in val_loader:
            xb_val, yb_val = xb_val.to(device), yb_val.to(device)
            val_output = model(xb_val)
            val_loss += criterion(val_output, yb_val).item()
        val_loss /= len(val_loader)
    train_losses.append(total_loss / len(train_loader))
    val_losses.append(val_loss)
    print(f"Epoch {epoch:03d}: Train Loss = {total_loss:.4f}, Val Loss = {val_loss:.4f}")

    # Check early stopping
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        best_model_state = model.state_dict()
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            break

# --- Plot Training vs Validation Loss ---
plt.figure(figsize=(8, 4))
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# --- Load best model ---
start_time = time.time()
# --- Predict on test IC ---
model.eval()
with torch.no_grad():
    pred_test_scaled = model(X_test_tensor).squeeze(0).cpu().numpy()

pred_test = y_scaler.inverse_transform(
    pred_test_scaled.reshape(-1, 1)
).flatten()

rmse = np.sqrt(mean_squared_error(y_test, pred_test))
r2 = r2_score(y_test, pred_test)
print(f"\nTest RMSE: {rmse:.4f}")
print(f"Test R²:   {r2:.4f}")
end_time = time.time()
# --- Plot results ---
plt.figure(figsize=(10, 5))
plt.plot(y_test, label='True')
plt.plot(pred_test, label='Predicted', linestyle='--')
plt.title(f"GRU Prediction on Unseen Initial Condition x₀ = {test_ic}")
plt.xlabel("Time Step")
plt.ylabel("x(t)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# --- F-statistic and p-value ---
n = len(y_test)
k = X_test.shape[1]  # number of predictors = 2
F_stat = (r2 / k) / ((1 - r2) / (n - k - 1))
p_value = 1 - f_dist.cdf(F_stat, k, n - k - 1)

print(f"F-statistic: {F_stat:.4f}")
print(f"P-value:     {p_value:.4e}")

print(f"Total Runtime: {end_time - start_time:.2f} seconds")

import numpy as np
import matplotlib.pyplot as plt

# Divergence
errors = np.abs(pred_test - y_test)            # abs error
rmse_window = np.sqrt((pred_test - y_test)**2) # RMSE error

# Optional: smooth with moving average for clarity
def moving_avg(x, w=10):
    return np.convolve(x, np.ones(w)/w, mode='valid')

window_size = 10
smoothed_error = moving_avg(errors, w=window_size)
smoothed_rmse = moving_avg(rmse_window, w=window_size)

# Plot
plt.figure(figsize=(10, 4))
plt.plot(smoothed_error, label="Abs Error (Smoothed)", alpha=0.8)
plt.plot(smoothed_rmse, label="RMSE (Smoothed)", alpha=0.8)
plt.axhline(y=0.05, color='r', linestyle='--', label='Error Threshold (0.05)')
plt.title("Prediction Divergence Over Time")
plt.xlabel("Time Step")
plt.ylabel("Prediction Error")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Divergence
errors = np.abs(pred_test - y_test)            # abs error
rmse_window = np.sqrt((pred_test - y_test)**2) # RMSE error

# Optional: smooth with moving average for clarity
def moving_avg(x, w=10):
    return np.convolve(x, np.ones(w)/w, mode='valid')

window_size = 10
smoothed_error = moving_avg(errors, w=window_size)
smoothed_rmse = moving_avg(rmse_window, w=window_size)

# Plot
plt.figure(figsize=(10, 4))
plt.plot(smoothed_error, label="Abs Error (Smoothed)", alpha=0.8)
plt.plot(smoothed_rmse, label="RMSE (Smoothed)", alpha=0.8)
plt.axhline(y=0.05, color='r', linestyle='--', label='Error Threshold (0.05)')
plt.title("Prediction Divergence Over Time")
plt.xlabel("Time Step")
plt.ylabel("Prediction Error")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

threshold = 0.05
divergence_time = np.argmax(smoothed_error > threshold)
print(f"Prediction horizon at threshold {threshold}: {divergence_time} steps")


print(f"Total runtime: {end_time - start_time:.2f} seconds")

from scipy.stats import pearsonr, spearmanr

def correlation_metrics(y_true, y_pred):
    pearson_corr, _ = pearsonr(y_true, y_pred)
    spearman_corr, _ = spearmanr(y_true, y_pred)
    return pearson_corr, spearman_corr

pearson_corr, spearman_corr = correlation_metrics(y_test, pred_test)
print(f"Pearson correlation: {pearson_corr:.4f}")
print(f"Spearman correlation: {spearman_corr:.4f}")

from scipy.signal import welch
from numpy.linalg import norm

def spectral_similarity(y_true, y_pred, fs=1.0):
    # Welch’s method for power spectral density (PSD)
    f_true, Pxx_true = welch(y_true, fs=fs, nperseg=128)
    f_pred, Pxx_pred = welch(y_pred, fs=fs, nperseg=128)

    # Normalize
    Pxx_true /= np.sum(Pxx_true)
    Pxx_pred /= np.sum(Pxx_pred)

    # Cosine similarity
    cosine_sim = np.dot(Pxx_true, Pxx_pred) / (norm(Pxx_true) * norm(Pxx_pred))
    return cosine_sim, f_true, Pxx_true, Pxx_pred

cos_sim, f, spec_true, spec_pred = spectral_similarity(y_test, pred_test)
print(f"Spectral cosine similarity: {cos_sim:.4f}")

# Plot spectra
plt.figure(figsize=(8,4))
plt.semilogy(f, spec_true, label="True PSD")
plt.semilogy(f, spec_pred, label="Predicted PSD")
plt.title("Power Spectrum Comparison")
plt.xlabel("Frequency")
plt.ylabel("Normalized Power")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Using device: cuda
# Epoch 000: Train Loss = 10.2550, Val Loss = 0.8442
# Epoch 001: Train Loss = 7.1122, Val Loss = 0.7455
# Epoch 002: Train Loss = 6.7379, Val Loss = 0.7764
# Epoch 003: Train Loss = 6.8080, Val Loss = 0.7638
# Epoch 004: Train Loss = 6.5619, Val Loss = 0.7426
# Epoch 005: Train Loss = 6.4259, Val Loss = 0.6347
# Epoch 006: Train Loss = 6.3872, Val Loss = 0.5787
# Epoch 007: Train Loss = 6.1255, Val Loss = 0.4915
# Epoch 008: Train Loss = 6.0301, Val Loss = 0.4715
# Epoch 009: Train Loss = 6.2974, Val Loss = 0.4209
# Epoch 010: Train Loss = 5.5428, Val Loss = 0.3955
# Epoch 011: Train Loss = 5.8854, Val Loss = 0.3804
# Epoch 012: Train Loss = 5.8540, Val Loss = 0.4070
# Epoch 013: Train Loss = 5.3682, Val Loss = 0.3572
# Epoch 014: Train Loss = 5.8549, Val Loss = 0.5042
# Epoch 015: Train Loss = 5.5088, Val Loss = 0.4274
# Epoch 016: Train Loss = 5.5167, Val Loss = 0.4475
# Epoch 017: Train Loss = 5.2449, Val Loss = 0.4538
# Epoch 018: Train Loss = 5.1754, Val Loss = 0.4490
# Epoch 019: Train Loss = 5.1969, Val Loss = 0.3649
# Epoch 020: Train Loss = 4.9134, Val Loss = 0.4463
# Epoch 021: Train Loss = 4.8583, Val Loss = 0.4086
# Epoch 022: Train Loss = 4.6849, Val Loss = 0.3925
# Epoch 023: Train Loss = 4.8684, Val Loss = 0.5607
# Epoch 024: Train Loss = 4.7584, Val Loss = 0.3250
# Epoch 025: Train Loss = 4.6537, Val Loss = 0.4270
# Epoch 026: Train Loss = 4.4547, Val Loss = 0.4991
# Epoch 027: Train Loss = 4.5620, Val Loss = 0.3124
# Epoch 028: Train Loss = 4.2519, Val Loss = 0.5505
# Epoch 029: Train Loss = 4.1671, Val Loss = 0.3845
# Epoch 030: Train Loss = 4.0238, Val Loss = 0.2964
# Epoch 031: Train Loss = 4.0708, Val Loss = 0.3461
# Epoch 032: Train Loss = 4.0525, Val Loss = 0.3342
# Epoch 033: Train Loss = 3.8623, Val Loss = 0.3132
# Epoch 034: Train Loss = 3.7220, Val Loss = 0.3107
# Epoch 035: Train Loss = 3.8064, Val Loss = 0.3456
# Epoch 036: Train Loss = 3.6068, Val Loss = 0.2638
# Epoch 037: Train Loss = 3.3970, Val Loss = 0.4394
# Epoch 038: Train Loss = 3.4627, Val Loss = 0.2606
# Epoch 039: Train Loss = 4.2081, Val Loss = 0.2473
# Epoch 040: Train Loss = 3.7045, Val Loss = 0.4564
# Epoch 041: Train Loss = 3.3180, Val Loss = 0.3032
# Epoch 042: Train Loss = 3.3980, Val Loss = 0.3109
# Epoch 043: Train Loss = 3.1469, Val Loss = 0.2896
# Epoch 044: Train Loss = 3.2174, Val Loss = 0.2806
# Epoch 045: Train Loss = 2.8606, Val Loss = 0.3535
# Epoch 046: Train Loss = 2.8191, Val Loss = 0.2507
# Epoch 047: Train Loss = 2.8620, Val Loss = 0.2305
# Epoch 048: Train Loss = 3.3018, Val Loss = 0.2354
# Epoch 049: Train Loss = 3.2146, Val Loss = 0.2756
# Epoch 050: Train Loss = 2.9138, Val Loss = 0.2383
# Epoch 051: Train Loss = 2.9659, Val Loss = 0.3417
# Epoch 052: Train Loss = 2.5939, Val Loss = 0.2738
# Epoch 053: Train Loss = 2.5266, Val Loss = 0.2969
# Epoch 054: Train Loss = 2.5255, Val Loss = 0.2300
# Epoch 055: Train Loss = 2.4666, Val Loss = 0.2357
# Epoch 056: Train Loss = 2.3504, Val Loss = 0.1726
# Epoch 057: Train Loss = 2.6410, Val Loss = 0.2271
# Epoch 058: Train Loss = 2.6421, Val Loss = 0.2041
# Epoch 059: Train Loss = 2.2342, Val Loss = 0.2299
# Epoch 060: Train Loss = 2.3131, Val Loss = 0.2610
# Epoch 061: Train Loss = 2.2143, Val Loss = 0.1750
# Epoch 062: Train Loss = 2.2561, Val Loss = 0.1793
# Epoch 063: Train Loss = 2.2618, Val Loss = 0.2677
# Epoch 064: Train Loss = 2.4354, Val Loss = 0.2427
# Epoch 065: Train Loss = 2.7569, Val Loss = 0.2335
# Epoch 066: Train Loss = 2.1359, Val Loss = 0.1707
# Epoch 067: Train Loss = 2.1369, Val Loss = 0.1508
# Epoch 068: Train Loss = 2.6557, Val Loss = 0.1547
# Epoch 069: Train Loss = 2.3058, Val Loss = 0.2670
# Epoch 070: Train Loss = 2.2990, Val Loss = 0.1404
# Epoch 071: Train Loss = 2.5477, Val Loss = 0.2004
# Epoch 072: Train Loss = 2.3933, Val Loss = 0.2055
# Epoch 073: Train Loss = 2.4653, Val Loss = 0.3554
# Epoch 074: Train Loss = 2.2824, Val Loss = 0.3019
# Epoch 075: Train Loss = 2.9938, Val Loss = 0.1356
# Epoch 076: Train Loss = 2.4889, Val Loss = 0.1918
# Epoch 077: Train Loss = 1.6633, Val Loss = 0.2152
# Epoch 078: Train Loss = 1.4992, Val Loss = 0.2042
# Epoch 079: Train Loss = 1.3819, Val Loss = 0.1531
# Epoch 080: Train Loss = 2.3456, Val Loss = 0.2112
# Epoch 081: Train Loss = 4.3181, Val Loss = 4.4637
# Epoch 082: Train Loss = 4.7672, Val Loss = 1.8190
# Epoch 083: Train Loss = 2.6376, Val Loss = 0.5573
# Epoch 084: Train Loss = 2.1205, Val Loss = 0.3075
# Epoch 085: Train Loss = 2.2672, Val Loss = 0.2518
# Epoch 086: Train Loss = 1.6126, Val Loss = 0.1689
# Epoch 087: Train Loss = 1.7625, Val Loss = 0.2835
# Epoch 088: Train Loss = 1.9762, Val Loss = 0.2880
# Epoch 089: Train Loss = 1.7684, Val Loss = 0.2086
# Epoch 090: Train Loss = 1.9381, Val Loss = 0.1960
# Epoch 091: Train Loss = 1.6785, Val Loss = 0.2512
# Epoch 092: Train Loss = 1.4799, Val Loss = 0.1648
# Epoch 093: Train Loss = 1.5254, Val Loss = 0.1928
# Epoch 094: Train Loss = 1.4028, Val Loss = 0.1874
# Epoch 095: Train Loss = 1.2160, Val Loss = 0.1746
# Epoch 096: Train Loss = 1.3741, Val Loss = 0.1196
# Epoch 097: Train Loss = 1.4659, Val Loss = 0.1842
# Epoch 098: Train Loss = 1.5926, Val Loss = 0.1165
# Epoch 099: Train Loss = 1.5546, Val Loss = 0.1376
# Epoch 100: Train Loss = 1.2784, Val Loss = 0.1050
# Epoch 101: Train Loss = 1.3392, Val Loss = 0.2722
# Epoch 102: Train Loss = 1.6165, Val Loss = 0.1063
# Epoch 103: Train Loss = 2.0457, Val Loss = 0.1085
# Epoch 104: Train Loss = 1.4203, Val Loss = 0.1667
# Epoch 105: Train Loss = 1.3377, Val Loss = 0.1533
# Epoch 106: Train Loss = 1.4888, Val Loss = 0.1262
# Epoch 107: Train Loss = 1.4761, Val Loss = 0.1267
# Epoch 108: Train Loss = 1.6752, Val Loss = 0.0835
# Epoch 109: Train Loss = 2.6287, Val Loss = 0.4800
# Epoch 110: Train Loss = 3.0044, Val Loss = 0.1798
# Epoch 111: Train Loss = 2.5852, Val Loss = 0.3009
# Epoch 112: Train Loss = 2.4299, Val Loss = 0.3101
# Epoch 113: Train Loss = 1.8131, Val Loss = 0.2513
# Epoch 114: Train Loss = 1.8262, Val Loss = 0.2322
# Epoch 115: Train Loss = 1.8251, Val Loss = 0.1718
# Epoch 116: Train Loss = 2.2024, Val Loss = 0.2247
# Epoch 117: Train Loss = 2.2200, Val Loss = 0.3767
# Epoch 118: Train Loss = 2.6615, Val Loss = 0.1549
# Epoch 119: Train Loss = 1.7191, Val Loss = 0.5341
# Epoch 120: Train Loss = 1.6833, Val Loss = 0.2153
# Epoch 121: Train Loss = 1.1198, Val Loss = 0.1796
# Epoch 122: Train Loss = 1.2235, Val Loss = 0.1489
# Epoch 123: Train Loss = 1.2763, Val Loss = 0.1322
# Epoch 124: Train Loss = 1.1074, Val Loss = 0.1112
# Epoch 125: Train Loss = 1.0432, Val Loss = 0.1075
# Epoch 126: Train Loss = 1.2174, Val Loss = 0.1099
# Epoch 127: Train Loss = 1.5559, Val Loss = 0.0999
# Epoch 128: Train Loss = 3.7289, Val Loss = 0.1105
# Epoch 129: Train Loss = 1.0494, Val Loss = 0.4128
# Epoch 130: Train Loss = 1.3405, Val Loss = 0.2494
# Epoch 131: Train Loss = 2.6250, Val Loss = 0.1446
# Epoch 132: Train Loss = 2.9386, Val Loss = 0.6050
# Epoch 133: Train Loss = 2.5776, Val Loss = 0.2491
# Epoch 134: Train Loss = 3.0108, Val Loss = 0.1735
# Epoch 135: Train Loss = 2.3142, Val Loss = 0.5310
# Epoch 136: Train Loss = 2.2222, Val Loss = 0.1711
# Epoch 137: Train Loss = 1.8676, Val Loss = 0.1140
# Epoch 138: Train Loss = 1.2903, Val Loss = 0.1406
# Epoch 139: Train Loss = 1.1686, Val Loss = 0.1299
# Epoch 140: Train Loss = 1.5547, Val Loss = 0.0854
# Epoch 141: Train Loss = 1.6873, Val Loss = 0.0701
# Epoch 142: Train Loss = 1.6480, Val Loss = 0.0781
# Epoch 143: Train Loss = 1.2260, Val Loss = 0.1621
# Epoch 144: Train Loss = 0.9051, Val Loss = 0.1526
# Epoch 145: Train Loss = 0.8755, Val Loss = 0.0698
# Epoch 146: Train Loss = 0.8214, Val Loss = 0.1112
# Epoch 147: Train Loss = 0.8570, Val Loss = 0.0758
# Epoch 148: Train Loss = 1.0206, Val Loss = 0.0879
# Epoch 149: Train Loss = 1.1129, Val Loss = 0.0669
# Epoch 150: Train Loss = 1.1892, Val Loss = 0.1047
# Epoch 151: Train Loss = 1.4651, Val Loss = 0.0749
# Epoch 152: Train Loss = 0.9071, Val Loss = 0.0690
# Epoch 153: Train Loss = 0.9391, Val Loss = 0.0603
# Epoch 154: Train Loss = 0.9919, Val Loss = 0.0717
# Epoch 155: Train Loss = 0.8624, Val Loss = 0.0521
# Epoch 156: Train Loss = 0.8515, Val Loss = 0.0865
# Epoch 157: Train Loss = 0.7338, Val Loss = 0.0459
# Epoch 158: Train Loss = 0.8069, Val Loss = 0.0580
# Epoch 159: Train Loss = 0.7287, Val Loss = 0.0963
# Epoch 160: Train Loss = 0.7635, Val Loss = 0.0537
# Epoch 161: Train Loss = 0.9480, Val Loss = 0.3020
# Epoch 162: Train Loss = 2.2542, Val Loss = 0.1488
# Epoch 163: Train Loss = 1.6586, Val Loss = 0.3436
# Epoch 164: Train Loss = 1.5726, Val Loss = 0.1200
# Epoch 165: Train Loss = 1.7182, Val Loss = 0.0982
# Epoch 166: Train Loss = 1.0942, Val Loss = 0.0767
# Epoch 167: Train Loss = 1.1173, Val Loss = 0.0733
# Epoch 168: Train Loss = 1.2820, Val Loss = 0.0865
# Epoch 169: Train Loss = 1.1172, Val Loss = 0.1092
# Epoch 170: Train Loss = 1.0388, Val Loss = 0.0691
# Epoch 171: Train Loss = 0.9109, Val Loss = 0.0607
# Epoch 172: Train Loss = 0.7460, Val Loss = 0.0704
# Epoch 173: Train Loss = 0.6843, Val Loss = 0.0725
# Epoch 174: Train Loss = 0.7330, Val Loss = 0.0589
# Epoch 175: Train Loss = 0.7315, Val Loss = 0.0972
# Epoch 176: Train Loss = 0.6437, Val Loss = 0.0500
# Epoch 177: Train Loss = 0.6606, Val Loss = 0.0648
# Epoch 178: Train Loss = 0.5452, Val Loss = 0.0541
# Epoch 179: Train Loss = 0.5485, Val Loss = 0.0640
# Epoch 180: Train Loss = 0.7405, Val Loss = 0.0825
# Epoch 181: Train Loss = 0.8349, Val Loss = 0.0497
# Epoch 182: Train Loss = 1.1569, Val Loss = 0.1560
# Epoch 183: Train Loss = 1.3530, Val Loss = 0.1326
# Epoch 184: Train Loss = 0.7842, Val Loss = 0.0560
# Epoch 185: Train Loss = 0.6611, Val Loss = 0.1074
# Epoch 186: Train Loss = 1.0302, Val Loss = 0.0525
# Epoch 187: Train Loss = 1.5411, Val Loss = 0.0527
# Epoch 188: Train Loss = 1.4989, Val Loss = 0.1696
# Epoch 189: Train Loss = 1.7398, Val Loss = 0.1096
# Epoch 190: Train Loss = 1.9005, Val Loss = 0.3896
# Epoch 191: Train Loss = 2.3867, Val Loss = 0.3058
# Epoch 192: Train Loss = 2.3218, Val Loss = 0.4273
# Epoch 193: Train Loss = 2.1568, Val Loss = 0.3174
# Epoch 194: Train Loss = 2.1669, Val Loss = 0.2544
# Epoch 195: Train Loss = 2.0701, Val Loss = 0.2749
# Epoch 196: Train Loss = 2.0226, Val Loss = 0.2138
# Epoch 197: Train Loss = 1.8819, Val Loss = 0.2106
# Early stopping at epoch 197
# Test RMSE: 0.0680
# Test R²:   0.9379
# F-statistic: 1488.9266
# P-value:     1.1102e-16
# Total Runtime: 0.00 seconds
# Prediction horizon at threshold 0.05: 6 steps
# Total runtime: 0.00 seconds
# Pearson correlation: 0.9687
# Spearman correlation: 0.9691
# Spectral cosine similarity: 0.9871
