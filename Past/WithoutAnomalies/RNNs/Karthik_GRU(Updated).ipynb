# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from scipy.stats import f as f_dist
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import time

# %%
# --- Mackey-Glass Generator ---
def mackey_glass(t_max, tau=17, delta_t=1, beta=0.2, gamma=0.1, n=10, x0=1.2):
    t_len = int(t_max / delta_t)
    x = np.zeros(t_len)
    x[0] = x0
    for t in range(1, t_len):
        if t - tau >= 0:
            x[t] = x[t - 1] + delta_t * (
                beta * x[t - tau] / (1 + x[t - tau] ** n) - gamma * x[t - 1]
            )
        else:
            x[t] = x[t - 1] - delta_t * gamma * x[t - 1]
    return x

# --- Parameters ---
t_max = 200
delta_t = 1
test_ic = 1.2
train_ics_all = np.concatenate((np.linspace(0, 1.19, 20), np.linspace(1.21, 3, 20)))
train_ics_train, train_ics_val = train_test_split(train_ics_all, test_size=0.1, random_state=42)
timesteps = np.arange(0, t_max, delta_t)

# --- Feature Generator ---
def generate_data(ics, t_max):
    X_list, y_list = [], []
    for ic in ics:
        x = mackey_glass(t_max=t_max, x0=ic)
        norm_t = timesteps / t_max
        features = np.stack([np.full_like(norm_t, ic), norm_t], axis=1)
        X_list.append(features)
        y_list.append(x)
    return np.vstack(X_list), np.concatenate(y_list), len(ics)

# --- Generate all sets ---
X_train, y_train, N_train = generate_data(train_ics_train, t_max)
X_val, y_val, N_val = generate_data(train_ics_val, t_max)
X_test, y_test, _ = generate_data([test_ic], t_max)

# --- Normalize ---
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# --- Reshape into (ICs, Timesteps, Features) ---
X_train_tensor = torch.tensor(X_train_scaled, dtype=torch.float32).reshape(N_train, t_max, 2)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32).reshape(N_train, t_max)
X_val_tensor = torch.tensor(X_val_scaled, dtype=torch.float32).reshape(N_val, t_max, 2)
y_val_tensor = torch.tensor(y_val, dtype=torch.float32).reshape(N_val, t_max)
X_test_tensor = torch.tensor(X_test_scaled, dtype=torch.float32).unsqueeze(0)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(0)

# --- Dataloaders ---
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=8)

# %%
# --- GRU Model ---
class GRUNet(nn.Module):
    def __init__(self, input_size=2, hidden_size=64, num_layers=3):
        super(GRUNet, self).__init__()
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True)
        self.linear = nn.Linear(hidden_size, 1)

    def forward(self, x):
        out, _ = self.gru(x)
        out = self.linear(out).squeeze(-1)
        return out

# %%
model = GRUNet()
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# --- Train with validation tracking ---
train_losses = []
val_losses = []
start_time = time.time()
epochs = 200

for epoch in range(epochs):
    model.train()
    total_train_loss = 0
    for xb, yb in train_loader:
        optimizer.zero_grad()
        pred = model(xb)
        loss = criterion(pred, yb)
        loss.backward()
        optimizer.step()
        total_train_loss += loss.item()

    model.eval()
    total_val_loss = 0
    with torch.no_grad():
        for xb, yb in val_loader:
            pred = model(xb)
            val_loss = criterion(pred, yb)
            total_val_loss += val_loss.item()

    avg_train_loss = total_train_loss / len(train_loader)
    avg_val_loss = total_val_loss / len(val_loader)
    train_losses.append(avg_train_loss)
    val_losses.append(avg_val_loss)

    if epoch % 10 == 0:
        print(f"Epoch {epoch}: Train Loss = {avg_train_loss:.4f}, Val Loss = {avg_val_loss:.4f}")
# Out:
# Epoch 0: Train Loss = 0.3777, Val Loss = 0.1000
# Epoch 10: Train Loss = 0.0847, Val Loss = 0.0632
# Epoch 20: Train Loss = 0.0613, Val Loss = 0.0489
# Epoch 30: Train Loss = 0.0515, Val Loss = 0.0427
# Epoch 40: Train Loss = 0.0426, Val Loss = 0.0394
# Epoch 50: Train Loss = 0.0460, Val Loss = 0.0326
# Epoch 60: Train Loss = 0.0377, Val Loss = 0.0420
# Epoch 70: Train Loss = 0.0377, Val Loss = 0.0396
# Epoch 80: Train Loss = 0.0323, Val Loss = 0.0311
# Epoch 90: Train Loss = 0.0340, Val Loss = 0.0291
# Epoch 100: Train Loss = 0.0428, Val Loss = 0.0352
# Epoch 110: Train Loss = 0.0309, Val Loss = 0.0183
# Epoch 120: Train Loss = 0.0132, Val Loss = 0.0223
# Epoch 130: Train Loss = 0.0218, Val Loss = 0.0168
# Epoch 140: Train Loss = 0.0359, Val Loss = 0.0223
# Epoch 150: Train Loss = 0.0241, Val Loss = 0.0066
# Epoch 160: Train Loss = 0.0084, Val Loss = 0.0039
# Epoch 170: Train Loss = 0.0188, Val Loss = 0.0041
# Epoch 180: Train Loss = 0.0164, Val Loss = 0.0079
# Epoch 190: Train Loss = 0.0139, Val Loss = 0.0077

# %%
end_time = time.time()

# --- Plot Training vs Validation Loss ---
plt.figure(figsize=(8, 4))
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# --- Final Test on Unseen Initial Condition + F-statistic ---
model.eval()
with torch.no_grad():
    pred_test = model(X_test_tensor).squeeze(0).numpy()

rmse = np.sqrt(mean_squared_error(y_test, pred_test))
r2 = r2_score(y_test, pred_test)
print(f"\nTest RMSE (IC={test_ic}): {rmse:.4f}")
print(f"Test R² (IC={test_ic}):   {r2:.4f}")

# --- F-statistic and p-value ---
n = len(y_test)
k = X_test.shape[1]  # number of predictors = 2
F_stat = (r2 / k) / ((1 - r2) / (n - k - 1))
p_value = 1 - f_dist.cdf(F_stat, k, n - k - 1)

print(f"F-statistic: {F_stat:.4f}")
print(f"P-value:     {p_value:.4e}")

print(f"Total Runtime: {end_time - start_time:.2f} seconds")

# --- Plot Test Prediction ---
plt.figure(figsize=(10, 5))
plt.plot(y_test, label='True')
plt.plot(pred_test, label='Predicted', linestyle='--')
plt.title(f"GRU Prediction on Unseen Initial Condition x₀ = {test_ic}")
plt.xlabel("Time Step")
plt.ylabel("x(t)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# --- Prediction Divergence / Horizon ---
errors = np.abs(pred_test - y_test)            # abs error
rmse_window = np.sqrt((pred_test - y_test)**2) # RMSE error

def moving_avg(x, w=10):
    return np.convolve(x, np.ones(w)/w, mode='valid')

window_size = 10
smoothed_error = moving_avg(errors, w=window_size)
smoothed_rmse = moving_avg(rmse_window, w=window_size)

plt.figure(figsize=(10, 4))
plt.plot(smoothed_error, label="Abs Error (Smoothed)", alpha=0.8)
plt.plot(smoothed_rmse, label="RMSE (Smoothed)", alpha=0.8)
plt.axhline(y=0.05, color='r', linestyle='--', label='Error Threshold (0.05)')
plt.title("Prediction Divergence Over Time")
plt.xlabel("Time Step")
plt.ylabel("Prediction Error")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

threshold = 0.05
divergence_time = np.argmax(smoothed_error > threshold) + window_size
print(f"Prediction horizon at threshold {threshold}: {divergence_time} steps")

print(f"Total runtime: {time.time() - start_time:.2f} seconds")
# Out:
# Test RMSE (IC=1.2): 0.0332
# Test R² (IC=1.2):   0.9845
# F-statistic: 6242.4390
# P-value:     1.1102e-16
# Total Runtime: 189.83 seconds
# Prediction horizon at threshold 0.05: 167 steps
# Total runtime: 190.36 seconds

# %%
import torch
from torch.utils.data import DataLoader

# Use CUDA if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Expanded hyperparameter search space
hidden_sizes = [32, 64, 128, 256]
num_layers_list = [1, 2, 3]
learning_rates = [1e-2, 5e-3, 1e-3, 5e-4, 1e-4]
batch_sizes = [4, 8, 16]
dropouts = [0.0, 0.2, 0.4]

# Redefine GRU model class to accept dropout
class GRUNet(nn.Module):
    def __init__(self, input_size=2, hidden_size=64, num_layers=2, dropout=0.0):
        super(GRUNet, self).__init__()
        self.gru = nn.GRU(input_size, hidden_size, num_layers,
                            batch_first=True, dropout=dropout if num_layers > 1 else 0.0)
        self.linear = nn.Linear(hidden_size, 1)

    def forward(self, x):
        out, _ = self.gru(x)
        out = self.linear(out).squeeze(-1)
        return out

# Grid search
best_model = None
best_loss = float("inf")
best_config = None

for h in hidden_sizes:
    for l in num_layers_list:
        for lr in learning_rates:
            for bs in batch_sizes:
                for do in dropouts:
                    print(f"\nTraining: hidden={h}, layers={l}, lr={lr}, batch={bs}, dropout={do}")

                    # Define model, optimizer, dataloader
                    model = GRUNet(hidden_size=h, num_layers=l, dropout=do).to(device)
                    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
                    train_loader = DataLoader(train_dataset, batch_size=bs, shuffle=True)

                    # Train for a few quick epochs
                    for epoch in range(15):
                        model.train()
                        for xb, yb in train_loader:
                            xb, yb = xb.to(device), yb.to(device)
                            optimizer.zero_grad()
                            output = model(xb)
                            loss = criterion(output, yb)
                            loss.backward()
                            optimizer.step()

                    # Evaluate on validation set
                    model.eval()
                    val_loss = 0
                    with torch.no_grad():
                        for xb, yb in val_loader:
                            xb, yb = xb.to(device), yb.to(device)
                            val_loss += criterion(model(xb), yb).item()
                    val_loss /= len(val_loader)
                    print(f"Val Loss: {val_loss:.5f}")

                    # Save best model
                    if val_loss < best_loss:
                        best_loss = val_loss
                        best_model = model
                        best_config = (h, l, lr, bs, do)

print(f"\n✅ Best Config: Hidden={best_config[0]}, Layers={best_config[1]}, "
      f"LR={best_config[2]}, Batch={best_config[3]}, Dropout={best_config[4]} "
      f"→ Val Loss={best_loss:.5f}")
# Out:
# Using device: cuda
#
# Training: hidden=32, layers=1, lr=0.01, batch=4, dropout=0.0
# Val Loss: 0.05273
#
# Training: hidden=32, layers=1, lr=0.01, batch=4, dropout=0.2
# Val Loss: 0.05381
#
# Training: hidden=32, layers=1, lr=0.01, batch=4, dropout=0.4
# Val Loss: 0.05038
#
# Training: hidden=32, layers=1, lr=0.01, batch=8, dropout=0.0
# Val Loss: 0.06058
#
# Training: hidden=32, layers=1, lr=0.01, batch=8, dropout=0.2
# Val Loss: 0.06792
#
# Training: hidden=32, layers=1, lr=0.01, batch=8, dropout=0.4
# Val Loss: 0.05674
#
# Training: hidden=32, layers=1, lr=0.01, batch=16, dropout=0.0
# Val Loss: 0.07396
#
# Training: hidden=32, layers=1, lr=0.01, batch=16, dropout=0.2
# Val Loss: 0.06807
#
# Training: hidden=32, layers=1, lr=0.01, batch=16, dropout=0.4
# Val Loss: 0.06966
#
# Training: hidden=32, layers=1, lr=0.005, batch=4, dropout=0.0
# Val Loss: 0.05962
#
# Training: hidden=32, layers=1, lr=0.005, batch=4, dropout=0.2
# Val Loss: 0.05949
#
# Training: hidden=32, layers=1, lr=0.005, batch=4, dropout=0.4
# Val Loss: 0.05826
#
# Training: hidden=32, layers=1, lr=0.005, batch=8, dropout=0.0
# Val Loss: 0.06856
#
# Training: hidden=32, layers=1, lr=0.005, batch=8, dropout=0.2
# Val Loss: 0.07309
#
# Training: hidden=32, layers=1, lr=0.005, batch=8, dropout=0.4
# Val Loss: 0.07573
#
# Training: hidden=32, layers=1, lr=0.005, batch=16, dropout=0.0
# Val Loss: 0.08662
#
# Training: hidden=32, layers=1, lr=0.005, batch=16, dropout=0.2
# Val Loss: 0.08325
#
# Training: hidden=32, layers=1, lr=0.005, batch=16, dropout=0.4
# Val Loss: 0.08514
#
# Training: hidden=32, layers=1, lr=0.001, batch=4, dropout=0.0
# Val Loss: 0.08141
#
# Training: hidden=32, layers=1, lr=0.001, batch=4, dropout=0.2
# Val Loss: 0.07775
#
# Training: hidden=32, layers=1, lr=0.001, batch=4, dropout=0.4
# Val Loss: 0.07836
#
# Training: hidden=32, layers=1, lr=0.001, batch=8, dropout=0.0
# Val Loss: 0.08154
#
# Training: hidden=32, layers=1, lr=0.001, batch=8, dropout=0.2
# Val Loss: 0.09820
#
# Training: hidden=32, layers=1, lr=0.001, batch=8, dropout=0.4
# Val Loss: 0.08490
#
# Training: hidden=32, layers=1, lr=0.001, batch=16, dropout=0.0
# Val Loss: 0.11771
#
# Training: hidden=32, layers=1, lr=0.001, batch=16, dropout=0.2
# Val Loss: 0.08745
#
# Training: hidden=32, layers=1, lr=0.001, batch=16, dropout=0.4
# Val Loss: 0.08121
#
# Training: hidden=32, layers=1, lr=0.0005, batch=4, dropout=0.0
# Val Loss: 0.07935
#
# Training: hidden=32, layers=1, lr=0.0005, batch=4, dropout=0.2
# Val Loss: 0.08241
#
# Training: hidden=32, layers=1, lr=0.0005, batch=4, dropout=0.4
# Val Loss: 0.07917
#
# Training: hidden=32, layers=1, lr=0.0005, batch=8, dropout=0.0
# Val Loss: 0.09107
#
# Training: hidden=32, layers=1, lr=0.0005, batch=8, dropout=0.2
# Val Loss: 0.21283
#
# Training: hidden=32, layers=1, lr=0.0005, batch=8, dropout=0.4
# Val Loss: 0.13195
#
# Training: hidden=32, layers=1, lr=0.0005, batch=16, dropout=0.0
# Val Loss: 0.23880
#
# Training: hidden=32, layers=1, lr=0.0005, batch=16, dropout=0.2
# Val Loss: 0.26475
#
# Training: hidden=32, layers=1, lr=0.0005, batch=16, dropout=0.4
# Val Loss: 0.37643
#
# Training: hidden=32, layers=1, lr=0.0001, batch=4, dropout=0.0
# Val Loss: 0.70213
#
# Training: hidden=32, layers=1, lr=0.0001, batch=4, dropout=0.2
# Val Loss: 0.52624
#
# Training: hidden=32, layers=1, lr=0.0001, batch=4, dropout=0.4
# Val Loss: 0.38563
#
# Training: hidden=32, layers=1, lr=0.0001, batch=8, dropout=0.0
# Val Loss: 0.69554
#
# Training: hidden=32, layers=1, lr=0.0001, batch=8, dropout=0.2
# Val Loss: 1.31520
#
# Training: hidden=32, layers=1, lr=0.0001, batch=8, dropout=0.4
# Val Loss: 0.95688
#
# Training: hidden=32, layers=1, lr=0.0001, batch=16, dropout=0.0
# Val Loss: 0.68609
#
# Training: hidden=32, layers=1, lr=0.0001, batch=16, dropout=0.2
# Val Loss: 0.82915
#
# Training: hidden=32, layers=1, lr=0.0001, batch=16, dropout=0.4
# Val Loss: 0.89230
#
# Training: hidden=32, layers=2, lr=0.01, batch=4, dropout=0.0
# Val Loss: 0.04641
#
# Training: hidden=32, layers=2, lr=0.01, batch=4, dropout=0.2
# Val Loss: 0.05124
#
# Training: hidden=32, layers=2, lr=0.01, batch=4, dropout=0.4
# Val Loss: 0.05172
#
# Training: hidden=32, layers=2, lr=0.01, batch=8, dropout=0.0
# Val Loss: 0.06022
#
# Training: hidden=32, layers=2, lr=0.01, batch=8, dropout=0.2
# Val Loss: 0.06074
#
# Training: hidden=32, layers=2, lr=0.01, batch=8, dropout=0.4
# Val Loss: 0.06184
#
# Training: hidden=32, layers=2, lr=0.01, batch=16, dropout=0.0
# Val Loss: 0.05911
#
# Training: hidden=32, layers=2, lr=0.01, batch=16, dropout=0.2
# Val Loss: 0.06978
#
# Training: hidden=32, layers=2, lr=0.01, batch=16, dropout=0.4
# Val Loss: 0.06826
#
# Training: hidden=32, layers=2, lr=0.005, batch=4, dropout=0.0
# Val Loss: 0.05099
#
# Training: hidden=32, layers=2, lr=0.005, batch=4, dropout=0.2
# Val Loss: 0.05724
#
# Training: hidden=32, layers=2, lr=0.005, batch=4, dropout=0.4
# Val Loss: 0.05989
#
# Training: hidden=32, layers=2, lr=0.005, batch=8, dropout=0.0
# Val Loss: 0.06133
#
# Training: hidden=32, layers=2, lr=0.005, batch=8, dropout=0.2
# Val Loss: 0.05951
#
# Training: hidden=32, layers=2, lr=0.005, batch=8, dropout=0.4
# Val Loss: 0.06266
#
# Training: hidden=32, layers=2, lr=0.005, batch=16, dropout=0.0
# Val Loss: 0.07124
#
# Training: hidden=32, layers=2, lr=0.005, batch=16, dropout=0.2
# Val Loss: 0.07855
#
# Training: hidden=32, layers=2, lr=0.005, batch=16, dropout=0.4
# Val Loss: 0.06873
#
# Training: hidden=32, layers=2, lr=0.001, batch=4, dropout=0.0
# Val Loss: 0.08160
#
# Training: hidden=32, layers=2, lr=0.001, batch=4, dropout=0.2
# Val Loss: 0.07971
#
# Training: hidden=32, layers=2, lr=0.001, batch=4, dropout=0.4
# Val Loss: 0.07371
#
# Training: hidden=32, layers=2, lr=0.001, batch=8, dropout=0.0
# Val Loss: 0.08274
#
# Training: hidden=32, layers=2, lr=0.001, batch=8, dropout=0.2
# Val Loss: 0.08059
#
# Training: hidden=32, layers=2, lr=0.001, batch=8, dropout=0.4
# Val Loss: 0.08472
#
# Training: hidden=32, layers=2, lr=0.001, batch=16, dropout=0.0
# Val Loss: 0.09065
#
# Training: hidden=32, layers=2, lr=0.001, batch=16, dropout=0.2
# Val Loss: 0.09111
#
# Training: hidden=32, layers=2, lr=0.001, batch=16, dropout=0.4
# Val Loss: 0.09272
#
# Training: hidden=32, layers=2, lr=0.0005, batch=4, dropout=0.0
# Val Loss: 0.08082
#
# Training: hidden=32, layers=2, lr=0.0005, batch=4, dropout=0.2
# Val Loss: 0.08527
#
# Training: hidden=32, layers=2, lr=0.0005, batch=4, dropout=0.4
# Val Loss: 0.08817
#
# Training: hidden=32, layers=2, lr=0.0005, batch=8, dropout=0.0
# Val Loss: 0.08989
#
# Training: hidden=32, layers=2, lr=0.0005, batch=8, dropout=0.2
# Val Loss: 0.08450
#
# Training: hidden=32, layers=2, lr=0.0005, batch=8, dropout=0.4
# Val Loss: 0.08899
#
# Training: hidden=32, layers=2, lr=0.0005, batch=16, dropout=0.0
# Val Loss: 0.24153
#
# Training: hidden=32, layers=2, lr=0.0005, batch=16, dropout=0.2
# Val Loss: 0.11126
#
# Training: hidden=32, layers=2, lr=0.0005, batch=16, dropout=0.4
# Val Loss: 0.09931
#
# Training: hidden=32, layers=2, lr=0.0001, batch=4, dropout=0.0
# Val Loss: 0.62358
#
# Training: hidden=32, layers=2, lr=0.0001, batch=4, dropout=0.2
# Val Loss: 0.23971
#
# Training: hidden=32, layers=2, lr=0.0001, batch=4, dropout=0.4
# Val Loss: 0.16804
#
# Training: hidden=32, layers=2, lr=0.0001, batch=8, dropout=0.0
# Val Loss: 0.44807
#
# Training: hidden=32, layers=2, lr=0.0001, batch=8, dropout=0.2
# Val Loss: 0.67498
#
# Training: hidden=32, layers=2, lr=0.0001, batch=8, dropout=0.4
# Val Loss: 0.48016
#
# Training: hidden=32, layers=2, lr=0.0001, batch=16, dropout=0.0
# Val Loss: 0.64966
#
# Training: hidden=32, layers=2, lr=0.0001, batch=16, dropout=0.2
# Val Loss: 0.56007
#
# Training: hidden=32, layers=2, lr=0.0001, batch=16, dropout=0.4
# Val Loss: 0.55580
#
# Training: hidden=32, layers=3, lr=0.01, batch=4, dropout=0.0
# Val Loss: 0.09676
#
# Training: hidden=32, layers=3, lr=0.01, batch=4, dropout=0.2
# Val Loss: 0.05047
#
# Training: hidden=32, layers=3, lr=0.01, batch=4, dropout=0.4
# Val Loss: 0.05340
#
# Training: hidden=32, layers=3, lr=0.01, batch=8, dropout=0.0
# Val Loss: 0.04935
#
# Training: hidden=32, layers=3, lr=0.01, batch=8, dropout=0.2
# Val Loss: 0.05875
#
# Training: hidden=32, layers=3, lr=0.01, batch=8, dropout=0.4
# Val Loss: 0.06521
#
# Training: hidden=32, layers=3, lr=0.01, batch=16, dropout=0.0
# Val Loss: 0.06339
#
# Training: hidden=32, layers=3, lr=0.01, batch=16, dropout=0.2
# Val Loss: 0.06412
#
# Training: hidden=32, layers=3, lr=0.01, batch=16, dropout=0.4
# Val Loss: 0.06544
#
# Training: hidden=32, layers=3, lr=0.005, batch=4, dropout=0.0
# Val Loss: 0.05519
#
# Training: hidden=32, layers=3, lr=0.005, batch=4, dropout=0.2
# Val Loss: 0.04937
#
# Training: hidden=32, layers=3, lr=0.005, batch=4, dropout=0.4
# Val Loss: 0.05175
#
# Training: hidden=32, layers=3, lr=0.005, batch=8, dropout=0.0
# Val Loss: 0.06240
#
# Training: hidden=32, layers=3, lr=0.005, batch=8, dropout=0.2
# Val Loss: 0.05973
#
# Training: hidden=32, layers=3, lr=0.005, batch=8, dropout=0.4
# Val Loss: 0.06162
#
# Training: hidden=32, layers=3, lr=0.005, batch=16, dropout=0.0
# Val Loss: 0.07415
#
# Training: hidden=32, layers=3, lr=0.005, batch=16, dropout=0.2
# Val Loss: 0.06979
#
# Training: hidden=32, layers=3, lr=0.005, batch=16, dropout=0.4
# Val Loss: 0.06687
#
# Training: hidden=32, layers=3, lr=0.001, batch=4, dropout=0.0
# Val Loss: 0.07018
#
# Training: hidden=32, layers=3, lr=0.001, batch=4, dropout=0.2
# Val Loss: 0.06962
#
# Training: hidden=32, layers=3, lr=0.001, batch=4, dropout=0.4
# Val Loss: 0.07533
#
# Training: hidden=32, layers=3, lr=0.001, batch=8, dropout=0.0
# Val Loss: 0.08804
#
# Training: hidden=32, layers=3, lr=0.001, batch=8, dropout=0.2
# Val Loss: 0.07982
#
# Training: hidden=32, layers=3, lr=0.001, batch=8, dropout=0.4
# Val Loss: 0.08225
#
# Training: hidden=32, layers=3, lr=0.001, batch=16, dropout=0.0
# Val Loss: 0.09345
#
# Training: hidden=32, layers=3, lr=0.001, batch=16, dropout=0.2
# Val Loss: 0.08117
#
# Training: hidden=32, layers=3, lr=0.001, batch=16, dropout=0.4
# Val Loss: 0.08969
#
# Training: hidden=32, layers=3, lr=0.0005, batch=4, dropout=0.0
# Val Loss: 0.08493
#
# Training: hidden=32, layers=3, lr=0.0005, batch=4, dropout=0.2
# Val Loss: 0.08513
#
# Training: hidden=32, layers=3, lr=0.0005, batch=4, dropout=0.4
# Val Loss: 0.08420
#
# Training: hidden=32, layers=3, lr=0.0005, batch=8, dropout=0.0
# Val Loss: 0.09071
#
# Training: hidden=32, layers=3, lr=0.0005, batch=8, dropout=0.2
# Val Loss: 0.08257
#
# Training: hidden=32, layers=3, lr=0.0005, batch=8, dropout=0.4
# Val Loss: 0.09001
#
# Training: hidden=32, layers=3, lr=0.0005, batch=16, dropout=0.0
# Val Loss: 0.07827
#
# Training: hidden=32, layers=3, lr=0.0005, batch=16, dropout=0.2
# Val Loss: 0.08022
#
# Training: hidden=32, layers=3, lr=0.0005, batch=16, dropout=0.4
# Val Loss: 0.08305
#
# Training: hidden=32, layers=3, lr=0.0001, batch=4, dropout=0.0
# Val Loss: 0.11363
#
# Training: hidden=32, layers=3, lr=0.0001, batch=4, dropout=0.2
# Val Loss: 0.20333
#
# Training: hidden=32, layers=3, lr=0.0001, batch=4, dropout=0.4
# Val Loss: 0.31441
#
# Training: hidden=32, layers=3, lr=0.0001, batch=8, dropout=0.0
# Val Loss: 0.39097
#
# Training: hidden=32, layers=3, lr=0.0001, batch=8, dropout=0.2
# Val Loss: 0.33579
#
# Training: hidden=32, layers=3, lr=0.0001, batch=8, dropout=0.4
# Val Loss: 0.68926
#
# Training: hidden=32, layers=3, lr=0.0001, batch=16, dropout=0.0
# Val Loss: 0.84856
#
# Training: hidden=32, layers=3, lr=0.0001, batch=16, dropout=0.2
# Val Loss: 0.43005
#
# Training: hidden=32, layers=3, lr=0.0001, batch=16, dropout=0.4
# Val Loss: 0.38870
#
# Training: hidden=64, layers=1, lr=0.01, batch=4, dropout=0.0
# Val Loss: 0.04953
#
# Training: hidden=64, layers=1, lr=0.01, batch=4, dropout=0.2
# Val Loss: 0.05409
#
# Training: hidden=64, layers=1, lr=0.01, batch=4, dropout=0.4
# Val Loss: 0.05608
#
# Training: hidden=64, layers=1, lr=0.01, batch=8, dropout=0.0
# Val Loss: 0.06117
#
# Training: hidden=64, layers=1, lr=0.01, batch=8, dropout=0.2
# Val Loss: 0.05134
#
# Training: hidden=64, layers=1, lr=0.01, batch=8, dropout=0.4
# Val Loss: 0.05225
#
# Training: hidden=64, layers=1, lr=0.01, batch=16, dropout=0.0
# Val Loss: 0.07128
#
# Training: hidden=64, layers=1, lr=0.01, batch=16, dropout=0.2
# Val Loss: 0.06644
#
# Training: hidden=64, layers=1, lr=0.01, batch=16, dropout=0.4
# Val Loss: 0.06652
#
# Training: hidden=64, layers=1, lr=0.005, batch=4, dropout=0.0
# Val Loss: 0.06310
#
# Training: hidden=64, layers=1, lr=0.005, batch=4, dropout=0.2
# Val Loss: 0.05870
#
# Training: hidden=64, layers=1, lr=0.005, batch=4, dropout=0.4
# Val Loss: 0.05252
#
# Training: hidden=64, layers=1, lr=0.005, batch=8, dropout=0.0
# Val Loss: 0.06345
#
# Training: hidden=64, layers=1, lr=0.005, batch=8, dropout=0.2
# Val Loss: 0.06676
#
# Training: hidden=64, layers=1, lr=0.005, batch=8, dropout=0.4
# Val Loss: 0.05866
#
# Training: hidden=64, layers=1, lr=0.005, batch=16, dropout=0.0
# Val Loss: 0.06609
#
# Training: hidden=64, layers=1, lr=0.005, batch=16, dropout=0.2
# Val Loss: 0.07416
#
# Training: hidden=64, layers=1, lr=0.005, batch=16, dropout=0.4
# Val Loss: 0.07808
#
# Training: hidden=64, layers=1, lr=0.001, batch=4, dropout=0.0
# Val Loss: 0.08340
#
# Training: hidden=64, layers=1, lr=0.001, batch=4, dropout=0.2
# Val Loss: 0.08587
#
# Training: hidden=64, layers=1, lr=0.001, batch=4, dropout=0.4
# Val Loss: 0.07930
#
# Training: hidden=64, layers=1, lr=0.001, batch=8, dropout=0.0
# Val Loss: 0.08469
#
# Training: hidden=64, layers=1, lr=0.001, batch=8, dropout=0.2
# Val Loss: 0.08318
#
# Training: hidden=64, layers=1, lr=0.001, batch=8, dropout=0.4
# Val Loss: 0.08521
#
# Training: hidden=64, layers=1, lr=0.001, batch=16, dropout=0.0
# Val Loss: 0.10565
#
# Training: hidden=64, layers=1, lr=0.001, batch=16, dropout=0.2
# Val Loss: 0.08865
#
# Training: hidden=64, layers=1, lr=0.001, batch=16, dropout=0.4
# Val Loss: 0.10964
#
# Training: hidden=64, layers=1, lr=0.0005, batch=4, dropout=0.0
# Val Loss: 0.08728
#
# Training: hidden=64, layers=1, lr=0.0005, batch=4, dropout=0.2
# Val Loss: 0.08094
#
# Training: hidden=64, layers=1, lr=0.0005, batch=4, dropout=0.4
# Val Loss: 0.09133
#
# Training: hidden=64, layers=1, lr=0.0005, batch=8, dropout=0.0
# Val Loss: 0.09319
#
# Training: hidden=64, layers=1, lr=0.0005, batch=8, dropout=0.2
# Val Loss: 0.08644
#
# Training: hidden=64, layers=1, lr=0.0005, batch=8, dropout=0.4
# Val Loss: 0.09354
#
# Training: hidden=64, layers=1, lr=0.0005, batch=16, dropout=0.0
# Val Loss: 0.13902
#
# Training: hidden=64, layers=1, lr=0.0005, batch=16, dropout=0.2
# Val Loss: 0.31420
#
# Training: hidden=64, layers=1, lr=0.0005, batch=16, dropout=0.4
# Val Loss: 0.09126
#
# Training: hidden=64, layers=1, lr=0.0001, batch=4, dropout=0.0
# Val Loss: 0.37833
#
# Training: hidden=64, layers=1, lr=0.0001, batch=4, dropout=0.2
# Val Loss: 0.27241
#
# Training: hidden=64, layers=1, lr=0.0001, batch=4, dropout=0.4
# Val Loss: 0.38064
#
# Training: hidden=64, layers=1, lr=0.0001, batch=8, dropout=0.0
# Val Loss: 0.54899
#
# Training: hidden=64, layers=1, lr=0.0001, batch=8, dropout=0.2
# Val Loss: 0.69549
#
# Training: hidden=64, layers=1, lr=0.0001, batch=8, dropout=0.4
# Val Loss: 0.51615
#
# Training: hidden=64, layers=1, lr=0.0001, batch=16, dropout=0.0
# Val Loss: 0.76308
#
# Training: hidden=64, layers=1, lr=0.0001, batch=16, dropout=0.2
# Val Loss: 0.91760
#
# Training: hidden=64, layers=1, lr=0.0001, batch=16, dropout=0.4
# Val Loss: 0.60949
#
# Training: hidden=64, layers=2, lr=0.01, batch=4, dropout=0.0
# Val Loss: 0.04804
#
# Training: hidden=64, layers=2, lr=0.01, batch=4, dropout=0.2
# Val Loss: 0.05050
#
# Training: hidden=64, layers=2, lr=0.01, batch=4, dropout=0.4
# Val Loss: 0.04920
#
# Training: hidden=64, layers=2, lr=0.01, batch=8, dropout=0.0
# Val Loss: 0.05194
#
# Training: hidden=64, layers=2, lr=0.01, batch=8, dropout=0.2
# Val Loss: 0.05219
#
# Training: hidden=64, layers=2, lr=0.01, batch=8, dropout=0.4
# Val Loss: 0.05950
#
# Training: hidden=64, layers=2, lr=0.01, batch=16, dropout=0.0
# Val Loss: 0.09194
#
# Training: hidden=64, layers=2, lr=0.01, batch=16, dropout=0.2
# Val Loss: 0.06495
#
# Training: hidden=64, layers=2, lr=0.01, batch=16, dropout=0.4
# Val Loss: 0.06169
#
# Training: hidden=64, layers=2, lr=0.005, batch=4, dropout=0.0
# Val Loss: 0.05489
#
# Training: hidden=64, layers=2, lr=0.005, batch=4, dropout=0.2
# Val Loss: 0.05264
#
# Training: hidden=64, layers=2, lr=0.005, batch=4, dropout=0.4
# Val Loss: 0.05342
#
# Training: hidden=64, layers=2, lr=0.005, batch=8, dropout=0.0
# Val Loss: 0.07737
#
# Training: hidden=64, layers=2, lr=0.005, batch=8, dropout=0.2
# Val Loss: 0.06793
#
# Training: hidden=64, layers=2, lr=0.005, batch=8, dropout=0.4
# Val Loss: 0.06136
#
# Training: hidden=64, layers=2, lr=0.005, batch=16, dropout=0.0
# Val Loss: 0.06606
#
# Training: hidden=64, layers=2, lr=0.005, batch=16, dropout=0.2
# Val Loss: 0.06486
#
# Training: hidden=64, layers=2, lr=0.005, batch=16, dropout=0.4
# Val Loss: 0.06233
#
# Training: hidden=64, layers=2, lr=0.001, batch=4, dropout=0.0
# Val Loss: 0.06511
#
# Training: hidden=64, layers=2, lr=0.001, batch=4, dropout=0.2
# Val Loss: 0.06805
#
# Training: hidden=64, layers=2, lr=0.001, batch=4, dropout=0.4
# Val Loss: 0.06815
#
# Training: hidden=64, layers=2, lr=0.001, batch=8, dropout=0.0
# Val Loss: 0.07982
#
# Training: hidden=64, layers=2, lr=0.001, batch=8, dropout=0.2
# Val Loss: 0.07986
#
# Training: hidden=64, layers=2, lr=0.001, batch=8, dropout=0.4
# Val Loss: 0.07897
#
# Training: hidden=64, layers=2, lr=0.001, batch=16, dropout=0.0
# Val Loss: 0.08028
#
# Training: hidden=64, layers=2, lr=0.001, batch=16, dropout=0.2
# Val Loss: 0.08305
#
# Training: hidden=64, layers=2, lr=0.001, batch=16, dropout=0.4
# Val Loss: 0.08160
#
# Training: hidden=64, layers=2, lr=0.0005, batch=4, dropout=0.0
# Val Loss: 0.08038
#
# Training: hidden=64, layers=2, lr=0.0005, batch=4, dropout=0.2
# Val Loss: 0.07927
#
# Training: hidden=64, layers=2, lr=0.0005, batch=4, dropout=0.4
# Val Loss: 0.08399
#
# Training: hidden=64, layers=2, lr=0.0005, batch=8, dropout=0.0
# Val Loss: 0.08565
#
# Training: hidden=64, layers=2, lr=0.0005, batch=8, dropout=0.2
# Val Loss: 0.08240
#
# Training: hidden=64, layers=2, lr=0.0005, batch=8, dropout=0.4
# Val Loss: 0.08423
#
# Training: hidden=64, layers=2, lr=0.0005, batch=16, dropout=0.0
# Val Loss: 0.09548
#
# Training: hidden=64, layers=2, lr=0.0005, batch=16, dropout=0.2
# Val Loss: 0.09489
#
# Training: hidden=64, layers=2, lr=0.0005, batch=16, dropout=0.4
# Val Loss: 0.09332
#
# Training: hidden=64, layers=2, lr=0.0001, batch=4, dropout=0.0
# Val Loss: 0.08488
#
# Training: hidden=64, layers=2, lr=0.0001, batch=4, dropout=0.2
# Val Loss: 0.08387
#
# Training: hidden=64, layers=2, lr=0.0001, batch=4, dropout=0.4
# Val Loss: 0.09054
#
# Training: hidden=64, layers=2, lr=0.0001, batch=8, dropout=0.0
# Val Loss: 0.55377
#
# Training: hidden=64, layers=2, lr=0.0001, batch=8, dropout=0.2
# Val Loss: 0.24074
#
# Training: hidden=64, layers=2, lr=0.0001, batch=8, dropout=0.4
# Val Loss: 0.43857
#
# Training: hidden=64, layers=2, lr=0.0001, batch=16, dropout=0.0
# Val Loss: 0.67319
#
# Training: hidden=64, layers=2, lr=0.0001, batch=16, dropout=0.2
# Val Loss: 0.39338
#
# Training: hidden=64, layers=2, lr=0.0001, batch=16, dropout=0.4
# Val Loss: 0.48157
#
# Training: hidden=64, layers=3, lr=0.01, batch=4, dropout=0.0
# Val Loss: 0.04819
#
# Training: hidden=64, layers=3, lr=0.01, batch=4, dropout=0.2
# Val Loss: 0.04996
#
# Training: hidden=64, layers=3, lr=0.01, batch=4, dropout=0.4
# Val Loss: 0.04842
#
# Training: hidden=64, layers=3, lr=0.01, batch=8, dropout=0.0
# Val Loss: 0.05536
#
# Training: hidden=64, layers=3, lr=0.01, batch=8, dropout=0.2
# Val Loss: 0.05562
#
# Training: hidden=64, layers=3, lr=0.01, batch=8, dropout=0.4
# Val Loss: 0.06007
#
# Training: hidden=64, layers=3, lr=0.01, batch=16, dropout=0.0
# Val Loss: 0.06225
#
# Training: hidden=64, layers=3, lr=0.01, batch=16, dropout=0.2
# Val Loss: 0.05882
#
# Training: hidden=64, layers=3, lr=0.01, batch=16, dropout=0.4
# Val Loss: 0.06341
#
# Training: hidden=64, layers=3, lr=0.005, batch=4, dropout=0.0
# Val Loss: 0.05248
#
# Training: hidden=64, layers=3, lr=0.005, batch=4, dropout=0.2
# Val Loss: 0.05094
#
# Training: hidden=64, layers=3, lr=0.005, batch=4, dropout=0.4
# Val Loss: 0.05521
#
# Training: hidden=64, layers=3, lr=0.005, batch=8, dropout=0.0
# Val Loss: 0.05575
#
# Training: hidden=64, layers=3, lr=0.005, batch=8, dropout=0.2
# Val Loss: 0.05824
#
# Training: hidden=64, layers=3, lr=0.005, batch=8, dropout=0.4
# Val Loss: 0.06589
#
# Training: hidden=64, layers=3, lr=0.005, batch=16, dropout=0.0
# Val Loss: 0.06002
#
# Training: hidden=64, layers=3, lr=0.005, batch=16, dropout=0.2
# Val Loss: 0.06358
#
# Training: hidden=64, layers=3, lr=0.005, batch=16, dropout=0.4
# Val Loss: 0.06469
#
# Training: hidden=64, layers=3, lr=0.001, batch=4, dropout=0.0
# Val Loss: 0.06203
#
# Training: hidden=64, layers=3, lr=0.001, batch=4, dropout=0.2
# Val Loss: 0.06850
#
# Training: hidden=64, layers=3, lr=0.001, batch=4, dropout=0.4
# Val Loss: 0.06849
#
# Training: hidden=64, layers=3, lr=0.001, batch=8, dropout=0.0
# Val Loss: 0.07869
#
# Training: hidden=64, layers=3, lr=0.001, batch=8, dropout=0.2
# Val Loss: 0.07947
#
# Training: hidden=64, layers=3, lr=0.001, batch=8, dropout=0.4
# Val Loss: 0.08083
#
# Training: hidden=64, layers=3, lr=0.001, batch=16, dropout=0.0
# Val Loss: 0.08451
#
# Training: hidden=64, layers=3, lr=0.001, batch=16, dropout=0.2
# Val Loss: 0.08404
#
# Training: hidden=64, layers=3, lr=0.001, batch=16, dropout=0.4
# Val Loss: 0.08731
#
# Training: hidden=64, layers=3, lr=0.0005, batch=4, dropout=0.0
# Val Loss: 0.08124
#
# Training: hidden=64, layers=3, lr=0.0005, batch=4, dropout=0.2
# Val Loss: 0.08485
#
# Training: hidden=64, layers=3, lr=0.0005, batch=4, dropout=0.4
# Val Loss: 0.08123
#
# Training: hidden=64, layers=3, lr=0.0005, batch=8, dropout=0.0
# Val Loss: 0.08135
#
# Training: hidden=64, layers=3, lr=0.0005, batch=8, dropout=0.2
# Val Loss: 0.08873
#
# Training: hidden=64, layers=3, lr=0.0005, batch=8, dropout=0.4
# Val Loss: 0.08804
#
# Training: hidden=64, layers=3, lr=0.0005, batch=16, dropout=0.0
# Val Loss: 0.09436
#
# Training: hidden=64, layers=3, lr=0.0005, batch=16, dropout=0.2
# Val Loss: 0.09192
#
# Training: hidden=64, layers=3, lr=0.0005, batch=16, dropout=0.4
# Val Loss: 0.09128
#
# Training: hidden=64, layers=3, lr=0.0001, batch=4, dropout=0.0
# Val Loss: 0.09013
#
# Training: hidden=64, layers=3, lr=0.0001, batch=4, dropout=0.2
# Val Loss: 0.08768
#
# Training: hidden=64, layers=3, lr=0.0001, batch=4, dropout=0.4
# Val Loss: 0.09086
#
# Training: hidden=64, layers=3, lr=0.0001, batch=8, dropout=0.0
# Val Loss: 0.10081
#
# Training: hidden=64, layers=3, lr=0.0001, batch=8, dropout=0.2
# Val Loss: 0.12785
#
# Training: hidden=64, layers=3, lr=0.0001, batch=8, dropout=0.4
# Val Loss: 0.14819
#
# Training: hidden=64, layers=3, lr=0.0001, batch=16, dropout=0.0
# Val Loss: 0.76469
#
# Training: hidden=64, layers=3, lr=0.0001, batch=16, dropout=0.2
# Val Loss: 0.37091
#
# Training: hidden=64, layers=3, lr=0.0001, batch=16, dropout=0.4
# Val Loss: 0.27309
#
# Training: hidden=128, layers=1, lr=0.01, batch=4, dropout=0.0
# Val Loss: 0.04800
#
# Training: hidden=128, layers=1, lr=0.01, batch=4, dropout=0.2
# Val Loss: 0.05525
#
# Training: hidden=128, layers=1, lr=0.01, batch=4, dropout=0.4
# Val Loss: 0.04854
#
# Training: hidden=128, layers=1, lr=0.01, batch=8, dropout=0.0
# Val Loss: 0.06328
#
# Training: hidden=128, layers=1, lr=0.01, batch=8, dropout=0.2
# Val Loss: 0.05352
#
# Training: hidden=128, layers=1, lr=0.01, batch=8, dropout=0.4
# Val Loss: 0.07008
#
# Training: hidden=128, layers=1, lr=0.01, batch=16, dropout=0.0
# Val Loss: 0.06496
#
# Training: hidden=128, layers=1, lr=0.01, batch=16, dropout=0.2
# Val Loss: 0.06341
#
# Training: hidden=128, layers=1, lr=0.01, batch=16, dropout=0.4
# Val Loss: 0.06770
#
# Training: hidden=128, layers=1, lr=0.005, batch=4, dropout=0.0
# Val Loss: 0.05055
#
# Training: hidden=128, layers=1, lr=0.005, batch=4, dropout=0.2
# Val Loss: 0.05417
#
# Training: hidden=128, layers=1, lr=0.005, batch=4, dropout=0.4
# Val Loss: 0.05450
#
# Training: hidden=128, layers=1, lr=0.005, batch=8, dropout=0.0
# Val Loss: 0.05861
#
# Training: hidden=128, layers=1, lr=0.005, batch=8, dropout=0.2
# Val Loss: 0.06408
#
# Training: hidden=128, layers=1, lr=0.005, batch=8, dropout=0.4
# Val Loss: 0.06146
#
# Training: hidden=128, layers=1, lr=0.005, batch=16, dropout=0.0
# Val Loss: 0.08042
#
# Training: hidden=128, layers=1, lr=0.005, batch=16, dropout=0.2
# Val Loss: 0.08243
#
# Training: hidden=128, layers=1, lr=0.005, batch=16, dropout=0.4
# Val Loss: 0.07447
#
# Training: hidden=128, layers=1, lr=0.001, batch=4, dropout=0.0
# Val Loss: 0.07327
#
# Training: hidden=128, layers=1, lr=0.001, batch=4, dropout=0.2
# Val Loss: 0.07268
#
# Training: hidden=128, layers=1, lr=0.001, batch=4, dropout=0.4
# Val Loss: 0.08349
#
# Training: hidden=128, layers=1, lr=0.001, batch=8, dropout=0.0
# Val Loss: 0.08245
#
# Training: hidden=128, layers=1, lr=0.001, batch=8, dropout=0.2
# Val Loss: 0.08409
#
# Training: hidden=128, layers=1, lr=0.001, batch=8, dropout=0.4
# Val Loss: 0.08437
#
# Training: hidden=128, layers=1, lr=0.001, batch=16, dropout=0.0
# Val Loss: 0.09104
#
# Training: hidden=128, layers=1, lr=0.001, batch=16, dropout=0.2
# Val Loss: 0.08462
#
# Training: hidden=128, layers=1, lr=0.001, batch=16, dropout=0.4
# Val Loss: 0.08323
#
# Training: hidden=128, layers=1, lr=0.0005, batch=4, dropout=0.0
# Val Loss: 0.08756
#
# Training: hidden=128, layers=1, lr=0.0005, batch=4, dropout=0.2
# Val Loss: 0.08346
#
# Training: hidden=128, layers=1, lr=0.0005, batch=4, dropout=0.4
# Val Loss: 0.08294
#
# Training: hidden=128, layers=1, lr=0.0005, batch=8, dropout=0.0
# Val Loss: 0.08898
#
# Training: hidden=128, layers=1, lr=0.0005, batch=8, dropout=0.2
# Val Loss: 0.09179
#
# Training: hidden=128, layers=1, lr=0.0005, batch=8, dropout=0.4
# Val Loss: 0.09814
#
# Training: hidden=128, layers=1, lr=0.0005, batch=16, dropout=0.0
# Val Loss: 0.09780
#
# Training: hidden=128, layers=1, lr=0.0005, batch=16, dropout=0.2
# Val Loss: 0.11200
#
# Training: hidden=128, layers=1, lr=0.0005, batch=16, dropout=0.4
# Val Loss: 0.10613
#
# Training: hidden=128, layers=1, lr=0.0001, batch=4, dropout=0.0
# Val Loss: 0.08864
#
# Training: hidden=128, layers=1, lr=0.0001, batch=4, dropout=0.2
# Val Loss: 0.08838
#
# Training: hidden=128, layers=1, lr=0.0001, batch=4, dropout=0.4
# Val Loss: 0.08945
#
# Training: hidden=128, layers=1, lr=0.0001, batch=8, dropout=0.0
# Val Loss: 0.30588
#
# Training: hidden=128, layers=1, lr=0.0001, batch=8, dropout=0.2
# Val Loss: 0.37742
#
# Training: hidden=128, layers=1, lr=0.0001, batch=8, dropout=0.4
# Val Loss: 0.48994
#
# Training: hidden=128, layers=1, lr=0.0001, batch=16, dropout=0.0
# Val Loss: 0.60198
#
# Training: hidden=128, layers=1, lr=0.0001, batch=16, dropout=0.2
# Val Loss: 0.70573
#
# Training: hidden=128, layers=1, lr=0.0001, batch=16, dropout=0.4
# Val Loss: 0.62193
#
# Training: hidden=128, layers=2, lr=0.01, batch=4, dropout=0.0
# Val Loss: 0.06542
#
# Training: hidden=128, layers=2, lr=0.01, batch=4, dropout=0.2
# Val Loss: 0.05302
#
# Training: hidden=128, layers=2, lr=0.01, batch=4, dropout=0.4
# Val Loss: 0.05603
#
# Training: hidden=128, layers=2, lr=0.01, batch=8, dropout=0.0
# Val Loss: 0.06052
#
# Training: hidden=128, layers=2, lr=0.01, batch=8, dropout=0.2
# Val Loss: 0.06282
#
# Training: hidden=128, layers=2, lr=0.01, batch=8, dropout=0.4
# Val Loss: 0.07203
#
# Training: hidden=128, layers=2, lr=0.01, batch=16, dropout=0.0
# Val Loss: 0.05810
#
# Training: hidden=128, layers=2, lr=0.01, batch=16, dropout=0.2
# Val Loss: 0.05747
#
# Training: hidden=128, layers=2, lr=0.01, batch=16, dropout=0.4
# Val Loss: 0.06482
#
# Training: hidden=128, layers=2, lr=0.005, batch=4, dropout=0.0
# Val Loss: 0.05219
#
# Training: hidden=128, layers=2, lr=0.005, batch=4, dropout=0.2
# Val Loss: 0.04553
#
# Training: hidden=128, layers=2, lr=0.005, batch=4, dropout=0.4
# Val Loss: 0.05605
#
# Training: hidden=128, layers=2, lr=0.005, batch=8, dropout=0.0
# Val Loss: 0.05970
#
# Training: hidden=128, layers=2, lr=0.005, batch=8, dropout=0.2
# Val Loss: 0.06501
#
# Training: hidden=128, layers=2, lr=0.005, batch=8, dropout=0.4
# Val Loss: 0.06100
#
# Training: hidden=128, layers=2, lr=0.005, batch=16, dropout=0.0
# Val Loss: 0.06126
#
# Training: hidden=128, layers=2, lr=0.005, batch=16, dropout=0.2
# Val Loss: 0.06790
#
# Training: hidden=128, layers=2, lr=0.005, batch=16, dropout=0.4
# Val Loss: 0.05816
#
# Training: hidden=128, layers=2, lr=0.001, batch=4, dropout=0.0
# Val Loss: 0.05729
#
# Training: hidden=128, layers=2, lr=0.001, batch=4, dropout=0.2
# Val Loss: 0.06188
#
# Training: hidden=128, layers=2, lr=0.001, batch=4, dropout=0.4
# Val Loss: 0.06464
#
# Training: hidden=128, layers=2, lr=0.001, batch=8, dropout=0.0
# Val Loss: 0.07691
#
# Training: hidden=128, layers=2, lr=0.001, batch=8, dropout=0.2
# Val Loss: 0.08406
#
# Training: hidden=128, layers=2, lr=0.001, batch=8, dropout=0.4
# Val Loss: 0.07419
#
# Training: hidden=128, layers=2, lr=0.001, batch=16, dropout=0.0
# Val Loss: 0.08970
#
# Training: hidden=128, layers=2, lr=0.001, batch=16, dropout=0.2
# Val Loss: 0.09036
#
# Training: hidden=128, layers=2, lr=0.001, batch=16, dropout=0.4
# Val Loss: 0.08704
#
# Training: hidden=128, layers=2, lr=0.0005, batch=4, dropout=0.0
# Val Loss: 0.07390
#
# Training: hidden=128, layers=2, lr=0.0005, batch=4, dropout=0.2
# Val Loss: 0.06992
#
# Training: hidden=128, layers=2, lr=0.0005, batch=4, dropout=0.4
# Val Loss: 0.07613
#
# Training: hidden=128, layers=2, lr=0.0005, batch=8, dropout=0.0
# Val Loss: 0.08617
#
# Training: hidden=128, layers=2, lr=0.0005, batch=8, dropout=0.2
# Val Loss: 0.08118
#
# Training: hidden=128, layers=2, lr=0.0005, batch=8, dropout=0.4
# Val Loss: 0.08320
#
# Training: hidden=128, layers=2, lr=0.0005, batch=16, dropout=0.0
# Val Loss: 0.07863
#
# Training: hidden=128, layers=2, lr=0.0005, batch=16, dropout=0.2
# Val Loss: 0.08114
#
# Training: hidden=128, layers=2, lr=0.0005, batch=16, dropout=0.4
# Val Loss: 0.08413
#
# Training: hidden=128, layers=2, lr=0.0001, batch=4, dropout=0.0
# Val Loss: 0.08945
#
# Training: hidden=128, layers=2, lr=0.0001, batch=4, dropout=0.2
# Val Loss: 0.08889
#
# Training: hidden=128, layers=2, lr=0.0001, batch=4, dropout=0.4
# Val Loss: 0.08927
#
# Training: hidden=128, layers=2, lr=0.0001, batch=8, dropout=0.0
# Val Loss: 0.08464
#
# Training: hidden=128, layers=2, lr=0.0001, batch=8, dropout=0.2
# Val Loss: 0.08437
#
# Training: hidden=128, layers=2, lr=0.0001, batch=8, dropout=0.4
# Val Loss: 0.08297
#
# Training: hidden=128, layers=2, lr=0.0001, batch=16, dropout=0.0
# Val Loss: 0.15074
#
# Training: hidden=128, layers=2, lr=0.0001, batch=16, dropout=0.2
# Val Loss: 0.27324
#
# Training: hidden=128, layers=2, lr=0.0001, batch=16, dropout=0.4
# Val Loss: 0.14738
#
# Training: hidden=128, layers=3, lr=0.01, batch=4, dropout=0.0
# Val Loss: 0.05059
#
# Training: hidden=128, layers=3, lr=0.01, batch=4, dropout=0.2
# Val Loss: 0.05963
#
# Training: hidden=128, layers=3, lr=0.01, batch=4, dropout=0.4
# Val Loss: 0.05730
#
# Training: hidden=128, layers=3, lr=0.01, batch=8, dropout=0.0
# Val Loss: 0.05184
#
# Training: hidden=128, layers=3, lr=0.01, batch=8, dropout=0.2
# Val Loss: 0.05294
#
# Training: hidden=128, layers=3, lr=0.01, batch=8, dropout=0.4
# Val Loss: 0.04903
#
# Training: hidden=128, layers=3, lr=0.01, batch=16, dropout=0.0
# Val Loss: 0.05423
#
# Training: hidden=128, layers=3, lr=0.01, batch=16, dropout=0.2
# Val Loss: 0.07037
#
# Training: hidden=128, layers=3, lr=0.01, batch=16, dropout=0.4
# Val Loss: 0.06719
#
# Training: hidden=128, layers=3, lr=0.005, batch=4, dropout=0.0
# Val Loss: 0.05853
#
# Training: hidden=128, layers=3, lr=0.005, batch=4, dropout=0.2
# Val Loss: 0.05542
#
# Training: hidden=128, layers=3, lr=0.005, batch=4, dropout=0.4
# Val Loss: 0.05136
#
# Training: hidden=128, layers=3, lr=0.005, batch=8, dropout=0.0
# Val Loss: 0.06360
#
# Training: hidden=128, layers=3, lr=0.005, batch=8, dropout=0.2
# Val Loss: 0.05387
#
# Training: hidden=128, layers=3, lr=0.005, batch=8, dropout=0.4
# Val Loss: 0.05964
#
# Training: hidden=128, layers=3, lr=0.005, batch=16, dropout=0.0
# Val Loss: 0.08128
#
# Training: hidden=128, layers=3, lr=0.005, batch=16, dropout=0.2
# Val Loss: 0.06631
#
# Training: hidden=128, layers=3, lr=0.005, batch=16, dropout=0.4
# Val Loss: 0.06708
#
# Training: hidden=128, layers=3, lr=0.001, batch=4, dropout=0.0
# Val Loss: 0.06048
#
# Training: hidden=128, layers=3, lr=0.001, batch=4, dropout=0.2
# Val Loss: 0.05711
#
# Training: hidden=128, layers=3, lr=0.001, batch=4, dropout=0.4
# Val Loss: 0.06252
#
# Training: hidden=128, layers=3, lr=0.001, batch=8, dropout=0.0
# Val Loss: 0.07311
#
# Training: hidden=128, layers=3, lr=0.001, batch=8, dropout=0.2
# Val Loss: 0.07599
#
# Training: hidden=128, layers=3, lr=0.001, batch=8, dropout=0.4
# Val Loss: 0.08049
#
# Training: hidden=128, layers=3, lr=0.001, batch=16, dropout=0.0
# Val Loss: 0.07880
#
# Training: hidden=128, layers=3, lr=0.001, batch=16, dropout=0.2
# Val Loss: 0.08350
#
# Training: hidden=128, layers=3, lr=0.001, batch=16, dropout=0.4
# Val Loss: 0.08461
#
# Training: hidden=128, layers=3, lr=0.0005, batch=4, dropout=0.0
# Val Loss: 0.06569
#
# Training: hidden=128, layers=3, lr=0.0005, batch=4, dropout=0.2
# Val Loss: 0.07185
#
# Training: hidden=128, layers=3, lr=0.0005, batch=4, dropout=0.4
# Val Loss: 0.06673
#
# Training: hidden=128, layers=3, lr=0.0005, batch=8, dropout=0.0
# Val Loss: 0.08108
#
# Training: hidden=128, layers=3, lr=0.0005, batch=8, dropout=0.2
# Val Loss: 0.08178
#
# Training: hidden=128, layers=3, lr=0.0005, batch=8, dropout=0.4
# Val Loss: 0.08610
#
# Training: hidden=128, layers=3, lr=0.0005, batch=16, dropout=0.0
# Val Loss: 0.08493
#
# Training: hidden=128, layers=3, lr=0.0005, batch=16, dropout=0.2
# Val Loss: 0.08244
#
# Training: hidden=128, layers=3, lr=0.0005, batch=16, dropout=0.4
# Val Loss: 0.08726
#
# Training: hidden=128, layers=3, lr=0.0001, batch=4, dropout=0.0
# Val Loss: 0.09014
#
# Training: hidden=128, layers=3, lr=0.0001, batch=4, dropout=0.2
# Val Loss: 0.08717
#
# Training: hidden=128, layers=3, lr=0.0001, batch=4, dropout=0.4
# Val Loss: 0.08920
#
# Training: hidden=128, layers=3, lr=0.0001, batch=8, dropout=0.0
# Val Loss: 0.09328
#
# Training: hidden=128, layers=3, lr=0.0001, batch=8, dropout=0.2
# Val Loss: 0.09132
#
# Training: hidden=128, layers=3, lr=0.0001, batch=8, dropout=0.4
# Val Loss: 0.09623
#
# Training: hidden=128, layers=3, lr=0.0001, batch=16, dropout=0.0
# Val Loss: 0.09167
#
# Training: hidden=128, layers=3, lr=0.0001, batch=16, dropout=0.2
# Val Loss: 0.08104
#
# Training: hidden=128, layers=3, lr=0.0001, batch=16, dropout=0.4
# Val Loss: 0.08265
#
# Training: hidden=256, layers=1, lr=0.01, batch=4, dropout=0.0
# Val Loss: 0.09479
#
# Training: hidden=256, layers=1, lr=0.01, batch=4, dropout=0.2
# Val Loss: 0.05013
#
# Training: hidden=256, layers=1, lr=0.01, batch=4, dropout=0.4
# Val Loss: 0.09918
#
# Training: hidden=256, layers=1, lr=0.01, batch=8, dropout=0.0
# Val Loss: 0.11812
#
# Training: hidden=256, layers=1, lr=0.01, batch=8, dropout=0.2
# Val Loss: 0.17524
#
# Training: hidden=256, layers=1, lr=0.01, batch=8, dropout=0.4
# Val Loss: 0.17370
#
# Training: hidden=256, layers=1, lr=0.01, batch=16, dropout=0.0
# Val Loss: 0.07912
#
# Training: hidden=256, layers=1, lr=0.01, batch=16, dropout=0.2
# Val Loss: 0.09188
#
# Training: hidden=256, layers=1, lr=0.01, batch=16, dropout=0.4
# Val Loss: 0.07638
#
# Training: hidden=256, layers=1, lr=0.005, batch=4, dropout=0.0
# Val Loss: 0.06587
#
# Training: hidden=256, layers=1, lr=0.005, batch=4, dropout=0.2
# Val Loss: 0.05951
#
# Training: hidden=256, layers=1, lr=0.005, batch=4, dropout=0.4
# Val Loss: 0.05051
#
# Training: hidden=256, layers=1, lr=0.005, batch=8, dropout=0.0
# Val Loss: 0.06320
#
# Training: hidden=256, layers=1, lr=0.005, batch=8, dropout=0.2
# Val Loss: 0.05460
#
# Training: hidden=256, layers=1, lr=0.005, batch=8, dropout=0.4
# Val Loss: 0.06966
#
# Training: hidden=256, layers=1, lr=0.005, batch=16, dropout=0.0
# Val Loss: 0.09096
#
# Training: hidden=256, layers=1, lr=0.005, batch=16, dropout=0.2
# Val Loss: 0.07556
#
# Training: hidden=256, layers=1, lr=0.005, batch=16, dropout=0.4
# Val Loss: 0.06096
#
# Training: hidden=256, layers=1, lr=0.001, batch=4, dropout=0.0
# Val Loss: 0.06599
#
# Training: hidden=256, layers=1, lr=0.001, batch=4, dropout=0.2
# Val Loss: 0.06213
#
# Training: hidden=256, layers=1, lr=0.001, batch=4, dropout=0.4
# Val Loss: 0.07451
#
# Training: hidden=256, layers=1, lr=0.001, batch=8, dropout=0.0
# Val Loss: 0.08469
#
# Training: hidden=256, layers=1, lr=0.001, batch=8, dropout=0.2
# Val Loss: 0.07748
#
# Training: hidden=256, layers=1, lr=0.001, batch=8, dropout=0.4
# Val Loss: 0.07932
#
# Training: hidden=256, layers=1, lr=0.001, batch=16, dropout=0.0
# Val Loss: 0.09304
#
# Training: hidden=256, layers=1, lr=0.001, batch=16, dropout=0.2
# Val Loss: 0.08444
#
# Training: hidden=256, layers=1, lr=0.001, batch=16, dropout=0.4
# Val Loss: 0.07948
#
# Training: hidden=256, layers=1, lr=0.0005, batch=4, dropout=0.0
# Val Loss: 0.08017
#
# Training: hidden=256, layers=1, lr=0.0005, batch=4, dropout=0.2
# Val Loss: 0.08355
#
# Training: hidden=256, layers=1, lr=0.0005, batch=4, dropout=0.4
# Val Loss: 0.07991
#
# Training: hidden=256, layers=1, lr=0.0005, batch=8, dropout=0.0
# Val Loss: 0.08511
#
# Training: hidden=256, layers=1, lr=0.0005, batch=8, dropout=0.2
# Val Loss: 0.08423
#
# Training: hidden=256, layers=1, lr=0.0005, batch=8, dropout=0.4
# Val Loss: 0.08597
#
# Training: hidden=256, layers=1, lr=0.0005, batch=16, dropout=0.0
# Val Loss: 0.09014
#
# Training: hidden=256, layers=1, lr=0.0005, batch=16, dropout=0.2
# Val Loss: 0.08385
#
# Training: hidden=256, layers=1, lr=0.0005, batch=16, dropout=0.4
# Val Loss: 0.08495
#
# Training: hidden=256, layers=1, lr=0.0001, batch=4, dropout=0.0
# Val Loss: 0.08987
#
# Training: hidden=256, layers=1, lr=0.0001, batch=4, dropout=0.2
# Val Loss: 0.09014
#
# Training: hidden=256, layers=1, lr=0.0001, batch=4, dropout=0.4
# Val Loss: 0.08900
#
# Training: hidden=256, layers=1, lr=0.0001, batch=8, dropout=0.0
# Val Loss: 0.08940
#
# Training: hidden=256, layers=1, lr=0.0001, batch=8, dropout=0.2
# Val Loss: 0.08746
#
# Training: hidden=256, layers=1, lr=0.0001, batch=8, dropout=0.4
# Val Loss: 0.08895
#
# Training: hidden=256, layers=1, lr=0.0001, batch=16, dropout=0.0
# Val Loss: 0.43688
#
# Training: hidden=256, layers=1, lr=0.0001, batch=16, dropout=0.2
# Val Loss: 0.36847
#
# Training: hidden=256, layers=1, lr=0.0001, batch=16, dropout=0.4
# Val Loss: 0.28780
#
# Training: hidden=256, layers=2, lr=0.01, batch=4, dropout=0.0
# Val Loss: 0.10820
#
# Training: hidden=256, layers=2, lr=0.01, batch=4, dropout=0.2
# Val Loss: 0.05433
#
# Training: hidden=256, layers=2, lr=0.01, batch=4, dropout=0.4
# Val Loss: 0.08526
#
# Training: hidden=256, layers=2, lr=0.01, batch=8, dropout=0.0
# Val Loss: 0.08405
#
# Training: hidden=256, layers=2, lr=0.01, batch=8, dropout=0.2
# Val Loss: 0.06640
#
# Training: hidden=256, layers=2, lr=0.01, batch=8, dropout=0.4
# Val Loss: 0.06828
#
# Training: hidden=256, layers=2, lr=0.01, batch=16, dropout=0.0
# Val Loss: 0.07377
#
# Training: hidden=256, layers=2, lr=0.01, batch=16, dropout=0.2
# Val Loss: 0.41626
#
# Training: hidden=256, layers=2, lr=0.01, batch=16, dropout=0.4
# Val Loss: 0.11361
#
# Training: hidden=256, layers=2, lr=0.005, batch=4, dropout=0.0
# Val Loss: 0.05204
#
# Training: hidden=256, layers=2, lr=0.005, batch=4, dropout=0.2
# Val Loss: 0.05396
#
# Training: hidden=256, layers=2, lr=0.005, batch=4, dropout=0.4
# Val Loss: 0.05082
#
# Training: hidden=256, layers=2, lr=0.005, batch=8, dropout=0.0
# Val Loss: 0.06141
#
# Training: hidden=256, layers=2, lr=0.005, batch=8, dropout=0.2
# Val Loss: 0.06532
#
# Training: hidden=256, layers=2, lr=0.005, batch=8, dropout=0.4
# Val Loss: 0.06022
#
# Training: hidden=256, layers=2, lr=0.005, batch=16, dropout=0.0
# Val Loss: 0.07784
#
# Training: hidden=256, layers=2, lr=0.005, batch=16, dropout=0.2
# Val Loss: 0.07060
#
# Training: hidden=256, layers=2, lr=0.005, batch=16, dropout=0.4
# Val Loss: 0.06015
#
# Training: hidden=256, layers=2, lr=0.001, batch=4, dropout=0.0
# Val Loss: 0.06208
#
# Training: hidden=256, layers=2, lr=0.001, batch=4, dropout=0.2
# Val Loss: 0.06435
#
# Training: hidden=256, layers=2, lr=0.001, batch=4, dropout=0.4
# Val Loss: 0.06095
#
# Training: hidden=256, layers=2, lr=0.001, batch=8, dropout=0.0
# Val Loss: 0.06701
#
# Training: hidden=256, layers=2, lr=0.001, batch=8, dropout=0.2
# Val Loss: 0.06665
#
# Training: hidden=256, layers=2, lr=0.001, batch=8, dropout=0.4
# Val Loss: 0.06336
#
# Training: hidden=256, layers=2, lr=0.001, batch=16, dropout=0.0
# Val Loss: 0.08496
#
# Training: hidden=256, layers=2, lr=0.001, batch=16, dropout=0.2
# Val Loss: 0.08721
#
# Training: hidden=256, layers=2, lr=0.001, batch=16, dropout=0.4
# Val Loss: 0.08372
#
# Training: hidden=256, layers=2, lr=0.0005, batch=4, dropout=0.0
# Val Loss: 0.06767
#
# Training: hidden=256, layers=2, lr=0.0005, batch=4, dropout=0.2
# Val Loss: 0.06945
#
# Training: hidden=256, layers=2, lr=0.0005, batch=4, dropout=0.4
# Val Loss: 0.06382
#
# Training: hidden=256, layers=2, lr=0.0005, batch=8, dropout=0.0
# Val Loss: 0.08058
#
# Training: hidden=256, layers=2, lr=0.0005, batch=8, dropout=0.2
# Val Loss: 0.07840
#
# Training: hidden=256, layers=2, lr=0.0005, batch=8, dropout=0.4
# Val Loss: 0.08225
#
# Training: hidden=256, layers=2, lr=0.0005, batch=16, dropout=0.0
# Val Loss: 0.08619
#
# Training: hidden=256, layers=2, lr=0.0005, batch=16, dropout=0.2
# Val Loss: 0.08842
#
# Training: hidden=256, layers=2, lr=0.0005, batch=16, dropout=0.4
# Val Loss: 0.08975
#
# Training: hidden=256, layers=2, lr=0.0001, batch=4, dropout=0.0
# Val Loss: 0.08840
#
# Training: hidden=256, layers=2, lr=0.0001, batch=4, dropout=0.2
# Val Loss: 0.08613
#
# Training: hidden=256, layers=2, lr=0.0001, batch=4, dropout=0.4
# Val Loss: 0.08956
#
# Training: hidden=256, layers=2, lr=0.0001, batch=8, dropout=0.0
# Val Loss: 0.08997
#
# Training: hidden=256, layers=2, lr=0.0001, batch=8, dropout=0.2
# Val Loss: 0.08759
#
# Training: hidden=256, layers=2, lr=0.0001, batch=8, dropout=0.4
# Val Loss: 0.09030
#
# Training: hidden=256, layers=2, lr=0.0001, batch=16, dropout=0.0
# Val Loss: 0.08742
#
# Training: hidden=256, layers=2, lr=0.0001, batch=16, dropout=0.2
# Val Loss: 0.08861
#
# Training: hidden=256, layers=2, lr=0.0001, batch=16, dropout=0.4
# Val Loss: 0.08513
#
# Training: hidden=256, layers=3, lr=0.01, batch=4, dropout=0.0
# Val Loss: 0.15360
#
# Training: hidden=256, layers=3, lr=0.01, batch=4, dropout=0.2
# Val Loss: 0.12309
#
# Training: hidden=256, layers=3, lr=0.01, batch=4, dropout=0.4
# Val Loss: 0.05343
#
# Training: hidden=256, layers=3, lr=0.01, batch=8, dropout=0.0
# Val Loss: 0.06958
#
# Training: hidden=256, layers=3, lr=0.01, batch=8, dropout=0.2
# Val Loss: 0.09727
#
# Training: hidden=256, layers=3, lr=0.01, batch=8, dropout=0.4
# Val Loss: 0.06314
#
# Training: hidden=256, layers=3, lr=0.01, batch=16, dropout=0.0
# Val Loss: 0.14346
#
# Training: hidden=256, layers=3, lr=0.01, batch=16, dropout=0.2
# Val Loss: 0.08569
#
# Training: hidden=256, layers=3, lr=0.01, batch=16, dropout=0.4
# Val Loss: 0.07179
#
# Training: hidden=256, layers=3, lr=0.005, batch=4, dropout=0.0
# Val Loss: 0.05097
#
# Training: hidden=256, layers=3, lr=0.005, batch=4, dropout=0.2
# Val Loss: 0.05230
#
# Training: hidden=256, layers=3, lr=0.005, batch=4, dropout=0.4
# Val Loss: 0.05208
#
# Training: hidden=256, layers=3, lr=0.005, batch=8, dropout=0.0
# Val Loss: 0.05094
#
# Training: hidden=256, layers=3, lr=0.005, batch=8, dropout=0.2
# Val Loss: 0.05046
#
# Training: hidden=256, layers=3, lr=0.005, batch=8, dropout=0.4
# Val Loss: 0.06054
#
# Training: hidden=256, layers=3, lr=0.005, batch=16, dropout=0.0
# Val Loss: 0.05228
#
# Training: hidden=256, layers=3, lr=0.005, batch=16, dropout=0.2
# Val Loss: 0.06458
#
# Training: hidden=256, layers=3, lr=0.005, batch=16, dropout=0.4
# Val Loss: 0.05510
#
# Training: hidden=256, layers=3, lr=0.001, batch=4, dropout=0.0
# Val Loss: 0.05999
#
# Training: hidden=256, layers=3, lr=0.001, batch=4, dropout=0.2
# Val Loss: 0.05764
#
# Training: hidden=256, layers=3, lr=0.001, batch=4, dropout=0.4
# Val Loss: 0.05895
#
# Training: hidden=256, layers=3, lr=0.001, batch=8, dropout=0.0
# Val Loss: 0.06127
#
# Training: hidden=256, layers=3, lr=0.001, batch=8, dropout=0.2
# Val Loss: 0.07018
#
# Training: hidden=256, layers=3, lr=0.001, batch=8, dropout=0.4
# Val Loss: 0.06416
#
# Training: hidden=256, layers=3, lr=0.001, batch=16, dropout=0.0
# Val Loss: 0.08489
#
# Training: hidden=256, layers=3, lr=0.001, batch=16, dropout=0.2
# Val Loss: 0.07945
#
# Training: hidden=256, layers=3, lr=0.001, batch=16, dropout=0.4
# Val Loss: 0.07723
#
# Training: hidden=256, layers=3, lr=0.0005, batch=4, dropout=0.0
# Val Loss: 0.07294
#
# Training: hidden=256, layers=3, lr=0.0005, batch=4, dropout=0.2
# Val Loss: 0.06748
#
# Training: hidden=256, layers=3, lr=0.0005, batch=4, dropout=0.4
# Val Loss: 0.07413
#
# Training: hidden=256, layers=3, lr=0.0005, batch=8, dropout=0.0
# Val Loss: 0.08118
#
# Training: hidden=256, layers=3, lr=0.0005, batch=8, dropout=0.2
# Val Loss: 0.07559
#
# Training: hidden=256, layers=3, lr=0.0005, batch=8, dropout=0.4
# Val Loss: 0.08412
#
# Training: hidden=256, layers=3, lr=0.0005, batch=16, dropout=0.0
# Val Loss: 0.07974
#
# Training: hidden=256, layers=3, lr=0.0005, batch=16, dropout=0.2
# Val Loss: 0.08421
#
# Training: hidden=256, layers=3, lr=0.0005, batch=16, dropout=0.4
# Val Loss: 0.08131
#
# Training: hidden=256, layers=3, lr=0.0001, batch=4, dropout=0.0
# Val Loss: 0.08796
#
# Training: hidden=256, layers=3, lr=0.0001, batch=4, dropout=0.2
# Val Loss: 0.08805
#
# Training: hidden=256, layers=3, lr=0.0001, batch=4, dropout=0.4
# Val Loss: 0.09145
#
# Training: hidden=256, layers=3, lr=0.0001, batch=8, dropout=0.0
# Val Loss: 0.08887
#
# Training: hidden=256, layers=3, lr=0.0001, batch=8, dropout=0.2
# Val Loss: 0.08846
#
# Training: hidden=256, layers=3, lr=0.0001, batch=8, dropout=0.4
# Val Loss: 0.09056
#
# Training: hidden=256, layers=3, lr=0.0001, batch=16, dropout=0.0
# Val Loss: 0.10543
#
# Training: hidden=256, layers=3, lr=0.0001, batch=16, dropout=0.2
# Val Loss: 0.10243
#
# Training: hidden=256, layers=3, lr=0.0001, batch=16, dropout=0.4
# Val Loss: 0.10792
#
# ✅ Best Config: Hidden=128, Layers=2, LR=0.005, Batch=4, Dropout=0.2 → Val Loss=0.04553
